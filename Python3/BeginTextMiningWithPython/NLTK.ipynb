# %%
import nltk

from nltk.corpus import brown

genre_word = [(genre,word)
              for genre in brown.categories()
              for word in brown.words(categories = genre)
              ] 

print(genre_word[0:5])
# Out:
# [('adventure', 'Dan'), ('adventure', 'Morgan'), ('adventure', 'told'), ('adventure', 'himself'), ('adventure', 'he')]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
cfd = nltk.ConditionalFreqDist(genre_word)
cfd.plot(conditions = ['news','adventure'] , samples=[u'stock', u'sunbonnet', u'Elevated', u'narcotic', u'four', u'woods', u'railing', u'Until', u'aggression', u'marching', u'looking', u'eligible', u'electricity', u'$25-a-plate', u'consulate', u'Casey', u'all-county', u'Belgians', u'Western', u'1959-60', u'Duhagon', u'sinking', u'1,119', u'co-operation', u'Famed', u'regional', u'Charitable', u'appropriation', u'yellow', u'uncertain', u'Heights', u'bringing', u'prize', u'Loen', u'Publique', u'wooden', u'Loeb', u'963', u'specialties', u'Sands', u'succession', u'Paul', u'Phyfe'])
plt.show()

# %%
def generate_model(cfdist,word,num=10):
    for i in range(num):
        print(word)
        word = cfdist[word].max()
nltk.corpus.stopwords.words
text = nltk.corpus.genesis.words('english-kjv.txt')

bigrams = nltk.bigrams(text)
# for i in bigrams:
#     print(i)

cfd = nltk.ConditionalFreqDist(bigrams)
# for i in cfd.keys():
#     print(i)
print(cfd.values())
    # print(cfd[i].tolist)
# generate_model(cfd,'the')

# %%
type(bigrams)
# Out:
# generator

# %%
porter = nltk.PorterStemmer()
porter.stem('yourselves')
# Out:
# 'yourselv'

# %%
words = nltk.word_tokenize("And now for something completely different")
nltk.pos_tag(words)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')
tagged_token
# Out:
# ('fly', 'NN')

# %%
nltk.corpus.stopwords.words()
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
for word in nltk.corpus.sinica_treebank.tagged_words():
    print (word[0], word[1])
# Out:
# 一 Neu
# 友情 Nad
# 嘉珍 Nba
# 和 Caa
# 我 Nhaa
# 住在 VC1
# 同一條 DM
# 巷子 Nab
# 我們 Nhaa
# 是 V_11
# 鄰居 Nab
# 也 Dbb
# 是 V_11
# 同班 Nv3
# 同學 Nab
# 我們 Nhaa
# 常常 Dd
# 一起 Dh
# 上學 VA4
# 一起 Dh
# 回家 VA13
# 有一天 DM
# 上學 VA4
# 時 Ng
# 我 Nhaa
# 到 P61
# 她 Nhaa
# 家 Ncb
# 等候 VK2
# 按 VC2
# 了 Di
# 門鈴 Nab
# 卻 Dbb
# 沒有 VJ3
# 任何 Neqa
# 動靜 Nad
# 正當 P16
# 我 Nhaa
# 想 VE2
# 離開 VC2
# 時 Ng
# 門 Nab
# 內 Ncda
# 突然 Dd
# 傳來 VC31
# 急促 VH11
# 的 DE
# 腳步聲 Nad
# 嘉珍 Nba
# 打開 VC2
# 了 Di
# 門 Nab
# 大聲 VH11
# 的 DE
# 叫 VE2
# 著 Di
# 快 VH13
# 點 Dfb
# 我 Nhaa
# 媽媽 Nab
# 暈倒 VH14
# 了 Ta
# 嘉珍 Nba
# 抓起 VC31
# 我 Nhaa
# 的 DE
# 手 Nab
# 急忙 Dh
# 往 P30
# 屋 Nab
# 裡 Ncda
# 跑 VA11
# 進入 VC1
# 房間 Ncb
# 看到 VE2
# 她 Nhaa
# 的 DE
# 媽媽 Nab
# 趴 VA12
# 在 P21
# 地 Naa
# 上 Ncda
# 臉色 Nad
# 蒼白 VH11
# 得 DE
# 像 P55
# 紙 Nab
# 一樣 VH11
# 這種 DM
# 情景 Nad
# 把 P07
# 我 Nhaa
# 嚇壞 VH22
# 了 Ta
# 怎麼辦 VH11
# 嘉珍 Nba
# 不停 VA11
# 的 DE
# 哭泣 VA4
# 聲音 Nad
# 有些 Dfa
# 顫抖 VA2
# 我 Nhaa
# 的 DE
# 腦海 Ncb
# 中 Ncda
# 頓時 Dd
# 一片 DM
# 空白 VH11
# 不 Dc
# 曉得 VK1
# 怎麼辦 VH11
# 才 Dd
# 好 VH11
# 過 VC1
# 了 Di
# 一會兒 Nddc
# 我 Nhaa
# 才 Dd
# 問 VE11
# 她 Nhaa
# 你 Nhaa
# 爸爸 Nab
# 呢 Tc
# 他 Nhaa
# 出差 VA4
# 了 Ta
# 嘉珍 Nba
# 擦 VC2
# 著 Di
# 眼淚 Nab
# 我 Nhaa
# 握住 VC2
# 她 Nhaa
# 的 DE
# 雙手 Naea
# 她 Nhaa
# 的 DE
# 手 Nab
# 又 Caa[P1]
# 冰 VH16
# 又 Caa[P2]
# 冷 VH11
# 這時 Ndda
# 有個 DM
# 念頭 Nac
# 突然 Dd
# 閃過 VC1
# 我 Nhaa
# 的 DE
# 眼前 Ncc
# 我 Nhaa
# 幫 VC2
# 她 Nhaa
# 撥 VC2
# 了 Di
# 一一九 Nba
# 請 VF2
# 救護車 Nab
# 來 VA11
# 而且 Cbcb
# 拍拍 VC31
# 她 Nhaa
# 的 DE
# 背 Nab
# 安慰 VC2
# 她 Nhaa
# 不要 Dbab
# 著急 VH21
# 我 Nhaa
# 會 Dbaa
# 陪 VC2
# 你 Nhaa
# 的 Ta
# 不久 Nddb
# 救護車 Nab
# 停 VH16
# 在 P21
# 她 Nhaa
# 家 Ncb
# 門口 Ncc
# 醫護 A
# 人員 Nab
# 很 Dfa
# 快 VH13
# 的 DE
# 將 P07
# 她 Nhaa
# 的 DE
# 媽媽 Nab
# 抬上 VC2
# 救護車 Nab
# 嘉珍 Nba
# 上車 VA13
# 前 Ng
# 對 P31
# 我 Nhaa
# 說 VE2
# 謝謝 VJ2
# 你 Nhaa
# 的 DE
# 幫忙 Nv1
# 我 Nhaa
# 握 VC2
# 著 Di
# 她 Nhaa
# 的 DE
# 手 Nab
# 說 VE2
# 不用 Dbab
# 謝 VJ2
# 我 Nhaa
# 因為 Cbaa
# 我們 Nhaa
# 是 V_11
# 好朋友 Nab
# 二 Neu
# 無私 VH11
# 的 DE
# 愛 Nad
# 愛 Nad
# 像 VG2
# 火紅 A
# 的 DE
# 太陽 Nab
# 散發 VC31
# 光 Naa
# 和 Caa
# 熱 Nv4
# 讓 VL4
# 大地 Nab
# 充滿 VJ3
# 生機 Nad
# 充滿 VJ3
# 希望 Nac
# 愛 Nad
# 是 V_11
# 生命 Nac
# 的 DE
# 原動力 Nad
# 史懷哲 Nba
# 醫生 Nab
# 踏遍 VC1
# 落後 VH11
# 貧困 VH11
# 的 DE
# 地區 Ncb
# 燃起 VC31
# 病患 Nab
# 重生 VH11
# 的 DE
# 希望 Nac
# 愛 Nad
# 是 V_11
# 和平 VH11
# 的 DE
# 基礎 Nad
# 德蕾莎 Nba
# 修女 Nab
# 承擔 VC2
# 千萬 Neu
# 窮人 Nab
# 的 DE
# 苦難 Nad
# 溫暖 VH16
# 無數 Neqa
# 受傷 VH11
# 的 DE
# 心靈 Nad
# 他們 Nhaa
# 奉獻 VD1
# 真愛 Nad
# 他們 Nhaa
# 散播 VC32
# 熱情 Nad
# 肯定 VK1
# 了 Di
# 生命 Nac
# 的 DE
# 價值 Nad
# 讓 VL4
# 我們 Nhaa
# 學習 VC2
# 付出 Nv1
# 讓 VL4
# 我們 Nhaa
# 學習 VC2
# 關懷 Nv2
# 生命 Nac
# 才 Dd
# 能 Dbab
# 綻放 VC31
# 光輝 Nad
# 三 Neu
# 愛 Nad
# 的 DE
# 傳承 Nv1
# 天 Ncb
# 剛 Dd
# 亮 VH11
# 江 Nbc
# 巡撫 Nab
# 坐 VA12
# 在 P21
# 書桌 Nab
# 前 Ncda
# 看 VC2
# 書 Nab
# 有一個 DM
# 侍官 Nab
# 交給 VD1
# 他 Nhaa
# 一封 DM
# 信 Nab
# 江 Nbc
# 巡撫 Nab
# 看 VC2
# 了 Di
# 信 Nab
# 原來 Dbb
# 是 Dbaa
# 一個 DM
# 書生 Nab
# 要 Dbab
# 進京 VA13
# 趕考 VA4
# 因為 Cbaa
# 缺乏 VJ3
# 旅費 Naeb
# 希望 VK1
# 到 P61
# 府中 Ncc
# 做工 VA4
# 江 Nbc
# 巡撫 Nab
# 放下 VC31
# 信 Nab
# 看 VC2
# 著 Di
# 窗 Nab
# 外 Ncda
# 隨 P58
# 風 Naa
# 飄動 VA11
# 的 DE
# 樹枝 Nab
# 回想 VE2
# 起 Di
# 二十年 DM
# 前 Ng
# 的 DE
# 往事 Nac
# 二十年 DM
# 前 Ng
# 他 Nhaa
# 在 P21
# 一個 DM
# 員外 Nab
# 家 Ncb
# 做工 VA4
# 賺取 VC31
# 趕考 VA4
# 進京 VA13
# 的 DE
# 旅費 Naeb
# 白天 Ndabe
# 他 Nhaa
# 必須 Dbab
# 做 VC31
# 一些 Neqa
# 粗重 VH11
# 的 DE
# 工作 Nac
# 晚上 Ndabe
# 他 Nhaa
# 還 Dbb
# 得 Dbab
# 挑燈 VA4
# 夜 Ndabe
# 讀 VC2
# 準備 VF1
# 參加 VC2
# 考試 Nac
# 考試 Nac
# 的 DE
# 日子 Nac
# 快 Dd
# 到 VC1
# 了 Ta
# 可是 Cbca
# 他 Nhaa
# 的 DE
# 心情 Nad
# 卻 Dbb
# 很 Dfa
# 沉重 VH11
# 當 P16
# 他 Nhaa
# 正 Dd
# 為了 P03
# 缺乏 VJ3
# 旅費 Naeb
# 而 Cbca
# 發愁 VH11
# 的 DE
# 時候 Nad
# 員外 Nab
# 來 Dbab
# 找 VC2
# 他 Nhaa
# 並且 Cbcb
# 對 P31
# 他 Nhaa
# 說 VE2
# 我 Nhaa
# 看 VE2
# 你 Nhaa
# 悶悶不樂 VH21
# 是不是 Dbaa
# 進京 VA13
# 趕考 VA4
# 的 DE
# 旅費 Naeb
# 不 Dc
# 夠 VH15
# 這裡 Ncdb
# 有 V_2
# 一些 Neqa
# 銀子 Nab
# 你 Nhaa
# 帶 VC32
# 在 P21
# 身 Nab
# 上 Ncda
# 立刻 Dd
# 動身 VA4
# 去 Dbab
# 趕考 VA4
# 吧 Tc
# 他 Nhaa
# 接 VC31
# 過 Di
# 銀子 Nab
# 感動 VH22
# 得 DE
# 說不出 VE2[+NEG]
# 話 Nac
# 來 Ta
# 後來 Nddb
# 他 Nhaa
# 果然 Dbb
# 金榜題名 VH11
# 當 P16
# 他 Nhaa
# 帶 VC32
# 著 Di
# 禮物 Nab
# 和 Caa
# 銀子 Nab
# 向 P62
# 員外 Nab
# 道謝 VB11
# 時 Ng
# 員外 Nab
# 握 VC2
# 著 Di
# 他 Nhaa
# 的 DE
# 手 Nab
# 說 VE2
# 你 Nhaa
# 不用 Dbab
# 還 VD1
# 我 Nhaa
# 了 Ta
# 我 Nhaa
# 只是 Dbb
# 盡 VJ1
# 一份 DM
# 心力 Nad
# 而已 Tb
# 以後 Nddb
# 有 V_2
# 機會 Nac
# 希望 VK1
# 你 Nhaa
# 也 Dbb
# 能夠 Dbab
# 幫助 VC2
# 別人 Nhaa
# 江 Nbc
# 巡撫 Nab
# 正 Dd
# 想 VE2
# 得 DE
# 入神 VH11
# 突然 Dd
# 聽到 VE2
# 一聲 DM
# 大人 Nab
# 江 Nbc
# 巡撫 Nab
# 回過神 VH11[+ASP]
# 對 P31
# 侍官 Nab
# 說 VE2
# 快 Dd
# 請 VF2
# 書生 Nab
# 進來 VA11
# 書生 Nab
# 低著頭 VA4[+ASP]
# 慢慢 VH11
# 的 DE
# 走到 VC1
# 他 Nhaa
# 的 DE
# 面前 Ncc
# 江 Nbc
# 巡撫 Nab
# 對 P31
# 書生 Nab
# 說 VE2
# 不要 Dbab
# 錯過 VJ1
# 今年 Ndaba
# 的 DE
# 考試 Nad
# 這些 Neqa
# 銀子 Nab
# 你 Nhaa
# 就 Dd
# 帶 VC32
# 在 P21
# 身 Nab
# 上 Ncda
# 動身 VA4
# 趕考 VA4
# 吧 Tc
# 書生 Nab
# 用 P39
# 顫抖 VA2
# 的 DE
# 手 Nab
# 接過 VC2
# 銀子 Nab
# 含 VJ3
# 著 Di
# 眼淚 Nab
# 說 VE2
# 謝謝 VJ2
# 您 Nhac
# 我 Nhaa
# 不 Dc
# 知道 VK1
# 要 Dbab
# 怎麼 Dj
# 來 Dbab
# 報答 VC2
# 您 Nhac
# 江 Nbc
# 巡撫 Nab
# 說 VE2
# 你 Nhaa
# 不必 Dbab
# 謝 VJ2
# 我 Nhaa
# 也 Dbb
# 不必 Dbab
# 回報 VC2
# 我 Nhaa
# 四 Neu
# 快樂 VH21
# 的 DE
# 閱讀課 Nac
# 上 VC1
# 國語課 Nac
# 的 DE
# 時候 Nad
# 老師 Nab
# 叫 VF2
# 我們 Nhaa
# 這一組 DM
# 做 VC31
# 讀書 Nv4
# 心得 Nac
# 報告 Nab
# 我 Nhaa
# 第一個 DM
# 站起來 VA11
# 發言 VA4
# 我們 Nhaa
# 閱讀 VC2
# 的 DE
# 好 VH11
# 書 Nab
# 是 V_11
# 小 VH13
# 王子 Nab
# 這 Nep
# 是 V_11
# 法國人 Nab
# 聖修伯里 Nba
# 的 DE
# 作品 Nac
# 書 Nab
# 中 Ncda
# 畫滿 VC33
# 了 Di
# 可愛 VH11
# 的 DE
# 插圖 Nac
# 小 VH13
# 王子 Nab
# 的 DE
# 外型 Nad
# 很 Dfa
# 討人喜歡 VH11
# 這本 DM
# 書 Nab
# 的 DE
# 內容 Nad
# 是 Dbaa
# 說 VE2
# 一個 DM
# 飛行員 Nab
# 在 VC1
# 非洲 Nca
# 沙漠 Nab
# 裡 Ncda
# 遇見 VC2
# 了 Di
# 小 VH13
# 王子 Nab
# 小 VH13
# 王子 Nab
# 告訴 VE12
# 他 Nhaa
# 在 P21
# 星球 Nab
# 旅行 VA4
# 的 DE
# 經過 Nac
# 兩 Neu
# 人 Nab
# 成為 VG2
# 知心 A
# 的 DE
# 朋友 Nab
# 我 Nhaa
# 說完 VC2
# 之後 Ng
# 組長 Nab
# 站起來 VA11
# 補充 VC31
# 說 VE2
# 小 VH13
# 王子 Nab
# 是 V_11
# 一個 DM
# 可愛 VH11
# 的 DE
# 人 Nab
# 他 Nhaa
# 在 VC1
# 小 VH13
# 行星 Nab
# 上 Ncda
# 每天 DM
# 照顧 VC2
# 會 Dbaa
# 說話 VA4
# 的 DE
# 玫瑰花 Nab
# 、 Caa
# 清理 VC2
# 火山灰 Naa
# 而且 Cbcb
# 欣賞 VJ2
# 落日 Naa
# 我 Nhaa
# 喜歡 VK1
# 這種 DM
# 自由自在 VH11
# 的 DE
# 生活 Nad
# 明珠 Nba
# 說 VE2
# 這本 DM
# 書 Nab
# 最 Dfa
# 精采 VH11
# 的 DE
# 部分 Neqa
# 遇到 VC2
# 許多 Neqa
# 不同 VH11
# 類型 Nac
# 的 DE
# 人 Nab
# 有 V_2
# 自大 VH11
# 先生 Nab
# 、 Caa
# 愛 VL1
# 下 VC31
# 命令 Nac
# 的 DE
# 國王 Nab
# 、 Caa
# 賣 VD1
# 解渴丸 Nab
# 的 DE
# 商人 Nab
# 等 Cab
# 小 VH13
# 王子 Nab
# 不 Dc
# 喜歡 VK1
# 自大 VH11
# 的 DE
# 人 Nab
# 也 Dbb
# 不 Dc
# 喜歡 VK1
# 虛偽 VH11
# 的 DE
# 人 Nab
# 我 Nhaa
# 覺得 VK1
# 小 VH13
# 王子 Nab
# 很 Dfa
# 正直 VH11
# 最後 Nddc
# 阿平 Nba
# 說 VE2
# 這本 DM
# 書 Nab
# 中 Ng
# 有 V_2
# 許多 Neqa
# 值得 VH15
# 思考 VE2
# 的 DE
# 句子 Nac
# 例如 P54
# 狐狸 Nab
# 告訴 VE12
# 小 VH13
# 王子 Nab
# 重要 VH11
# 的 DE
# 東西 Nab
# 不能 Dbab
# 只 Daa
# 靠 P27
# 眼睛 Nab
# 去 Dbab
# 看 VC2
# 只有 Dbb
# 用心 VH11
# 去 Dbab
# 體會 VK1
# 才 Dd
# 能 Dbab
# 看到 VE2
# 事物 Naeb
# 的 DE
# 真相 Nac
# 這 Nep
# 是 V_11
# 我 Nhaa
# 閱讀 VC2
# 小 VH13
# 王子 Nab
# 最 Dfa
# 大 VH13
# 的 DE
# 收穫 Nac
# 我們 Nhaa
# 這一組 DM
# 報告完 VE2
# 之後 Ng
# 獲得 VJ3
# 同學 Nab
# 熱烈 VH11
# 的 DE
# 掌聲 Nad
# 老師 Nab
# 說 VE2
# 這一組 DM
# 小朋友 Nab
# 不但 Cbbb
# 說 VE2
# 了 Di
# 這本 DM
# 書 Nab
# 的 DE
# 大意 Nad
# 而且 Cbcb
# 說出 VE2
# 心得 Nac
# 感想 Nac
# 也 Dbb
# 提到 VE2
# 書 Nab
# 中 Ncda
# 的 DE
# 好 VH11
# 句子 Nac
# 有 V_2
# 了 Di
# 這三項 DM
# 再 Dd
# 寫出 VC31
# 作者 Nab
# 和 Caa
# 出版社 Ncb
# 就 Dd
# 是 V_11
# 一份 DM
# 完整 VH11
# 的 DE
# 讀書 Nv4
# 報告 Nab
# 了 Ta
# 收穫 Nac
# 很多 VH11
# 五 Neu
# 書 Nab
# 的 DE
# 誕生 Nv4
# 書 Nab
# 是 V_11
# 人類 Naeb
# 的 DE
# 好朋友 Nab
# 它 Nhaa
# 用來 VL2
# 表達 VC31
# 作者 Nab
# 的 DE
# 思想 Nad
# 和 Caa
# 情感 Nad
# 更 Dfa
# 用來 VL2
# 傳播 VC33
# 知識 Nac
# 是 Dbaa
# 怎樣 Dh
# 誕生 VA12
# 的 Ta
# 呢 Tc
# 人類 Naeb
# 有 V_2
# 了 Di
# 文字 Nac
# 以後 Ng
# 用 P39
# 文字 Nac
# 表達 VC31
# 思想 Nad
# 和 Caa
# 情感 Nad
# 這些 Neqa
# 文字 Nac
# 最早 Dd
# 是 Dbaa
# 刻 VC33
# 在 P21
# 竹片 Nab
# 或 Caa
# 木片 Nab
# 上 Ncda
# 古人 Nab
# 稱為 VG1
# 冊 Nab
# 冊 Nab
# 太 Dfa
# 重 VH12
# 了 Ta
# 於是 Cbca
# 人們 Naeb
# 把 P07
# 文字 Nac
# 寫 VC33
# 在 P21
# 絲 Naa
# 上 Ncda
# 稱為 VG1
# 帛書 Nab
# 絲 Naa
# 很 Dfa
# 貴 VH11
# 聰明 VH11
# 的 DE
# 祖先 Nab
# 又 Dd
# 發明 VC31
# 了 Di
# 紙 Nab
# 過去 Ndda
# 人們 Naeb
# 用 P39
# 手抄 A
# 的 DE
# 方式 Nac
# 寫 VC33
# 書 Nab
# 到 VC1
# 了 Di
# 唐代 Ndaab
# 開始 VL2
# 用 P39
# 印刷術 Nad
# 印 VC33
# 書 Nab
# 現在 Nddc
# 印刷術 Nad
# 越來越 Dfa
# 進步 VH11
# 人們 Naeb
# 可以 Dbab
# 讀到 VC2
# 更 Dfa
# 精美 VH11
# 、 Caa
# 更 Dfa
# 多樣 VH11
# 的 DE
# 書 Nab
# 書 Nab
# 是 Dbaa
# 怎樣 Dh
# 完成 VC31
# 的 Ta
# 呢 Tc
# 作者 Nab
# 把 P07
# 文章 Nac
# 送 VD1
# 到 P61
# 印刷廠 Ncb
# 進行 VC2
# 電腦 Nab
# 打字 Nv4
# 和 Caa
# 排版 Nv4
# 接著 Dd
# 是 V_11
# 校對 VC2
# 的 DE
# 工作 Nac
# 校對 VC2
# 之後 Ng
# 再 Dd
# 加上 VC2
# 插圖 Nac
# 就 Dd
# 可以 Dbab
# 印刷 VC31
# 了 Ta
# 印刷 Nv1
# 和 P35
# 紙 Nab
# 有 V_2
# 密切 VH11
# 的 DE
# 關係 Nad
# 不管 Cbaa
# 是 V_11
# 銅版紙 Nab
# 或是 Caa
# 道林紙 Nab
# 都 Dab
# 各 Dab
# 具 VJ3
# 特色 Nac
# 等到 P18
# 散發 VC31
# 著 Di
# 油墨 Naa
# 芳香 Nv4
# 的 DE
# 紙張 Naeb
# 裝釘成冊 VB11
# 後 Ng
# 加上 VC2
# 封面 Nab
# 就 Dd
# 完成 VC31
# 了 Di
# 如果 Cbaa
# 作者 Nab
# 是 V_11
# 書 Nab
# 的 DE
# 母親 Nab
# 印刷廠 Ncb
# 就 Dd
# 是 V_11
# 產婆 Nab
# 兩 Neu
# 者 Nab
# 同等 A
# 重要 VH11
# 還 Dbb
# 要 Dbab
# 為 P03
# 它 Nhaa
# 辦理 VC2
# 一張 DM
# 身分證 Nab
# 那 Nep
# 就 Dd
# 是 V_11
# 版權頁 Nab
# 放 VC33
# 在 P21
# 書 Nab
# 的 DE
# 後面 Ncdb
# 有 V_2
# 了 Di
# 它 Nhaa
# 新 VH11
# 書 Nab
# 就 Dd
# 可以 Dbab
# 合法 VH11
# 的 DE
# 和 P35
# 讀者 Nab
# 見面 VA4
# 了 Ta
# 六 Neu
# 拜訪 VC2
# 書 Nab
# 的 DE
# 家 Ncb
# 阿群 Nba
# 是 V_11
# 我們 Nhaa
# 班 Ncb
# 上 Ncda
# 的 DE
# 風雲人物 Nab
# 不但 Cbbb
# 功課 Nac
# 好 VH11
# 而且 Cbcb
# 很 Dfa
# 熱心 VJ1
# 他 Nhaa
# 參加 VC2
# 校 Ncb
# 內 Ncda
# 的 DE
# 科展 Nad
# 、 Caa
# 演講 Nad
# 、 Caa
# 查 VE2
# 資料 Nab
# 比賽 Nac
# 常常 Dd
# 拿 VC31
# 第一 Neu
# 同學 Nab
# 們 Naea
# 都 Dab
# 說 VE2
# 他 Nhaa
# 有 V_2
# 一個 DM
# 金 Naa
# 頭腦 Nab
# 然而 Cbca
# 阿群 Nba
# 總是 Dd
# 客氣 VH11
# 的 DE
# 說 VE2
# 我 Nhaa
# 只是 Dbb
# 知道 VK1
# 知識 Nac
# 的 DE
# 寶庫 Nab
# 在 VC1
# 哪裡 Ncdb
# 常常 Dd
# 去 Dbab
# 使用 VC2
# 它 Nhaa
# 而已 Tb
# 一個 DM
# 假日 Ndabf
# 阿群 Nba
# 邀 VF2
# 我 Nhaa
# 去 VC1
# 圖書館 Ncb
# 走入 VC1
# 寬敞 VH11
# 的 DE
# 閱覽室 Ncb
# 空氣 Naa
# 中 Ncda
# 飄送 VH14
# 著 Di
# 淡淡 VH11
# 的 DE
# 書香 Nad
# 我 Nhaa
# 第一眼 DM
# 就 Dd
# 看到 VE2
# 新 VH11
# 書 Nab
# 展示架 Nab
# 上 Ncda
# 放 VC33
# 著 Di
# 許多 Neqa
# 才 Dd
# 出版 VC31
# 的 DE
# 書 Nab
# 和 Caa
# 雜誌 Nab
# 再 Dd
# 往 P30
# 裡面 Ncdb
# 走 VA11
# 一座座 Neqa
# 書架 Nab
# 上 Ncda
# 放 VC33
# 著 Di
# 各類 DM
# 圖書 Naeb
# 有 V_2
# 精裝 A
# 書 Nab
# 、 Caa
# 平裝 A
# 書 Nab
# 這兒 Ncdb
# 就 Dd
# 像 VG2
# 一個 DM
# 書籍 Naeb
# 的 DE
# 大 VH13
# 家庭 Nac
# 圖書館 Ncb
# 不但 Cbbb
# 是 V_11
# 書 Nab
# 的 DE
# 家 Ncb
# 而且 Cbcb
# 是 V_11
# 舉辦 VC2
# 書香 Nad
# 活動 Nac
# 的 DE
# 好 VH11
# 地方 Nab
# 當天 Ndabd
# 我們 Nhaa
# 參加 VC2
# 活用 VC2
# 工具書 Nab
# 的 DE
# 比賽 Nac
# 抽中 VC2
# 的 DE
# 題目 Nac
# 是 V_11
# 臺灣 Nca
# 有 V_2
# 哪些 Neqa
# 列入 VJ1
# 保育 Nv1
# 的 DE
# 鳥類 Nad
# 我 Nhaa
# 原本 Dd
# 打算 VF1
# 在 P21
# 自然 Nad
# 科學類 Naeb
# 中 Ng
# 找 VC2
# 答案 Nac
# 阿群 Nba
# 建議 VE2
# 先 Dd
# 查尋 VE2
# 期刊 Nab
# 索引 Nac
# 來 Dbab
# 找 VC2
# 相關 VH11
# 資料 Nab
# 找到 VC2
# 黑面琵鷺 Nab
# 等 Cab
# 保育 Nv1
# 鳥類 Nad
# 的 DE
# 報導 Nac
# 由於 Cbba
# 我們 Nhaa
# 快速 VH11
# 的 DE
# 找到 VC2
# 完整 VH11
# 的 DE
# 資料 Nab
# 所以 Cbca
# 得到 VJ3
# 優等 Nad
# 阿群 Nba
# 真 Dbb
# 不愧 Dbb
# 是 V_11
# 個 DM
# 查 VE2
# 資料 Nab
# 的 DE
# 高手 Nab
# 我 Nhaa
# 打從 P17
# 心 Nab
# 裡 Ncda
# 佩服 VJ2
# 他 Nhaa
# 走出 VC1
# 圖書館 Ncb
# 我 Nhaa
# 向 P62
# 阿群 Nba
# 說 VE2
# 現在 Nddc
# 我 Nhaa
# 知道 VK1
# 了 Ta
# 也 Dbb
# 是 V_11
# 知識 Nac
# 的 DE
# 寶庫 Nab
# 以後 Nddb
# 我 Nhaa
# 要 Dbab
# 常 Dd
# 來 Dbab
# 拜訪 VC2
# 它 Nhaa
# 七 Neu
# 登山 VA13
# 今年 Ndaba
# 的 DE
# 重陽節 Ndabd
# 正好 Daa
# 是 V_11
# 星期天 Ndabd
# 爸爸 Nab
# 帶 VC32
# 著 Di
# 我們 Nhaa
# 全 Neqa
# 家 Ncb
# 去 Dbab
# 爬山 VA13
# 爸爸 Nab
# 說 VE2
# 中國人 Nab
# 都 Dab
# 以 P11
# 登高 VA13
# 來 Dbab
# 慶祝 VE2
# 這個 DM
# 日子 Nac
# 來到 VC1
# 山腳 Ncb
# 下 Ncda
# 已經 Dd
# 看到 VE2
# 許多 Neqa
# 人 Nab
# 踩 VC2
# 著 Di
# 陽光 Naa
# 陸陸續續 Dd
# 的 DE
# 登上 VC1
# 山路 Nab
# 了 Ta
# 走到 VC1
# 半 Neqa
# 山 Nab
# 上 Ncda
# 看到 VE2
# 一個 DM
# 年輕人 Nab
# 站 VA12
# 在 P21
# 路 Nab
# 旁 Ncda
# 滿頭大汗 VH11
# 氣喘如牛 VH11
# 爸爸 Nab
# 走到 VC1
# 年輕人 Nab
# 的 DE
# 身邊 Ncc
# 關心 VK1
# 的 DE
# 問 VE11
# 他 Nhaa
# 年輕人 Nab
# 啊 Tc
# 怎麼 Dj
# 才 Dd
# 走到 VC1
# 山腰 Ncb
# 就 Dd
# 走不動 VH11
# 了 Ta
# 呢 Tc
# 年輕人 Nab
# 擦 VC2
# 著 Di
# 汗水 Naa
# 不好意思 VH21
# 的 DE
# 說 VE2
# 爬山 VA13
# 好 Dfa
# 累 VH16
# 我 Nhaa
# 的 DE
# 腿 Nab
# 已經 Dd
# 不聽使喚 VH11
# 了 Ta
# 氣 Naa
# 也 Dbb
# 喘不過來 VA4[+NEG,+ASP]
# 了 Ta
# 山路 Nab
# 不 Dc
# 難 VH11
# 走 VA11
# 你 Nhaa
# 走不動 VH11
# 是 Dbaa
# 因為 Cbaa
# 平常 Nddc
# 運動 Nac
# 太少 VH11
# 了 Ta
# 年輕人 Nab
# 嘆 VE2
# 了 Di
# 一口 DM
# 氣 Naa
# 說 VE2
# 唉 I
# 沒辦法 VI2
# 平日 Nddc
# 工作 Nac
# 太 Dfa
# 忙碌 VH11
# 了 Ta
# 沒 VJ3
# 時間 Nad
# 運動 VA4
# 爸爸 Nab
# 笑 VA4
# 著 Di
# 說 VE2
# 一個 DM
# 人 Nab
# 不能 Dbab
# 只有 Dbb
# 工作 VA4
# 休閒 VA12
# 和 Caa
# 運動 VA4
# 也 Dbb
# 很 Dfa
# 重要 VH11
# 的 Ta
# 登山 VA13
# 是 V_11
# 很 Dfa
# 好 VH11
# 的 DE
# 運動 Nac
# 可以 Dbab
# 呼吸 VC2
# 新鮮 VH11
# 空氣 Naa
# 可以 Dbab
# 鍛鍊 VC2
# 身體 Nab
# 還可以 Dbab
# 欣賞 VJ2
# 美麗 VH11
# 的 DE
# 風景 Nad
# 你 Nhaa
# 說 VE2
# 是 V_11
# 不 Dc
# 是 V_11
# 啊 Tc
# 年輕人 Nab
# 伸展 VC2
# 了 Di
# 雙臂 Naea
# 深深 VH11
# 的 DE
# 吸 VC31
# 了 Di
# 一口 DM
# 氣 Naa
# 說 VE2
# 真 VH11
# 的 Ta
# 山 Nab
# 上 Ncda
# 的 DE
# 空氣 Naa
# 真 Dbb
# 好 VH11
# 爸爸 Nab
# 轉過身 VA11[+ASP]
# 對 P31
# 我們 Nhaa
# 說 VE2
# 要 Dbab
# 多 Neqa
# 運動 VA4
# 身體 Nab
# 才 Dd
# 健康 VH11
# 有 V_2
# 健康 VH11
# 的 DE
# 身體 Nab
# 讀書 VA4
# 工作 VA4
# 才 Dd
# 會 Dbaa
# 有 V_2
# 效率 Nad
# 這時 Ndda
# 我 Nhaa
# 看到 VE2
# 年輕人 Nab
# 望 VC2
# 了 Di
# 爸爸 Nab
# 說 VE2
# 您 Nhac
# 臉色 Nad
# 紅潤 VH11
# 精力 Nad
# 充沛 VH11
# 一定 Dbaa
# 是 Dbaa
# 常 Dd
# 運動 VA4
# 囉 Tc
# 只 Daa
# 見 VE2
# 爸爸 Nab
# 得意 VH21
# 的 DE
# 回答 VE12
# 嗯 I
# 我 Nhaa
# 早睡早起 VA12
# 每天 DM
# 做 VC31
# 體操 Nad
# 假日 Ndabf
# 就 Dd
# 帶 VC32
# 家人 Nab
# 爬山 VA13
# 享受 VJ2
# 可貴 VH11
# 的 DE
# 森林浴 Nac
# 運動 Nac
# 帶給 VD1
# 我 Nhaa
# 舒適 VH11
# 和 Caa
# 健康 VH11
# 的 DE
# 生活 Nad
# 年輕人 Nab
# 點點頭 VA4
# 好像 Dbaa
# 已經 Dd
# 找到 VC2
# 健康 VH11
# 的 DE
# 途徑 Nac
# 了 Ta
# 爸爸 Nab
# 拍拍 VC2
# 年輕人 Nab
# 的 DE
# 肩 Nab
# 說 VE2
# 加油 VB12
# 吧 Tc
# 我們 Nhaa
# 一起 Dh
# 登山 VA13
# 慶祝 VE2
# 重陽 Ndabd
# 佳節 Nac
# 我們 Nhaa
# 一步 DM
# 一步 DM
# 的 DE
# 向 P62
# 山 Nab
# 上 Ncda
# 前進 VA11
# 八 Neu
# 健康 VH11
# 四則 DM
# 踢踢腿 VA4
# 來 Ta
# 彎彎腰 VA4
# 我們 Nhaa
# 一起 Dh
# 作 VC31
# 體操 Nad
# 一 Neu
# 、 Caa
# 二 Neu
# 、 Caa
# 三 Neu
# 、 Caa
# 四 Neu
# 二 Neu
# 、 Caa
# 二 Neu
# 、 Caa
# 三 Neu
# 、 Caa
# 四 Neu
# 天天 Dd
# 運動 VA4
# 精神 Nad
# 好 VH11
# 身體 Nab
# 健康 VH11
# 沒 Dc
# 煩惱 VH11
# 早餐 Nab
# 吃 VC31
# 得 DE
# 好 VH11
# 營養 Nad
# 均衡 VH16
# 很 Dfa
# 重要 VH11
# 午餐 Naa
# 吃 VC31
# 得 DE
# 飽 VH11
# 魚肉 Naa
# 蔬菜 Naa
# 不可 Dbab
# 少 VH13
# 晚餐 Nab
# 吃 VC31
# 得 DE
# 巧 VH11
# 腸胃 Naeb
# 休息 VA12
# 睡得著 VH11[+DE]
# 拒絕 VF1
# 煙 Naa
# 拒絕 VF1
# 酒 Naa
# 檳榔 Nab
# 更 Dfa
# 是 Dbaa
# 不 Dc
# 入 VC1
# 口 Nab
# 毒品 Naa
# 傷身 VH21
# 又 Caa
# 害命 VH11
# 嘗試 VF1
# 之後 Ng
# 易 VH15
# 上鉤 VH11
# 快 Dd
# 向 P62
# 它們 Nhaa
# 說 VE2
# 聲 DM
# 不 Dc
# 青春 Nad
# 歲月 Nad
# 才 Dd
# 長久 VH11
# 吸收 VC31
# 新 VH11
# 知識 Nac
# 態度 Nad
# 認真 VH11
# 又 Caa
# 積極 VH11
# 多 Neqa
# 交 VC2
# 好朋友 Nab
# 接納 VC2
# 別人 Nhaa
# 的 DE
# 建議 Nac
# 肯定 VK1
# 自己 Nhab
# 的 DE
# 能力 Nad
# 心理 Nad
# 要 Dbab
# 健康 VH11
# 生活 Nad
# 才 Dd
# 能 Dbab
# 有 V_2
# 意義 Nad
# 九 Neu
# 探病 VA4
# 一向 Dd
# 健康 VH11
# 活潑 VH11
# 的 DE
# 小 VH13
# 阿姨 Nab
# 竟然 Dbb
# 生病 VH11
# 住院 VA13
# 了 Ta
# 媽媽 Nab
# 知道 VK1
# 這個 DM
# 消息 Nac
# 心 Nab
# 裡 Ncda
# 很 Dfa
# 著急 VH21
# 趕緊 Dd
# 帶 VC32
# 著 Di
# 我 Nhaa
# 到 P61
# 醫院 Ncb
# 探病 VA4
# 媽媽 Nab
# 在 VC1
# 醫院 Ncb
# 大門 Nab
# 旁 Ncda
# 的 DE
# 水果店 Ncb
# 買 VC31
# 了 Di
# 一盒 DM
# 蘋果 Nab
# 禮盒 Nab
# 小 VH13
# 阿姨 Nab
# 喜歡 VK1
# 吃 VC31
# 蘋果 Nab
# 等一下 Dd
# 看到 VE2
# 她 Nhaa
# 你 Nhaa
# 就 Dd
# 先 Dd
# 把 P07
# 蘋果 Nab
# 送給 VD1
# 她 Nhaa
# 祝 VE12
# 她 Nhaa
# 平平安安 VH11
# 早日 Dd
# 康復 VH11
# 走進 VC1
# 醫院 Ncb
# 搭 VC2
# 電梯 Nab
# 上 VC1
# 了 Di
# 五樓 Nab
# 看到 VE2
# 有的 Neqa
# 病人 Nab
# 骨瘦如柴 VH11
# 的 DE
# 躺 VA12
# 在 P21
# 床 Nab
# 上 Ncda
# 有的 Neqa
# 病人 Nab
# 在 Dd
# 打點滴 VA4
# 看到 VE2
# 這 Nep
# 許多 Neqa
# 失去 VJ3
# 健康 Nv4
# 的 DE
# 人 Nab
# 我 Nhaa
# 的 DE
# 心 Nab
# 裡 Ncda
# 很 Dfa
# 難過 VK1
# 找到 VC2
# 小 VH13
# 阿姨 Nab
# 的 DE
# 病房 Ncb
# 媽媽 Nab
# 趕緊 Dd
# 走向 VC1
# 床 Nab
# 邊 Ncda
# 拉 VC2
# 著 Di
# 她 Nhaa
# 的 DE
# 手 Nab
# 輕輕 VH11
# 的 DE
# 問 VE11
# 現在 Nddc
# 好 VH11
# 一點兒 Neqa
# 了 Ta
# 嗎 Td
# 小 VH13
# 阿姨 Nab
# 紅 VH11
# 著 Di
# 眼眶 Nab
# 說 VE2
# 本來 Dd
# 只 Daa
# 是 V_11
# 輕微 VH11
# 的 DE
# 感冒 Nad
# 我 Nhaa
# 相信 VK1
# 了 Di
# 藥品 Naeb
# 廣告 Nac
# 就 Dd
# 隨便 VH11
# 買 VC31
# 成藥 Nab
# 吃 VC31
# 後來 Nddb
# 全 Neqa
# 身 Nab
# 紅腫 VH11
# 又 Caa[P1]
# 癢 VH11
# 又 Caa[P2]
# 痛 VH11
# 醫師 Nab
# 告訴 VE12
# 我 Nhaa
# 不 Dc
# 該 Dbab
# 自己 Nhab
# 亂 VH11
# 吃 VC31
# 藥 Nab
# 媽媽 Nab
# 安慰 VC2
# 小 VH13
# 阿姨 Nab
# 說 VE2
# 現在 Nddc
# 妳 Nhaa
# 要 Dbab
# 安心 VH21
# 養病 VA4
# 聽從 VC2
# 醫師 Nab
# 的 DE
# 吩咐 Nv1
# 好好 VH11
# 接受 VC31
# 治療 Nad
# 身體 Nab
# 就 Dd
# 會 Dbaa
# 很 Dfa
# 快 VH13
# 的 DE
# 恢復 VH16
# 健康 VH11
# 離開 VC2
# 醫院 Ncb
# 在 P21
# 回家 VA13
# 的 DE
# 路 Nab
# 上 Ncda
# 看到 VE2
# 來來往往 VA11
# 的 DE
# 行人 Nab
# 我 Nhaa
# 才 Dd
# 知道 VK1
# 才 Dd
# 能 Dbab
# 讀書 VA4
# 、 Caa
# 工作 VA4
# 、 Caa
# 服務 VC2
# 社會 Nac
# 媽媽 Nab
# 牽 VC2
# 著 Di
# 我 Nhaa
# 的 DE
# 手 Nab
# 說 VE2
# 你 Nhaa
# 看 VC2
# 身體 Nab
# 健康 VH11
# 多麼 Dfa
# 重要 VH11
# 啊 Tc
# 你 Nhaa
# 知道 VK1
# 嗎 Td
# 西方 Ncdb
# 有 V_2
# 句 DM
# 話 Nac
# 說 VE2
# 寧願 VK1
# 做 VG2
# 一個 DM
# 健康 VH11
# 的 DE
# 乞丐 Nab
# 也 Dbb
# 不要 Dbab
# 做 VG2
# 一個 DM
# 生病 VH11
# 的 DE
# 國王 Nab
# 這次 DM
# 跟 P63
# 媽媽 Nab
# 到 P61
# 醫院 Ncb
# 探病 VA4
# 不但 Cbbb
# 安慰 VC2
# 了 Di
# 小 VH13
# 阿姨 Nab
# 也 Dbb
# 讓 VL4
# 我 Nhaa
# 體會 VK1
# 了 Di
# 健康 Nv4
# 的 DE
# 重要 Nv4
# 十 Neu
# 孝子泉 Nab
# 大福 Nba
# 是 V_11
# 個 DM
# 孝順 VJ1
# 的 DE
# 孩子 Nab
# 有一次 DM
# 他 Nhaa
# 的 DE
# 父親 Nab
# 得 VJ3
# 了 Di
# 怪病 Nac
# 身 Nab
# 上 Ncda
# 長滿 VH14
# 又 Caa[P1]
# 紅 VH11
# 又 Caa[P2]
# 腫 VH11
# 的 DE
# 斑塊 Naa
# 整天 DM
# 痛苦 VH21
# 的 DE
# 呻吟 VA4
# 著 Di
# 大福 Nba
# 焦急 VH21
# 的 DE
# 背 VC33
# 著 Di
# 父親 Nab
# 到處 Dg
# 看病 VA4
# 花 VC31
# 了 Di
# 不少 Neqa
# 錢 Naeb
# 病情 Nad
# 卻 Dbb
# 依然 Dd
# 沒有 VJ3
# 起色 Nad
# 一天 DM
# 晚上 Ndabe
# 大福 Nba
# 靠在 VJ1
# 父親 Nab
# 的 DE
# 床 Nab
# 邊 Ncda
# 打瞌睡 VA12
# 忽 Dd
# 聽到 VE2
# 有 Nes
# 人 Nab
# 唱 VC2
# 著 Di
# 千種 DM
# 病 Nad
# 萬種 DM
# 病 Nad
# 神醫 Nab
# 能 Dbab
# 治 VC2
# 奇怪 VH11
# 病 Nad
# 千座 DM
# 山 Nab
# 萬座 DM
# 山 Nab
# 神醫 Nab
# 就 Dd
# 在 VC1
# 安平山 Nca
# 大福 Nba
# 聽到 VE2
# 了 Di
# 歌聲 Nad
# 決定 VE2
# 天 Ncb
# 一 Dd
# 亮 VH11
# 就 Dd
# 上山 VA13
# 去 Dbab
# 找 VC2
# 神醫 Nab
# 隔天 Ndabd
# 一大早 Ndc
# 大福 Nba
# 背 VC2
# 著 Di
# 父親 Nab
# 向 P62
# 山 Nab
# 上 Ncda
# 走去 VA11
# 一 Neu
# 路 Nab
# 上 Ncda
# 長長 VH11
# 的 DE
# 芒草 Nab
# 割破 VC2
# 了 Di
# 大福 Nba
# 的 DE
# 手腳 Naeb
# 粗糙 VH11
# 的 DE
# 石塊 Nab
# 刺穿 VC2
# 了 Di
# 他 Nhaa
# 的 DE
# 草鞋 Nab
# 背 Nab
# 上 Ncda
# 的 DE
# 父親 Nab
# 似乎 Dbaa
# 越來越 Dfa
# 重 VH12
# 了 Ta
# 可是 Cbca
# 大福 Nba
# 仍然 Dbb
# 盡力 VH11
# 的 DE
# 向 P62
# 前 Ncda
# 走 VA11
# 一心 Dh
# 只 Daa
# 想 VE2
# 找到 VC2
# 神醫 Nab
# 為 P03
# 父親 Nab
# 治病 VB11
# 到 VC1
# 了 Di
# 安平山 Nca
# 山頂 Ncc
# 坐 VA12
# 著 Di
# 一個 DM
# 老人 Nab
# 就 Dd
# 過去 VA11
# 向 P62
# 他 Nhaa
# 說明 VE2
# 來意 Nad
# 老人 Nab
# 緊閉 VH11
# 著 Di
# 雙眼 Naea
# 不 Dc
# 說話 VA4
# 大福 Nba
# 跪 VA12
# 在 P21
# 地 Naa
# 上 Ncda
# 一面 Dd
# 流淚 VA4
# 一面 Dd
# 苦苦 VH11
# 的 DE
# 哀求 VF2
# 老人 Nab
# 被 P02
# 大福 Nba
# 的 DE
# 孝心 Nad
# 感動 VH22
# 便 Dd
# 給 VD1
# 了 Di
# 大福 Nba
# 一粒 DM
# 金色 Nad
# 的 DE
# 丸子 Nab
# 叫 VF2
# 他 Nhaa
# 把 P07
# 金丸 Nab
# 丟進 VC1
# 山泉 Naa
# 裡 Ncda
# 再 Dd
# 讓 VL4
# 父親 Nab
# 下去 VA11
# 浸泡 VB12
# 就 Dd
# 能 Dbab
# 治好 VC2
# 父親 Nab
# 的 DE
# 病 Nad
# 了 Ta
# 大福 Nba
# 依照 P43
# 老人 Nab
# 的 DE
# 指示 Nac
# 去 Dbab
# 做 VC31
# 村子 Nab
# 裡 Ncda
# 的 DE
# 山泉 Naa
# 成 VG2
# 了 Di
# 熱騰騰 VH11
# 的 DE
# 溫泉 Nab
# 身 Nab
# 上 Ncda
# 長 VH13
# 著 Di
# 斑塊 Naa
# 的 DE
# 病人 Nab
# 泡 VC33
# 在 P21
# 溫 VH16
# 的 DE
# 泉水 Naa
# 中 Ng
# 覺得 VK1
# 既 Caa[P1]
# 輕鬆 VH11
# 又 Caa[P2]
# 舒服 VH21
# 大家 Nhab
# 都 Dab
# 很 Dfa
# 感謝 VK1
# 大福 Nba
# 便 Dd
# 把 P07
# 這個 DM
# 溫泉 Nab
# 命名為 VG1
# 孝子泉 Nab
# 十一 Neu
# 給 VD1
# 堂弟 Nab
# 的 DE
# 一封 DM
# 信 Nab
# 親愛 VH11
# 的 DE
# 聖耀 Nba
# 堂弟 Nab
# 接到 VC2
# 你 Nhaa
# 的 DE
# 來信 Nab
# 才 Dd
# 知道 VK1
# 嬸嬸 Nab
# 被 P02
# 車子 Nab
# 撞傷 VC2
# 了 Ta
# 不 Dc
# 知道 VK1
# 嬸嬸 Nab
# 的 DE
# 傷勢 Nad
# 如何 VH11
# 我們 Nhaa
# 都 Dab
# 很 Dfa
# 擔心 VK1
# 希望 VK1
# 她 Nhaa
# 很 Dfa
# 快 VH13
# 就 Dd
# 會 Dbaa
# 康復 VH11
# 上 Nes
# 星期 Nac
# 老師 Nab
# 說 VE2
# 了 Di
# 一則 DM
# 孝行獎 Nab
# 的 DE
# 故事 Nac
# 讓 VL4
# 我們 Nhaa
# 非常 Dfa
# 感動 VH22
# 孝行獎 Nab
# 的 DE
# 得獎人 Nab
# 中 Ng
# 有 V_2
# 七十歲 DM
# 的 DE
# 老先生 Nab
# 也 Dbb
# 有 V_2
# 十二歲 DM
# 的 DE
# 小孩子 Nab
# 每一位 DM
# 得獎人 Nab
# 都 Dab
# 有 V_2
# 一段 DM
# 感人 VH11
# 的 DE
# 故事 Nac
# 其中 Nep
# 有 V_2
# 一個 DM
# 高中生 Nab
# 他 Nhaa
# 看起來 Dbc
# 很 Dfa
# 瘦弱 VH11
# 卻 Dbb
# 做 VC31
# 了 Di
# 許多 Neqa
# 令 VL4
# 人 Nab
# 欽佩 VJ2
# 的 DE
# 事 Nac
# 他 Nhaa
# 的 DE
# 父母 Naeb
# 雙眼 Naea
# 失明 VH11
# 靠著 P27
# 微薄 VH11
# 的 DE
# 救濟金 Naeb
# 生活 VA12
# 所以 Cbca
# 從 P19
# 小時候 Ndda
# 開始 Ng
# 他 Nhaa
# 就 Dd
# 扛起 VC2
# 了 Di
# 照顧 VC2
# 家人 Nab
# 的 DE
# 責任 Nac
# 他 Nhaa
# 經常 Dd
# 帶 VC32
# 著 Di
# 眼盲 VH11
# 的 DE
# 父母 Naeb
# 外出 VA11
# 工作 VA4
# 和 Caa
# 購買 VC31
# 東西 Nab
# 放學 VH11
# 回家 VA13
# 除了 P50
# 看顧 VC2
# 年幼 VH11
# 的 DE
# 弟弟 Nab
# 還 Dbb
# 要 Dbab
# 做 VC31
# 家事 Nad
# 直到 P18
# 夜深人靜 VH11
# 才 Dd
# 能 Dbab
# 做 VC31
# 學校 Ncb
# 的 DE
# 功課 Nac
# 他 Nhaa
# 雖然 Cbaa
# 每天 DM
# 很 Dfa
# 疲累 VH11
# 但是 Cbca
# 從不 Dd
# 抱怨 VE2
# 十幾年 DM
# 來 Ng
# 他 Nhaa
# 盡心 VH11
# 盡力 VH11
# 的 DE
# 照顧 VC2
# 父母 Naeb
# 和 Caa
# 弟弟 Nab
# 鄰居 Nab
# 和 Caa
# 朋友 Nab
# 都 Dab
# 讚美 VC2
# 他 Nhaa
# 說 VE2
# 他 Nhaa
# 乖巧 VH11
# 又 Caa
# 懂事 VH11
# 他 Nhaa
# 不僅 Cbbb
# 是 V_11
# 父母 Naeb
# 生活 Nad
# 中 Ng
# 的 DE
# 眼睛 Nab
# 和 Caa
# 雙手 Naea
# 更 Dfa
# 是 V_11
# 大家 Nhab
# 心目中 Ncc
# 的 DE
# 好 VH11
# 孩子 Nab
# 聽完 VC2
# 老師 Nab
# 講 VE2
# 的 DE
# 故事 Nac
# 我 Nhaa
# 的 DE
# 心 Nab
# 裡 Ncda
# 好 Dfa
# 感動 VH22
# 也 Dbb
# 很 Dfa
# 佩服 VJ2
# 他 Nhaa
# 的 DE
# 孝行 Nac
# 聖耀 Nba
# 堂弟 Nab
# 你 Nhaa
# 是否 Dj
# 也 Dbb
# 有 V_2
# 相同 VH11
# 的 DE
# 感受 Nad
# 呢 Tc
# 天氣 Nad
# 越來越 Dfa
# 涼 VH11
# 了 Ta
# 別 Dbab
# 忘 VK1
# 了 Di
# 也 Dbb
# 要 Dbab
# 好好 VH11
# 照顧 VC2
# 自己 Nhab
# 喔 Tc
# 祝 VE12
# 健康 VH11
# 快樂 VH21
# 堂哥 Nab
# 立宇 Nba
# 上 VA4
# 10月 Ndabc
# 5日 Ndabd
# 十二 Neu
# 詩選 Nab
# 憶 VK1
# 母 Nab
# 倪瑞璿 Nba
# 河 Nab
# 廣 VH11
# 難 VH11
# 航 VA11
# 莫 Dbab
# 我 Nhaa
# 過 VC1
# 未知 VJ2
# 安 VH11
# 否 Td
# 近 Dd
# 如何 VH11
# 暗中 Dh
# 時 Dd
# 滴 VC32
# 思親 VH21
# 淚 Naa
# 只 Daa
# 恐 Dbaa
# 思 VE2
# 兒 Nab
# 淚 Naa
# 更 Dfa
# 多 VH13
# 遊子吟 Nba
# 孟郊 Nba
# 慈母 Nab
# 手 Nab
# 中 Ncda
# 線 Nab
# 遊子 Nab
# 身 Nab
# 上 Ncda
# 衣 Nab
# 臨行 Nddc
# 密密 VH11
# 縫 VC2
# 意恐 VK1
# 遲遲 Dd
# 歸 VC1
# 誰 Nhb
# 言 VE2
# 寸 DM
# 草 Nab
# 心 Nab
# 報 VC2
# 得 DE
# 三 Neu
# 春 Ndabb
# 暉 Nad
# 十三 Neu
# 木匠 Nab
# 畫家 Nab
# 齊白石 Nba
# 民國 Ndaab
# 十一年 Ndaad
# 中 Nca
# 日 Nca
# 聯合 Nv1
# 畫展 Nac
# 一位 DM
# 名不見經傳 VH11
# 的 DE
# 中國 Nca
# 畫家 Nab
# 成為 VG2
# 大家 Nhab
# 注目 VB11
# 的 DE
# 焦點 Nac
# 當時 Ndabe
# 他 Nhaa
# 的 DE
# 作品 Nac
# 與 Caa
# 生活 Nad
# 情形 Nac
# 被 P02
# 拍成 VG1
# 了 Di
# 電影 Nac
# 接著 Dd
# 他 Nhaa
# 又 Dd
# 參加 VC2
# 巴黎 Nca
# 藝術 Nad
# 展覽會 Nac
# 成 VG2
# 了 Di
# 名聞 VI2
# 國際 Ncc
# 的 DE
# 大 VH13
# 畫家 Nab
# 他 Nhaa
# 就 Dd
# 是 V_11
# 生於 VJ1
# 清朝 Ndaab
# 末年 Nad
# 的 DE
# 齊白石 Nba
# 齊白石 Nba
# 是 V_11
# 一個 DM
# 農家 Ncb
# 子弟 Naeb
# 父親 Nab
# 想 VE2
# 教 VL4
# 他 Nhaa
# 種田 VA4
# 但 Cbca
# 他 Nhaa
# 身體 Nab
# 瘦弱 VH11
# 無法 Dbab
# 勝任 VJ2
# 只好 Dbb
# 送 VD1
# 他 Nhaa
# 去 Dbab
# 學 VC2
# 木工 Nab
# 先 Dd
# 做 VC31
# 一般 A
# 的 DE
# 桌子 Nab
# 椅子 Nab
# 後來 Nddb
# 改學 VC2
# 雕花 Nab
# 的 DE
# 細 VH13
# 木工 Nac
# 改變 VC2
# 一些 Neqa
# 新 VH11
# 花樣 Nac
# 因此 Cbca
# 名氣 Nad
# 漸漸 Dd
# 傳開 VH16
# 齊白石 Nba
# 在 P21
# 朋友 Nab
# 家 Ncb
# 見到 VE2
# 一本 DM
# 芥子園 Nba
# 畫譜 Nab
# 才 Dd
# 發現 VE2
# 自己 Nhab
# 過去 Ndda
# 畫 VC31
# 人 Nab
# 不是 Cbbb
# 頭 Nab
# 太 Dfa
# 大 VH13
# 就是 Cbcb
# 腳 Nab
# 太 Dfa
# 長 VH12
# 畫 VC31
# 花 Nab
# 不是 Cbbb
# 花 Nab
# 太 Dfa
# 肥 VH16
# 就是 Cbcb
# 葉 Nab
# 太 Dfa
# 瘦 VH13
# 向 P62
# 主人 Nab
# 借 VD2
# 了 Di
# 書 Nab
# 利用 VC2
# 晚上 Ndabe
# 將 P07
# 畫譜 Nab
# 上 Ncda
# 的 DE
# 畫 Nab
# 一幅 DM
# 一幅 DM
# 的 DE
# 勾畫 VC31
# 下來 Di
# 如此 VH11
# 他 Nhaa
# 的 DE
# 雕花 Nab
# 圖案 Nac
# 就 Dd
# 更 Dfa
# 富有 VJ3
# 變化 Nac
# 了 Ta
# 齊白石 Nba
# 學習 VC2
# 工筆 A
# 的 DE
# 花鳥畫 Nab
# 時 Ng
# 就 Dd
# 在 P21
# 家 Ncb
# 裡 Ncda
# 養 VC2
# 了 Di
# 許多 Neqa
# 蜻蜓 Nab
# 、 Caa
# 蝴蝶 Nab
# 、 Caa
# 蜜蜂 Nab
# 他 Nhaa
# 細心 VH11
# 觀察 VE2
# 牠們 Nhaa
# 的 DE
# 生活 Nad
# 動態 Nad
# 不斷 VH11
# 的 DE
# 練習 VC2
# 寫生 Nv4
# 據說 Dk
# 他 Nhaa
# 把 P07
# 蝗蟲 Nab
# 的 DE
# 寫生 Nv4
# 稿 Nab
# 放 VC33
# 在 P21
# 地 Naa
# 上 Ncda
# 可以 Dbab
# 引起 VC2
# 群 DM
# 雞 Nab
# 撲啄 Nv1
# 呢 Tc
# 除了 P50
# 畫畫 VA4
# 運用 VC2
# 在 P21
# 刻 VC33
# 印章 Nab
# 上 Ng
# 練習 VC2
# 刻印 Nv4
# 時 Ng
# 他 Nhaa
# 把 P07
# 印章 Nab
# 刻 VC33
# 了 Di
# 又 Dd
# 磨 VC2
# 磨 VC2
# 了 Di
# 又 Dd
# 刻 VC33
# 後來 Nddb
# 成 VG2
# 了 Di
# 刻印 VA4
# 的 DE
# 大師 Nab
# 齊白石 Nba
# 二十七歲 DM
# 才 Dd
# 開始 VL2
# 正式 VH11
# 學 VC2
# 畫 Nab
# 六十六歲 DM
# 時 Ng
# 他 Nhaa
# 到 VC1
# 北平 Nca
# 藝術 Nad
# 學院 Ncb
# 教書 VA4
# 將 P07
# 富有 VJ3
# 鄉土 Nad
# 氣息 Naa
# 的 DE
# 畫風 Nad
# 一個 DM
# 貧窮 VH11
# 的 DE
# 小 VH13
# 木匠 Nab
# 經過 VC1
# 不斷 VH11
# 的 DE
# 努力 Nv4
# 不斷 VH11
# 的 DE
# 上進 Nv4
# 終於 Dd
# 成 VG2
# 了 Di
# 名 Nac
# 留 VC33
# 畫史 Nac
# 、 Caa
# 聞名 VI2
# 中外 Ncb
# 的 DE
# 大 VH13
# 畫家 Nab
# 十四 Neu
# 四 Neu
# 時 Nad
# 都 Dab
# 是 V_11
# 讀書 Nv4
# 天 Nad
# 春天 Ndabb
# 讀 VC2
# 唐詩 Nac
# 床 Nab
# 前 Ncda
# 明月 Nab
# 光 Naa
# 疑 VK1
# 是 V_11
# 地 Naa
# 上 Ncda
# 霜 Naa
# 李白 Nba
# 清新 VH11
# 的 DE
# 詩 Nac
# 令 VL4
# 人 Nab
# 喜愛 VL1
# 鐵 Nab
# 杵 Nab
# 磨成 VG1
# 繡花針 Nab
# 的 DE
# 啟示 Nac
# 激發 VC31
# 他 Nhaa
# 努力 VH11
# 學習 VC2
# 創作 VC31
# 許多 Neqa
# 的 DE
# 詩歌 Nac
# 夏日 Ndabd
# 在 VC1
# 樹 Nab
# 下 Ncda
# 閱讀 VC2
# 牛頓 Nba
# 的 DE
# 傳記 Nac
# 由 Caa[P1]
# 蘋果 Nab
# 到 Caa[P2]
# 萬有引力 Nad
# 他 Nhaa
# 不斷 VH11
# 的 DE
# 實驗 VE2
# 不斷 VH11
# 的 DE
# 研究 VE2
# 使 VL4
# 科學 Nad
# 邁進 VC1
# 一大步 DM
# 秋天 Ndabb
# 的 DE
# 午後 Ndc
# 坐 VA12
# 在 P21
# 草地 Ncb
# 上 Ncda
# 看 VC2
# 書法家 Nab
# 懷素 Nba
# 的 DE
# 故事 Nac
# 他 Nhaa
# 揮著汗 VA4[+ASP]
# 頂 VC31
# 著 Di
# 風 Naa
# 在 P21
# 芭蕉 Nab
# 上 Ncda
# 辛勤 VH11
# 練字 VA4
# 成為 VG2
# 一 Neu
# 代 Nac
# 草書 Nad
# 大師 Nab
# 寒冬 Ndabb
# 的 DE
# 夜晚 Ndabe
# 在 P21
# 燈火 Naa
# 下 Ng
# 看 VC2
# 愛迪生 Nba
# 的 DE
# 發明 Nv1
# 事蹟 Nac
# 他 Nhaa
# 花 VC31
# 了 Di
# 十三個 DM
# 月 Ndabc
# 的 DE
# 時間 Nad
# 實驗 VE2
# 了 Di
# 一千六百種 DM
# 材料 Nab
# 發明 VC31
# 電燈 Nab
# 照亮 VC2
# 了 Di
# 世界 Ncb
# 只有 Dbb
# 不斷 VH11
# 的 DE
# 努力 VH11
# 學習 VC2
# 才 Dd
# 能 Dbab
# 增加 VH16
# 我們 Nhaa
# 的 DE
# 知識 Nac
# 開拓 VC31
# 我們 Nhaa
# 的 DE
# 視野 Nad
# 十五 Neu
# 光 Naa
# 之 DE
# 天使 Nab
# 在 P21
# 沒有 VJ3
# 色彩 Nad
# 、 Caa
# 沒有 VJ3
# 聲音 Nad
# 、 Caa
# 沒有 VJ3
# 亮光 Naa
# 的 DE
# 世界 Ncb
# 中 Ng
# 生活 VA12
# 是 V_11
# 一件 DM
# 痛苦 VH21
# 的 DE
# 事情 Nac
# 海倫凱勒 Nba
# 卻 Dbb
# 克服 VJ1
# 了 Di
# 它 Nhaa
# 海倫 Nba
# 一歲半 DM
# 時 Ng
# 變成 VG2
# 了 Di
# 不僅 Cbbb
# 不能 Dbab
# 聽 VE2
# 、 Caa
# 不能 Dbab
# 看 VC2
# 而且 Cbcb
# 無法 Dbab
# 說話 VA4
# 的 DE
# 多重 A
# 障礙 Nac
# 者 Nab
# 從此 Dd
# 海倫 Nba
# 的 DE
# 脾氣 Nad
# 變 VH11
# 得 DE
# 非常 Dfa
# 暴躁 VH11
# 行為 Nad
# 變 VH11
# 得 DE
# 非常 Dfa
# 任性 VH11
# 直到 P18
# 蘇利文 Nba
# 小姐 Nab
# 當 VG2
# 了 Di
# 她 Nhaa
# 的 DE
# 家庭 Nac
# 教師 Nab
# 用 P39
# 無比 VH11
# 的 DE
# 耐心 Nad
# 和 Caa
# 堅持 Nv3
# 才 Dd
# 慢慢 VH11
# 的 DE
# 改變 VC2
# 了 Di
# 海倫 Nba
# 的 DE
# 脾氣 Nad
# 蘇利文 Nba
# 小姐 Nab
# 以 P11
# 手指 Nab
# 代 VC2
# 筆 Nab
# 教 VC2
# 海倫 Nba
# 洋娃娃 Nab
# 、 Caa
# 坐下 Nv4
# 、 Caa
# 帽子 Nab
# 等 Cab
# 字 Nac
# 當 P16
# 教 VC2
# 她 Nhaa
# 水 Naa
# 字 Nac
# 時 Ng
# 同時 Ndabe
# 讓 VL4
# 海倫 Nba
# 摸到 VC2
# 冰冷 VH11
# 而 Caa
# 流動 VA11
# 的 DE
# 水 Naa
# 海倫 Nba
# 才 Dd
# 知道 VK1
# 每一樣 DM
# 東西 Nab
# 都 Dab
# 有 V_2
# 名字 Nac
# 她 Nhaa
# 開始 VL2
# 用心 VH11
# 的 DE
# 去 Dbab
# 認識 VJ1
# 這個 DM
# 世界 Ncb
# 海倫 Nba
# 利用 VC2
# 點字 Nv4
# 來 Dbab
# 看書 VA11
# 利用 VC2
# 手語 Nac
# 來 Dbab
# 表達 VC31
# 自己 Nhab
# 的 DE
# 意思 Nac
# 她 Nhaa
# 最 Dfa
# 大 VH13
# 的 DE
# 希望 Nac
# 是 V_11
# 進入 VC1
# 最 Dfa
# 好 VH11
# 的 DE
# 大學 Ncb
# 許多 Neqa
# 朋友 Nab
# 都 Dab
# 認為 VE2
# 是 V_11
# 不 Dc
# 可能 VH11
# 的 DE
# 事 Nac
# 蘇利文 Nba
# 小姐 Nab
# 陪 VC2
# 著 Di
# 海倫 Nba
# 不斷 VH11
# 的 DE
# 努力 VH11
# 用功 VH11
# 終於 Dd
# 使得 VL4
# 海倫 Nba
# 考進 VC1
# 了 Di
# 哈佛 Nba
# 大學 Ncb
# 不僅 Cbbb
# 美國人 Nab
# 大為 Dfa
# 震驚 VH22
# 甚至 Dbb
# 全 Neqa
# 世界 Ncb
# 的 DE
# 人 Nab
# 都 Dab
# 驚訝不已 VH11
# 海倫 Nba
# 畢業 VH11
# 後 Ng
# 到 VC1
# 各 Nes
# 地 Naa
# 演講 VA4
# 她 Nhaa
# 發覺到 VK1
# 只 Daa
# 用 VC2
# 手語 Nac
# 沒辦法 VI2
# 充分 VH11
# 表露 VC31
# 自己 Nhab
# 的 DE
# 心情 Nad
# 又 Dd
# 花 VC31
# 了 Di
# 三年 DM
# 的 DE
# 時間 Nad
# 學 VC2
# 說話 Nv4
# 表達 VC31
# 自己 Nhab
# 的 DE
# 意思 Nac
# 海倫 Nba
# 克服 VJ1
# 了 Di
# 許多 Neqa
# 的 DE
# 困難 Nac
# 以 P11
# 親身 Dh
# 的 DE
# 痛苦 VH21
# 經驗 Nac
# 鼓勵 VF2
# 不幸 VH11
# 的 DE
# 人 Nab
# 勇敢 VH11
# 的 DE
# 站起來 VA11
# 海倫 Nba
# 帶給 VD1
# 他們 Nhaa
# 光明 VH11
# 的 DE
# 希望 Nac
# 光 Naa
# 之 DE
# 天使 Nab
# 就 Dd
# 是 V_11
# 世人 Naeb
# 對 P31
# 她 Nhaa
# 的 DE
# 尊稱 Nad
# 十六 Neu
# 汽車 Nab
# 的 DE
# 聯想 Nac
# 五月 Ndabc
# 十五日 Ndabd
# 星期一 Ndabd
# 天氣 Nad
# 晴 VH11
# 跟 P63
# 平常 Nddc
# 一樣 VH11
# 早上 Ndabe
# 七點鐘 Ndabe
# 我 Nhaa
# 坐 VC2
# 爸爸 Nab
# 的 DE
# 車子 Nab
# 去 VC1
# 學校 Ncb
# 今天 Ndabd
# 馬路 Nab
# 上 Ncda
# 的 DE
# 車子 Nab
# 好多 VH11
# 我 Nhaa
# 覺得 VK1
# 馬路 Nab
# 變成 VG2
# 一條 DM
# 長長 VH11
# 的 DE
# 河流 Nab
# 而 Cbca
# 車子 Nab
# 就 Dd
# 像 VG2
# 一條條 Neqa
# 彩色 A
# 的 DE
# 魚 Nab
# 它們 Nhaa
# 在 P21
# 河 Nab
# 裡 Ncda
# 川流不息 VH11
# 的 DE
# 游 VA11
# 著 Di
# 真 Dbb
# 是 Dbaa
# 有趣 VH11
# 極了 Dfb
# 爸 Nab
# 汽車 Nab
# 是 Dbaa
# 誰 Nhb
# 發明 VC31
# 的 Ta
# 我 Nhaa
# 突然 Dd
# 想起 VE2
# 這個 DM
# 問題 Nac
# 便 Dd
# 把 P07
# 這個 DM
# 問題 Nac
# 當作 VG1
# 一個 DM
# 球 Nab
# 投給 VD1
# 了 Di
# 爸爸 Nab
# 想不到 Dk
# 爸爸 Nab
# 很 Dfa
# 快 VH13
# 的 DE
# 把 P07
# 球 Nab
# 丟還 VD1
# 給 P04
# 我 Nhaa
# 要 VE2
# 我 Nhaa
# 自己 Nhab
# 去 Dbab
# 找 VC2
# 資料 Nab
# 利用 VC2
# 午休 VH11
# 時間 Nad
# 我 Nhaa
# 到 VC1
# 圖書館 Ncb
# 看 VC2
# 了 Di
# 幾本 DM
# 跟 P63
# 車子 Nab
# 有關 VJ1
# 的 DE
# 書 Nab
# 我 Nhaa
# 才 Dd
# 發現到 VE2
# 人類 Naeb
# 是 Dbaa
# 多麼 Dfa
# 了不起 VH11
# 以前 Ndda
# 人們 Naeb
# 要 VE2
# 到 VC1
# 一個 DM
# 地方 Nab
# 必須 Dbab
# 靠 VJ1
# 兩隻 DM
# 腳 Nab
# 走路 VA11
# 非常 Dfa
# 的 DE
# 不 Dc
# 方便 VH15
# 因此 Cbca
# 有 Nes
# 人 Nab
# 一 Neu
# 輩子 Nac
# 都 Dab
# 沒 Dc
# 離開 VC2
# 過 Di
# 他 Nhaa
# 的 DE
# 家鄉 Ncb
# 人們 Naeb
# 一直 Dd
# 動著腦筋 VA4[+ASP]
# 想 VE2
# 利用 VC2
# 機器 Nab
# 代替 VC2
# 人力 Nad
# 於是 Cbca
# 發明 VC31
# 了 Di
# 輪子 Nab
# 使 VL4
# 整個 Neqa
# 世界 Ncb
# 都 Dab
# 滾動 VA11
# 起來 Di
# 了 Ta
# 牛車 Nab
# 、 Caa
# 馬車 Nab
# 、 Caa
# 蒸汽 Naa
# 火車 Nab
# 、 Caa
# 腳踏車 Nab
# 、 Caa
# 電車 Nab
# 陸陸續續 Dd
# 被 P02
# 製造出來 VB2
# 發明 VC31
# 汽車 Nab
# 了 Ta
# 汽車 Nab
# 可 Dbb
# 不 Dc
# 是 V_11
# 一個 DM
# 人 Nab
# 所 Dab
# 發明 VC31
# 的 Ta
# 而 Cbca
# 是 V_11
# 許多 Neqa
# 國家 Nac
# 、 Caa
# 許多 Neqa
# 人 Nab
# 經過 VC1
# 多年 DM
# 不斷 VH11
# 的 DE
# 研究 Nad
# 和 Caa
# 努力 Nv4
# 才 Dd
# 共同 A
# 製造 VC31
# 來 Ta
# 的 Ta
# 汽車 Nab
# 剛 Dd
# 出現 VH14
# 時 Ng
# 它 Nhaa
# 有 V_2
# 一個 DM
# 很 Dfa
# 奇怪 VH11
# 的 DE
# 名字 Nac
# 叫 VG1
# 無 VJ3
# 馬 Nab
# 的 DE
# 馬車 Nab
# 吃 VC31
# 過 Di
# 晚飯 Naa
# 爸爸 Nab
# 聽 VE2
# 了 Di
# 我 Nhaa
# 的 DE
# 報告 Nab
# 滿意 VK1
# 的 DE
# 點著頭 VA4[+ASP]
# 媽媽 Nab
# 卻 Dbb
# 提醒 VE12
# 我 Nhaa
# 汽車 Nab
# 的 DE
# 發明 Nv1
# 雖 Cbba
# 帶給 VD1
# 人們 Naeb
# 生活 Nad
# 上 Ng
# 很 Dfa
# 大 VH13
# 的 DE
# 方便 Nv4
# 也 Dbb
# 帶來 VC2
# 一些 Neqa
# 禍害 Nab
# 像 P55
# 觸目驚心 VH21
# 的 DE
# 車禍 Nac
# 日益 Dd
# 嚴重 VH11
# 的 DE
# 汙染 Nad
# 問題 Nac
# 媽媽 Nab
# 的 DE
# 話 Nac
# 使 VL4
# 我 Nhaa
# 的 DE
# 想像力 Nad
# 飛起來 VA11
# 了 Ta
# 如果 Cbaa
# 我 Nhaa
# 發明 VC31
# 一種 DM
# 低 VH13
# 汙染 Nad
# 、 Caa
# 零 Neu
# 車禍 Nac
# 的 DE
# 汽車 Nab
# 我 Nhaa
# 就 Dd
# 是 V_11
# 一個 DM
# 了不起 VH11
# 的 DE
# 發明家 Nab
# 了 Ta
# 十七 Neu
# 魯班 Nba
# 的 DE
# 故事 Nac
# 公輸班 Nba
# 是 V_11
# 春秋 Ndaab
# 時代 Nac
# 的 DE
# 魯國人 Nab
# 又 Dd
# 稱為 VG1
# 魯班 Nba
# 他 Nhaa
# 小 VH13
# 的 DE
# 時候 Nad
# 就 Dd
# 很 Dfa
# 喜歡 VK1
# 觀察 VE2
# 觀察 VE2
# 大人 Nab
# 煮飯 VA4
# 、 Caa
# 織布 VA4
# 、 Caa
# 蓋 VC33
# 房子 Nab
# 他 Nhaa
# 都 Dab
# 看 VC2
# 得 DE
# 很 Dfa
# 仔細 VH11
# 他 Nhaa
# 不僅 Cbbb
# 認真 VH11
# 的 DE
# 看 VC2
# 用心 VH11
# 的 DE
# 想 VE2
# 還 Dbb
# 做 VC31
# 一些 Neqa
# 精巧 VH11
# 有用 VH11
# 的 DE
# 東西 Nab
# 鄰居 Nab
# 都 Dab
# 稱讚 VC2
# 他 Nhaa
# 是 V_11
# 個 DM
# 巧 VH11
# 童 Nab
# 魯班 Nba
# 長大 VH11
# 了 Ta
# 當 VG2
# 一名 DM
# 木工 Nab
# 他 Nhaa
# 在 P21
# 木材 Naeb
# 上 Ncda
# 畫線 VA4
# 時 Ng
# 總是 Dd
# 自己 Nhab
# 拿 VC31
# 著 Di
# 線 Nab
# 的 DE
# 一 Neu
# 端 Ncda
# 請 VF2
# 母親 Nab
# 拿 VC31
# 著 Di
# 線 Nab
# 的 DE
# 另 Nes
# 一 Neu
# 端 Ncda
# 才 Dd
# 能 Dbab
# 畫出 VC31
# 線 Nab
# 來 Ta
# 他 Nhaa
# 做 VC31
# 了 Di
# 一個 DM
# 彎 VH11
# 鉤 Nab
# 只要 Cbaa
# 鉤 VC2
# 在 P21
# 木材 Naeb
# 上 Ncda
# 一個 DM
# 人 Nab
# 就 Dd
# 可以 Dbab
# 畫線 VA4
# 這個 DM
# 工具 Nab
# 就 Dd
# 是 V_11
# 墨斗 Nab
# 在 P21
# 刨 VC2
# 木 Nab
# 時 Ng
# 魯班 Nba
# 都 Dab
# 要 Dbab
# 請 VF2
# 他 Nhaa
# 的 DE
# 妻子 Nab
# 扶 VC2
# 著 Di
# 木材 Naeb
# 才 Dd
# 能 Dbab
# 完成 VC31
# 刨 VC2
# 木 Nab
# 的 DE
# 工作 Nac
# 有一次 DM
# 要 VE2
# 刨 VC2
# 木 Nab
# 時 Ng
# 他 Nhaa
# 便 Dd
# 放 VC33
# 了 Di
# 一塊 DM
# 短 VH13
# 木頭 Nab
# 頂住 VC2
# 木材 Naeb
# 一個 DM
# 人 Nab
# 就 Dd
# 可以 Dbab
# 刨 VC2
# 木 Nab
# 了 Ta
# 於是 Cbca
# 橛子 Nab
# 被 P02
# 發明 VC31
# 了 Di
# 魯班 Nba
# 帶 VC32
# 著 Di
# 學徒 Nab
# 上山 VA13
# 去 Dbab
# 伐木 VA4
# 一 Dd
# 不 Dc
# 小心 VK1
# 他 Nhaa
# 的 DE
# 手 Nab
# 被 P02
# 芒草 Nab
# 的 DE
# 葉子 Nab
# 割傷 VC2
# 了 Di
# 他 Nhaa
# 很 Dfa
# 仔細 VH11
# 的 DE
# 觀察 VE2
# 那片 DM
# 葉子 Nab
# 發現 VE2
# 這種 DM
# 葉緣 Ncb
# 的 DE
# 鋸齒 Nab
# 像 P55
# 刀子 Nab
# 一樣 VH11
# 鋒利 VH11
# 魯班 Nba
# 便 Dd
# 模仿 VC2
# 著 Di
# 芒草 Nab
# 的 DE
# 葉緣 Ncb
# 先 Dd
# 用 P39
# 竹片 Nab
# 做成 VG1
# 鋸齒 Nab
# 的 DE
# 樣子 Nac
# 在 P21
# 一棵 DM
# 小 VH13
# 樹幹 Nab
# 上 Ncda
# 鋸 VC2
# 著 Di
# 居然 Dbb
# 在 P21
# 樹幹 Nab
# 上 Ncda
# 留下 VC2
# 了 Di
# 一道 DM
# 深溝 Nab
# 他 Nhaa
# 更 Dfa
# 有 V_2
# 信心 Nad
# 了 Ta
# 他 Nhaa
# 把 P07
# 長 VH12
# 鐵片 Nab
# 打造成 VG1
# 鋸齒 Nab
# 的 DE
# 樣子 Nac
# 再 Dd
# 和 P35
# 學徒 Nab
# 各 Dab
# 抓住 VC2
# 長 VH13
# 鐵片 Nab
# 的 DE
# 一 Neu
# 端 Ncda
# 靠著 P27
# 樹幹 Nab
# 來來回回 VA11
# 的 DE
# 拉 VC2
# 著 Di
# 沒 VJ3
# 多久 Nddc
# 就 Dd
# 把 P07
# 一棵 DM
# 大 VH13
# 樹 Nab
# 鋸斷 VC2
# 了 Di
# 人們 Naeb
# 有 V_2
# 了 Di
# 鋸子 Nab
# 魯班 Nba
# 喜歡 VK1
# 觀察 VE2
# 並且 Cbcb
# 動手 VA4
# 去 Dbab
# 做 VC31
# 這種 DM
# 創造 VC31
# 與 Caa
# 發明 VC31
# 的 DE
# 精神 Nad
# 使 VL4
# 他 Nhaa
# 在 P21
# 兩千多年 DM
# 前 Ng
# 所 Dab
# 發明 VC31
# 的 DE
# 一些 Neqa
# 工具 Nab
# 一直 Dd
# 流傳 VK2
# 到 P61
# 今天 Ndabd
# 所以 Cbca
# 他 Nhaa
# 成為 VG2
# 我國 Ncb
# 古代 Ndda
# 手藝 Nac
# 精湛 VH11
# 的 DE
# 巧 VH11
# 匠 Nab
# 也 Dbb
# 為 P03
# 中國 Nca
# 歷史 Naeb
# 留下 VC2
# 永 Dd
# 不 Dc
# 褪色 VH11
# 的 DE
# 一頁 DM
# 十八 Neu
# 未來 Nddb
# 的 DE
# 生活 Nad
# 未來 Nddb
# 的 DE
# 生活 Nad
# 是 V_11
# 科技 Nac
# 的 DE
# 、 Caa
# 安全 VH11
# 的 DE
# 、 Caa
# 舒適 VH11
# 的 DE
# 這樣 VH11
# 的 DE
# 生活 Nad
# 可能 Dbaa
# 實現 VC2
# 嗎 Td
# 可能 VH11
# 的 Ta
# 因為 Cbaa
# 人類 Naeb
# 會 Dbaa
# 善用 VJ1
# 他們 Nhaa
# 的 DE
# 天賦 Nad
# 聰明 VH11
# 的 DE
# 頭腦 Nab
# 和 Caa
# 靈巧 VH11
# 的 DE
# 雙手 Naea
# 去 Dbab
# 創造 VC31
# 很多 Neqa
# 東西 Nab
# 使 VL4
# 我們 Nhaa
# 未來 Nddb
# 的 DE
# 生活 Nad
# 更 Dfa
# 美好 VH11
# 如果 Cbaa
# 創造 VC31
# 萬能 VH11
# 的 DE
# 機器人 Nab
# 那麼 Dk
# 人類 Naeb
# 未來 Nddb
# 的 DE
# 生活 Nad
# 會 Dbaa
# 更 Dfa
# 舒適 VH11
# 萬能 VH11
# 機器人 Nab
# 是 V_11
# 全 Neqa
# 家 Ncb
# 的 DE
# 好 VH11
# 幫手 Nab
# 幫 P37
# 媽媽 Nab
# 做 VC31
# 家事 Nad
# 幫 P37
# 爸爸 Nab
# 打 VC2
# 電腦 Nab
# 還 Dbb
# 陪 VC2
# 弟弟 Nab
# 玩耍 VA4
# 接送 VC2
# 姊姊 Nab
# 上下學 VA11
# 它 Nhaa
# 不僅 Cbbb
# 對 P31
# 主人 Nab
# 忠心 VH21
# 還 Dbb
# 全年 DM
# 無休 VH11
# 呢 Tc
# 如果 Cbaa
# 能 Dbab
# 發明 VC31
# 神奇 VH11
# 的 DE
# 守護神 Nac
# 那麼 Dk
# 人類 Naeb
# 未來 Nddb
# 的 DE
# 生活 Nad
# 會 Dbaa
# 更 Dfa
# 安全 VH11
# 神奇 VH11
# 的 DE
# 守護神 Nac
# 是 V_11
# 一個 DM
# 圓形 Nac
# 的 DE
# 小球 Nab
# 可 Dbab
# 掛 VC33
# 在 P21
# 人們 Naeb
# 的 DE
# 胸 Nab
# 前 Ncda
# 上街 VA13
# 迷路 VH11
# 了 Ta
# 或 Caa
# 走失 VH17
# 了 Ta
# 可以 Dbab
# 按 VC2
# 一下 DM
# 胸 Nab
# 前 Ncda
# 的 DE
# 小球 Nab
# 附近 Ncb
# 警察局 Ncb
# 的 DE
# 網路 Nac
# 上 Ncda
# 就 Dd
# 會 Dbaa
# 接受到 VC31
# 訊息 Nac
# 警察 Nab
# 人員 Nab
# 會 Dbaa
# 及時 Dd
# 趕過來 VA11
# 幫忙 VC2
# 遇到 VC2
# 歹徒 Nab
# 時 Ng
# 趕快 Dd
# 按 VC2
# 一下 DM
# 胸 Nab
# 前 Ncda
# 的 DE
# 小球 Nab
# 歹徒 Nab
# 的 DE
# 容貌 Nad
# 會 Dbaa
# 被 P02
# 輸送 VC32
# 到 P61
# 警察局 Ncb
# 的 DE
# 網路 Nac
# 上 Ng
# 警察 Nab
# 人員 Nab
# 會 Dbaa
# 以 P11
# 最 Dfa
# 快 VH13
# 的 DE
# 速度 Nad
# 趕到 VC1
# 現場 Ncb
# 再 Dbb
# 狡猾 VH11
# 的 DE
# 歹徒 Nab
# 也 Dbb
# 插翅難飛 VH11
# 了 Ta
# 如果 Cbaa
# 利用 VC2
# 科技 Nac
# 發明 VC31
# 一些 Neqa
# 東西 Nab
# 那麼 Dk
# 人類 Naeb
# 未來 Nddb
# 的 DE
# 生活 Nad
# 會 Dbaa
# 更 Dfa
# 方便 VH15
# 倘若 Cbaa
# 發明 VC31
# 空氣 Naa
# 調節器 Nab
# 早上 Ndabe
# 一 Dd
# 醒來 VH21
# 就 Dd
# 可以 Dbab
# 呼吸到 VC2
# 新鮮 VH11
# 的 DE
# 空氣 Naa
# 而且 Cbcb
# 空氣 Naa
# 的 DE
# 味道 Nad
# 可以 Dbab
# 隨 P58
# 個人 Nhab
# 喜好 Nv2
# 調整 VC2
# 像 P55
# 牛奶 Naa
# 、 Caa
# 草莓 Nab
# 、 Caa
# 花香 Nad
# 倘若 Cbaa
# 發明 VC31
# 自動 VH11
# 調整 VC2
# 溫度 Nad
# 的 DE
# 帳篷 Nab
# 出外 VA11
# 旅遊 VA4
# 只要 Cbaa
# 隨身 Dh
# 帶 VC32
# 著 Di
# 它 Nhaa
# 都 Dab
# 可以 Dbab
# 成為 VG2
# 露營 VA4
# 的 DE
# 好 VH11
# 地方 Nab
# 了 Ta
# 有 Nes
# 人 Nab
# 說 VE2
# 頭腦 Nab
# 是 V_11
# 思想家 Nab
# 雙手 Naea
# 是 V_11
# 實行家 Nab
# 也 Dbb
# 不錯 VH11
# 讓 VL4
# 它們 Nhaa
# 充分 VH11
# 合作 VH11
# 去 Dbab
# 創造 VC31
# 、 Caa
# 去 Dbab
# 發明 VC31
# 可以 Dbab
# 拓展 VC2
# 我們 Nhaa
# 的 DE
# 生活 Nad
# 領域 Nac
# 提高 VC2
# 我們 Nhaa
# 的 DE
# 生活 Nad
# 品質 Nad
# 使 VL4
# 未來 Nddb
# 的 DE
# 生活 Nad
# 美 VH11
# 夢 Nac
# 成真 VH11
# 成長 VH12
# 的 DE
# 喜悅 Nv4
# 星期六 Ndabd
# 下午 Ndabe
# 我 Nhaa
# 在 VC1
# 寫 VC33
# 功課 Nac
# 時 Ng
# 哥哥 Nab
# 走過來 VA11
# 愁眉苦臉 VH11
# 的 DE
# 說 VE2
# 妹 Nab
# 這個 DM
# 月 Ndabc
# 量 VC2
# 身高 Nad
# 我 Nhaa
# 居然 Dbb
# 沒 Dc
# 長高 VH12
# 哥 Nab
# 你 Nhaa
# 大 VH13
# 我 Nhaa
# 三歲 DM
# 已經 Dd
# 高出 VH13
# 我 Nhaa
# 一個 DM
# 頭 Nab
# 了 Ta
# 我 Nhaa
# 還 Dbb
# 比不上 VJ1
# 我 Nhaa
# 班 Nac
# 上 Ncda
# 的 DE
# 阿泰 Nba
# 他 Nhaa
# 不僅 Cbbb
# 長 VH13
# 得 DE
# 高 VH13
# 、 Caa
# 長 VH13
# 得 DE
# 壯 VH17
# 還 Dbb
# 長出 VJ3
# 了 Di
# 小 VH13
# 鬍子 Naa
# 就 Dd
# 像 VG2
# 漫畫書 Nab
# 中 Ng
# 的 DE
# 翩翩 VH11
# 美 VH11
# 少年 Nab
# 你 Nhaa
# 班 Nac
# 上 Ncda
# 已經 Dd
# 有 Nes
# 人 Nab
# 長 VH13
# 鬍子 Naa
# 啦 Tc
# 這時 Ndda
# 媽媽 Nab
# 回來 VA11
# 了 Di
# 她 Nhaa
# 聽見 VE2
# 我們 Nhaa
# 的 DE
# 談話 Naeb
# 覺得 VK1
# 很 Dfa
# 有趣 VH11
# 摟 VC2
# 著 Di
# 我們 Nhaa
# 說 VE2
# 長大 VH11
# 了 Ta
# 生理 Nad
# 上 Ng
# 、 Caa
# 心理 Nad
# 上 Ng
# 都 Dab
# 會 Dbaa
# 有 V_2
# 變化 Nac
# 的 Ta
# 你們 Nhaa
# 想 VE2
# 知道 VK1
# 身體 Nab
# 的 DE
# 變化 Nac
# 嗎 Td
# 社教館 Nca
# 正好 Daa
# 有 V_2
# 一個 DM
# 認識 VJ1
# 身體 Nab
# 的 DE
# 展覽 Nv1
# 明天 Ndabd
# 我們 Nhaa
# 一起 Dh
# 去 Dbab
# 參觀 VC2
# 探索 VE2
# 一下 Nddc
# 青春期 Nad
# 的 DE
# 身體 Nab
# 變化 Nac
# 第二天 DM
# 我們 Nhaa
# 一家人 Naea
# 到 VC1
# 社教館 Nca
# 去 Ta
# 看到 VE2
# 展覽區 Ncb
# 分為 VG1
# 幼兒區 Ncb
# 、 Caa
# 青春區 Ncb
# 和 Caa
# 中老年區 Ncb
# 我們 Nhaa
# 直接 VH11
# 到 VC1
# 青春區 Ncb
# 參觀 VC2
# 這 Nep
# 是 V_11
# 多媒體 Nab
# 的 DE
# 展覽 Nv1
# 有 V_2
# 聲光 Nad
# 也 Dbb
# 有 V_2
# 活動 Nac
# 一面 DM
# 牆 Nab
# 上 Ncda
# 掛 VC33
# 著 Di
# 各式 DM
# 圖片 Nab
# 和 Caa
# 照片 Nab
# 另一面 DM
# 有 V_2
# 電影 Nac
# 還 Dbb
# 有 V_2
# 電腦 Nab
# 人體 Nab
# 分析 Nv1
# 圖 Nab
# 我 Nhaa
# 一面 Dd
# 看 VC2
# 著 Di
# 圖片 Nab
# 一面 Dd
# 讀 VC2
# 著 Di
# 文字 Nac
# 對 P31
# 青春期 Nad
# 的 DE
# 男生 Nab
# 、 Caa
# 女生 Nab
# 身體 Nab
# 的 DE
# 變化 Nac
# 有 V_2
# 了 Di
# 初步 A
# 的 DE
# 認識 Nv3
# 也 Dd
# 覺得 VK1
# 身體 Nab
# 的 DE
# 成長 Nv4
# 是 Dbaa
# 自然 VH11
# 而 Caa
# 神祕 VH11
# 的 Ta
# 而且 Cbcb
# 知道 VK1
# 再 Dd
# 過 VC1
# 幾年 DM
# 我 Nhaa
# 就 Dd
# 可以 Dbab
# 長高 VH12
# 十公分 DM
# 變成 VG2
# 亭亭玉立 VH11
# 的 DE
# 美 VH11
# 少女 Nab
# 了 Ta
# 回家 VA13
# 的 DE
# 路 Nab
# 上 Ncda
# 我 Nhaa
# 想起 VE2
# 好友 Nab
# 容玉 Nba
# 她 Nhaa
# 對 P31
# 自己 Nhab
# 的 DE
# 身體 Nab
# 也 Dbb
# 有 V_2
# 一些 Neqa
# 好奇 Nv4
# 和 Caa
# 不解 Nv3
# 我 Nhaa
# 希望 VK1
# 把 P07
# 這個 DM
# 訊息 Nac
# 告訴 VE12
# 她 Nhaa
# 於是 Cbca
# 我 Nhaa
# 迫不及待 Dd
# 的 DE
# 奔向 VC1
# 她 Nhaa
# 家 Ncb
# 結果 Dk
# 她 Nhaa
# 去 VC1
# 舅舅 Nab
# 家 Ncb
# 了 Ta
# 因此 Cbca
# 我 Nhaa
# 留 VC33
# 了 Di
# 一張 DM
# 便條 Nab
# 給 VD1
# 她 Nhaa
# 容玉 Nba
# 早上 Ndabe
# 我們 Nhaa
# 全 Neqa
# 家 Ncb
# 去 VC1
# 社教館 Nca
# 參觀 VC2
# 了 Di
# 認識 VJ1
# 身體 Nab
# 的 DE
# 多媒體 Nab
# 展覽 Nv1
# 我 Nhaa
# 覺得 VK1
# 獲益良多 VH11
# 希望 VK1
# 妳 Nhaa
# 能 Dbab
# 抽空 Dh
# 去 Dbab
# 看看 VC2
# 讓 VL4
# 我們 Nhaa
# 一起 Dh
# 分享 VJ1
# 成長 VH12
# 的 DE
# 喜悅 Nv4
# 晴芳 Nba
# 上 VA4
# 二月 Ndabc
# 二十日 Ndabd
# 山豬 Nab
# 的 DE
# 尾巴 Nab
# 捲起來 VB12
# 了 Di
# 在 P21
# 一座 DM
# 廣大 VH11
# 的 DE
# 森林 Nab
# 裡 Ncda
# 住 VC1
# 了 Di
# 許多 Neqa
# 動物 Nab
# 其中 Nep
# 有 V_2
# 一隻 DM
# 山豬 Nab
# 全 Neqa
# 身 Nab
# 黑黑 VH11
# 的 Ta
# 樣子 Nac
# 笨笨 VH11
# 的 Ta
# 常常 Dd
# 受到 VJ3
# 一些 Neqa
# 動物 Nab
# 的 DE
# 嘲笑 Nv1
# 看到 VE2
# 山豬 Nab
# 走過來 VA11
# 枝頭 Ncc
# 上 Ncda
# 的 DE
# 小鳥 Nab
# 總是 Dd
# 吱吱喳喳 VA4
# 的 DE
# 叫 VE2
# 山豬 Nab
# 長 VH13
# 得 DE
# 黑 VH11
# 黑 VH11
# 又 Caa
# 黑 VH11
# 好 Dfa
# 像 VG2
# 垃圾堆 Nab
# 看 VC2
# 了 Di
# 會 Dbaa
# 倒楣 VH11
# 草地 Ncb
# 上 Ncda
# 的 DE
# 兔子 Nab
# 也 Dbb
# 會 Dbaa
# 叫 VE2
# 著 Di
# 山豬 Nab
# 嘴巴 Nab
# 大 VH13
# 大 VH13
# 又 Caa
# 大 VH13
# 兩隻 DM
# 大 VH13
# 獠牙 Nab
# 看 VC2
# 了 Di
# 好 Dfa
# 害怕 VK1
# 山豬 Nab
# 聽 VE2
# 了 Di
# 好 Dfa
# 難過 VK1
# 他 Nhaa
# 不 Dc
# 喜歡 VK1
# 身 Nab
# 上 Ncda
# 的 DE
# 黑 VH11
# 毛 Nab
# 冬天 Ndabb
# 過 VC1
# 了 Di
# 春神 Nab
# 把 P07
# 森林 Nab
# 變 VG1
# 得 DE
# 五顏六色 Naea
# 、 Caa
# 多彩多姿 VH11
# 獨自 Dh
# 走 VA11
# 在 P21
# 森林 Nab
# 裡 Ncda
# 的 DE
# 山豬 Nab
# 也 Dbb
# 希望 VK1
# 春神 Nab
# 把 P07
# 他 Nhaa
# 變 VG1
# 得 DE
# 像 P55
# 獅子 Nab
# 一樣 VH11
# 的 DE
# 雄壯 VH11
# 山豬 Nab
# 正 Dd
# 想 VE2
# 得 DE
# 開心 VH21
# 的 DE
# 時候 Nad
# 忽然 Dd
# 傳來 VC31
# 了 Di
# 喊 VE2
# 救命 VA4
# 的 DE
# 聲音 Nad
# 山豬 Nab
# 趕緊 Dd
# 循 VC2
# 著 Di
# 聲音 Nad
# 跑過去 VA11
# 在 P21
# 一棵 DM
# 大 VH13
# 樹 Nab
# 下 Ng
# 看到 VE2
# 一隻 DM
# 小 VH13
# 鹿 Nab
# 中 VJ3
# 了 Di
# 獵人 Nab
# 的 DE
# 陷阱 Nab
# 被 P02
# 一張 DM
# 網子 Nab
# 網住 VC2
# 了 Di
# 小 VH13
# 鹿 Nab
# 很 Dfa
# 害怕 VK1
# 不停 Dd
# 的 DE
# 叫喊 VA4
# 著 Di
# 山豬 Nab
# 連忙 Dd
# 用 P39
# 他 Nhaa
# 尖利 VH11
# 的 DE
# 獠牙 Nab
# 去 Dbab
# 撥開 VC2
# 網子 Nab
# 撥 VC2
# 呀 Tc
# 撥 VC2
# 的 Ta
# 終於 Dd
# 把 P07
# 網子 Nab
# 弄破 VC2
# 了 Di
# 救出 VC2
# 了 Di
# 小 VH13
# 鹿 Nab
# 小 VH13
# 鹿 Nab
# 一再 Dd
# 的 DE
# 感謝 VK1
# 山豬 Nab
# 從此 Dd
# 以後 Ng
# 小鳥 Nab
# 看到 VE2
# 山豬 Nab
# 走過來 VA11
# 他們 Nhaa
# 會 Dbaa
# 大聲 VH11
# 的 DE
# 唱 VC2
# 山豬 Nab
# 山豬 Nab
# 好 Dfa
# 雄壯 VH11
# 全 Neqa
# 身 Nab
# 黑 VH11
# 毛 Nab
# 會 Dbaa
# 發亮 VH11
# 兩隻 DM
# 獠牙 Nab
# 有 V_2
# 力量 Nad
# 真 Dbb
# 是 V_11
# 我們 Nhaa
# 的 DE
# 偶像 Nab
# 山豬 Nab
# 聽 VE2
# 了 Di
# 不僅 Cbbb
# 笑開 VC2
# 了 Di
# 大 VH13
# 嘴 Nab
# 連 Cbba
# 尾巴 Nab
# 都 Dab
# 捲起來 VB12
# 了 Di
# 日記 Nab
# 一則 DM
# 魔鏡 Nab
# 會 Dbaa
# 說話 VA4
# 三月 Ndabc
# 十日 Ndabd
# 星期二 Ndabd
# 今天 Ndabd
# 上 VC1
# 說話課 Nac
# 時 Ng
# 老師 Nab
# 教 VC2
# 我們 Nhaa
# 玩 VC2
# 魔鏡 Nab
# 會 Dbaa
# 說話 VA4
# 的 DE
# 遊戲 Nac
# 我們 Nhaa
# 高興 VK1
# 得 DE
# 拍手 VA4
# 歡呼 VE2
# 音樂聲 Nad
# 響起 VH14
# 遊戲 Nac
# 就 Dd
# 開始 VH11
# 了 Ta
# 每個 DM
# 同學 Nab
# 的 DE
# 手 Nab
# 上 Ncda
# 都 Dab
# 拿 VC31
# 著 Di
# 紙 Nab
# 做 VC31
# 的 DE
# 半面 DM
# 鏡子 Nab
# 踩 VC2
# 著 Di
# 輕快 VH11
# 的 DE
# 腳步 Nad
# 在 P21
# 同學 Nab
# 中 Ng
# 尋找 VC2
# 另外 Nes
# 的 DE
# 半面 DM
# 鏡子 Nab
# 只要 Cbaa
# 找到 VC2
# 它 Nhaa
# 跟 P63
# 自己 Nhab
# 手 Nab
# 上 Ncda
# 的 DE
# 半面 DM
# 鏡子 Nab
# 合成 VG1
# 一個 DM
# 圓 Nac
# 魔鏡 Nab
# 就 Dd
# 會 Dbaa
# 出現 VH14
# 了 Ta
# 我 Nhaa
# 手 Nab
# 上 Ncda
# 拿 VC31
# 的 DE
# 半面 DM
# 鏡子 Nab
# 跟 P63
# 小山 Nba
# 手 Nab
# 上 Ncda
# 拿 VC31
# 的 DE
# 半面 DM
# 鏡子 Nab
# 合成 VG1
# 一個 DM
# 圓圓 VH11
# 的 DE
# 魔鏡 Nab
# 了 Ta
# 我們 Nhaa
# 高興 VK1
# 得 DE
# 抱 VC2
# 在一起 VH11
# 做出 VC31
# 勝利 VH11
# 的 DE
# 姿勢 Nac
# 然後 Dd
# 商量 VE2
# 要 Dbab
# 讓 VL4
# 魔鏡 Nab
# 說 VE2
# 些 DM
# 什麼 Nep
# 話 Nac
# 輪到 VL3
# 我 Nhaa
# 和 Caa
# 小山 Nba
# 拿 VC31
# 著 Di
# 魔鏡 Nab
# 上臺 VA13
# 小山 Nba
# 問 VE11
# 魔鏡 Nab
# 魔鏡 Nab
# 啊 Tc
# 魔鏡 Nab
# 誰 Nhb
# 是 V_11
# 班 Nac
# 上 Ncda
# 的 DE
# 超人 Nab
# 我 Nhaa
# 故意 VL1
# 壓低 VC2
# 聲音 Nad
# 裝成 VG2
# 老婆婆 Nab
# 的 DE
# 聲音 Nad
# 回答 VE12
# 是 V_11
# 小山 Nba
# 小山 Nba
# 長 VH13
# 得 DE
# 壯 VH11
# 跑 VA11
# 得 DE
# 快 VH13
# 又 Dd
# 熱心 VJ1
# 助人 Nv4
# 他 Nhaa
# 當 VG2
# 了 Di
# 超人 Nab
# 之後 Ng
# 班 Nac
# 上 Ncda
# 一年 DM
# 四 Neu
# 季 Ndabf
# 都 Dab
# 平安 VH11
# 魔鏡 Nab
# 說 VE2
# 的 DE
# 話 Nac
# 引起 VC2
# 同學 Nab
# 的 DE
# 共鳴 Nad
# 臺 Nab
# 下 Ncda
# 響起 VH14
# 如雷 VH11
# 的 DE
# 掌聲 Nad
# 想 VE2
# 當 VG2
# 超人 Nab
# 的 DE
# 小山 Nba
# 咧開 VC2
# 嘴 Nab
# 笑 VA4
# 還 Dbb
# 做出 VC31
# 超人 Nab
# 要 Dbab
# 飛行 VA11
# 的 DE
# 模樣 Nac
# 接下來 Dd
# 是 Dbaa
# 我 Nhaa
# 問 VE11
# 魔鏡 Nab
# 誰 Nhb
# 是 V_11
# 班 Nac
# 上 Ncda
# 的 DE
# 英雄 Nab
# 小山 Nba
# 裝成 VG2
# 老婆婆 Nab
# 的 DE
# 聲音 Nad
# 回答 VE12
# 是 V_11
# 阿智 Nba
# 自從 P12
# 他 Nhaa
# 找到 VC2
# 今日事今日畢 Nba
# 的 DE
# 寶劍 Nab
# 之後 Ng
# 終於 Dd
# 把 P07
# 那隻 DM
# 名叫 VG2
# 拖拖拉拉 Nba
# 的 DE
# 怪物 Nab
# 除掉 VC2
# 使 VL4
# 阿智 Nba
# 變 VH11
# 得 DE
# 勤快 VH11
# 而且 Cbcb
# 功課 Nac
# 也 Dbb
# 進步 VH11
# 了 Ta
# 獲得 VJ3
# 許多 Neqa
# 同學 Nab
# 的 DE
# 支持 Nv1
# 大家 Nhab
# 看看 VC2
# 我 Nhaa
# 給 VD1
# 我 Nhaa
# 讚美 VC2
# 的 DE
# 掌聲 Nad
# 玩 VC2
# 了 Di
# 這個 DM
# 遊戲 Nac
# 我 Nhaa
# 認識 VJ1
# 了 Di
# 更多 Neqa
# 同學 Nab
# 的 DE
# 優點 Nac
# 今天 Ndabd
# 是 V_11
# 充實 VH16
# 而 Caa
# 快樂 VH21
# 的 DE
# 一天 DM
# 感恩 VI1
# 的 DE
# 日子 Nac
# 在 P21
# 美國 Nca
# 東部 Ncdb
# 十一月 Ndabc
# 的 DE
# 天空 Ncb
# 飄 VA11
# 著 Di
# 細細 VH11
# 的 DE
# 白雪 Naa
# 屋 Nab
# 裡 Ncda
# 的 DE
# 老約翰 Nba
# 夫婦 Naeb
# 正 Dd
# 歡歡喜喜 VH21
# 的 DE
# 忙著 VL2
# 他們 Nhaa
# 準備 VC2
# 了 Di
# 香噴噴 VH11
# 的 DE
# 烤 Nv1
# 火雞 Nab
# 、 Caa
# 南瓜派 Nab
# 還 Dbb
# 有 V_2
# 各式各樣 A
# 美味 VH11
# 的 DE
# 點心 Naa
# 等待 VK2
# 與 P35
# 家人 Nab
# 共 Dh
# 度 VC1
# 美好 VH11
# 的 DE
# 感恩節 Ndabd
# 從 P19
# 各 Nes
# 地 Ncb
# 回來 VA11
# 的 DE
# 孩子 Nab
# 們 Naea
# 和 P35
# 老約翰 Nba
# 夫婦 Naeb
# 圍坐 VA12
# 在 P21
# 桌 Nab
# 邊 Ncda
# 在 P21
# 溫暖 VH16
# 的 DE
# 燈光 Naa
# 下 Ng
# 他們 Nhaa
# 先 Dd
# 感謝 VK1
# 上天 Nad
# 的 DE
# 恩典 Nad
# 然後 Dd
# 吃 VC31
# 著 Di
# 豐盛 VH11
# 的 DE
# 火雞 Nab
# 大餐 Nac
# 全 Neqa
# 家 Ncb
# 大小 Nad
# 有說有笑 VA4
# 吃完 VC31
# 飯 Nab
# 大家 Nhab
# 圍 VC2
# 著 Di
# 八十多歲 DM
# 的 DE
# 老爺爺 Nab
# 聽 VE2
# 他 Nhaa
# 說 VE2
# 感恩節 Ndabd
# 的 DE
# 故事 Nac
# 三百多年 DM
# 前 Ng
# 有 V_2
# 一百多名 DM
# 英國人 Nab
# 搭乘 VC2
# 五月花號 Nba
# 木船 Nab
# 越過 VC1
# 大西洋 Nca
# 尋找 VC2
# 新 VH11
# 的 DE
# 天地 Naeb
# 他們 Nhaa
# 經過 VC1
# 了 Di
# 千辛萬苦 Nad
# 到達 VC1
# 新大陸 Nca
# 當時 Ndabe
# 天氣 Nad
# 非常 Dfa
# 寒冷 VH11
# 又 Dd
# 缺少 VJ3
# 食物 Naa
# 餓死 VH16
# 了 Di
# 許多 Neqa
# 人 Nab
# 以 P11
# 勤奮 VH11
# 的 DE
# 雙手 Naea
# 堅強 VH11
# 的 DE
# 毅力 Nad
# 開始 VL2
# 了 Di
# 拓荒 VA4
# 的 DE
# 工作 Nac
# 第二年 DM
# 新 VH11
# 移民 Nab
# 們 Naea
# 所 Dab
# 種植 VC33
# 的 DE
# 玉米 Nab
# 和 Caa
# 穀物 Naeb
# 收成 VC2
# 了 Di
# 他們 Nhaa
# 忍不住 VL1
# 跪 VA12
# 在 P21
# 地 Naa
# 上 Ncda
# 捧 VC2
# 著 Di
# 豐收 VH11
# 的 DE
# 農作物 Naeb
# 開心 VH21
# 得 DE
# 互相 Dh
# 擁抱 VC2
# 相互 Dh
# 道賀 VB11
# 為了 P03
# 表達 VC31
# 內心 Nad
# 的 DE
# 喜悅 Nv4
# 他們 Nhaa
# 便 Dd
# 訂出 VC31
# 了 Di
# 感恩節 Ndabd
# 這個 DM
# 節日 Nac
# 來 Dbab
# 感謝 VK1
# 上天 Nad
# 和 Caa
# 大自然 Ncb
# 的 DE
# 恩賜 Nad
# 現在 Nddc
# 印地安人 Nab
# 和 Caa
# 新 VH11
# 移民 Nab
# 都 Dab
# 成 VG2
# 了 Di
# 美國人 Nab
# 他們 Nhaa
# 和平 VH11
# 的 DE
# 生活 VA12
# 在一起 VH11
# 每年 DM
# 的 DE
# 感恩節 Ndabd
# 所有 Neqa
# 的 DE
# 美國人 Nab
# 都 Dab
# 像 P55
# 老約翰 Nba
# 夫婦 Naeb
# 一樣 VH11
# 以 P11
# 最 Dfa
# 快樂 VH21
# 的 DE
# 心情 Nad
# 和 P35
# 親人 Nab
# 一同 Dh
# 歡度 VJ3
# 這個 DM
# 特別 VH11
# 的 DE
# 節日 Nac
# 歡樂 VH21
# 豐年祭 Nac
# 嗨 I
# 嗨咿 I
# 歌詠 VC2
# 著 Di
# 天地 Naeb
# 的 DE
# 偉大 Nv4
# 唱出 VC31
# 對 P31
# 自然 Nad
# 的 DE
# 熱愛 Nv2
# 看 VC2
# 七八月 Ndabc
# 亮麗 VH11
# 的 DE
# 陽光 Naa
# 下 Ng
# 高高 VH11
# 的 DE
# 穀堆 Nab
# 變成 VG2
# 金色 Nad
# 的 DE
# 小 VH13
# 山 Nab
# 輕快 VH11
# 的 DE
# 打穀機 Nab
# 開心 VH21
# 的 DE
# 為 P03
# 我們 Nhaa
# 伴奏 VA4
# 感謝 VK1
# 天 Ncb
# 感謝 VK1
# 地 Naa
# 感謝 VK1
# 神明 Nac
# 的 DE
# 賜福 Nv1
# 嘿 I
# 嘿唷 I
# 踏出 VC1
# 力量 Nad
# 和 Caa
# 信心 Nad
# 舞出 VC1
# 喜悅 Nv4
# 和 Caa
# 歡樂 Nv4
# 七八月 Ndabc
# 柔和 VH11
# 的 DE
# 月光 Nad
# 下 Ng
# 桶桶 Neqa
# 的 DE
# 美酒 Naa
# 變成 VG2
# 銀色 Nad
# 的 DE
# 瀑布 Nab
# 忙碌 VH11
# 的 DE
# 杵臼 Naeb
# 興奮 VH21
# 的 DE
# 為 P03
# 我們 Nhaa
# 鼓掌 VA4
# 感謝 VK1
# 山 Nab
# 感謝 VK1
# 水 Naa
# 感謝 VK1
# 祖先 Nab
# 的 DE
# 護佑 Nv1
# 不 Dc
# 一樣 VH11
# 的 DE
# 母親花 Nab
# 翻 VC2
# 一 Di
# 翻 VC2
# 日曆 Nab
# 母親節 Ndabd
# 快 Dd
# 到 VC1
# 了 Di
# 我們 Nhaa
# 計畫 VF1
# 著 Di
# 要 Dbab
# 送 VD1
# 什麼 Nep
# 禮物 Nab
# 給 P04
# 媽媽 Nab
# 整天 DM
# 注意 VK1
# 報紙 Nab
# 廣告 Nac
# 的 DE
# 姊姊 Nab
# 捧 VC2
# 著 Di
# 報紙 Nab
# 說 VE2
# 快 Dd
# 看 VC2
# 百貨公司 Ncb
# 的 DE
# 化妝品 Naa
# 專櫃 Ncb
# 正在 Dd
# 舉行 VC31
# 大 VH13
# 贈送 Nv1
# 買 VC31
# 一組 DM
# 就 Dd
# 送 VD1
# 化妝包 Nab
# 媽媽 Nab
# 一定 Dbaa
# 會 Dbaa
# 喜歡 VK1
# 這個 DM
# 禮物 Nab
# 哥哥 Nab
# 搖搖頭 VA4
# 說 VE2
# 媽媽 Nab
# 已經 Dd
# 夠 Dfa
# 雍容華貴 VH11
# 了 Ta
# 還 Dbb
# 送 VD1
# 什麼 Nep
# 化妝品 Naa
# 我 Nhaa
# 覺得 VK1
# 不如 Cbca
# 請 VF2
# 媽媽 Nab
# 吃 VC31
# 母親節 Ndabd
# 大餐 Nac
# 我 Nhaa
# 看 VE2
# 是 Dbaa
# 你 Nhaa
# 想 VE2
# 吃 VC31
# 吧 Tc
# 姊姊 Nab
# 一面 Dd
# 對 P31
# 哥哥 Nab
# 扮鬼臉 VA4
# 一面 Dd
# 拍拍 VC2
# 我 Nhaa
# 的 DE
# 肩膀 Nab
# 問 VE11
# 妳 Nhaa
# 說 VE2
# 送 VD1
# 什麼 Nep
# 好 VH11
# 呢 Tc
# 我 Nhaa
# 想 VE2
# 了 Di
# 一 Di
# 想 VE2
# 說 VE2
# 做 VC31
# 一束 DM
# 花 Nab
# 送給 VD1
# 媽媽 Nab
# 吧 Tc
# 哥哥 Nab
# 好奇 VH11
# 的 DE
# 睜大 VC2
# 眼睛 Nab
# 問 VE11
# 做 VC31
# 花 Nab
# 做 VC31
# 什麼 Nep
# 花 Nab
# 康乃馨 Nab
# 嗎 Td
# 不 Dc
# 是 V_11
# 老師 Nab
# 告訴 VE12
# 過 Di
# 我們 Nhaa
# 中國 Nca
# 的 DE
# 母親花 Nab
# 是 V_11
# 萱草 Nab
# 萱草 Nab
# 開出 VC31
# 橘黃色 Nad
# 的 DE
# 花 Nab
# 像 P55
# 溫暖 VH16
# 的 DE
# 陽光 Naa
# 可以 Dbab
# 讓 VL4
# 人 Nab
# 忘掉 VK1
# 煩惱 Nad
# 所以 Cbca
# 也 Dbb
# 叫 VG1
# 忘憂草 Nab
# 今年 Ndaba
# 我們 Nhaa
# 就 Dd
# 親手 Dh
# 做 VC31
# 一束 DM
# 不 Dc
# 一樣 VH11
# 的 DE
# 母親花 Nab
# 當作 VG1
# 禮物 Nab
# 既 Cbba
# 省錢 VH11
# 又 Dd
# 能 Dbab
# 表達 VC31
# 我們 Nhaa
# 的 DE
# 心意 Nad
# 不 Dc
# 是 Dbaa
# 很 Dfa
# 好 VH11
# 嗎 Td
# 姊姊 Nab
# 聽 VE2
# 了 Di
# 我 Nhaa
# 的 DE
# 話 Nac
# 笑咪咪 VH11
# 的 DE
# 直 Dh
# 點頭 VA4
# 說 VE2
# 送 VD1
# 忘憂草 Nab
# 好 VH11
# 啊 Tc
# 這個 DM
# 名字 Nac
# 真 Dbb
# 有意思 VH11
# 媽媽 Nab
# 平時 Nddc
# 擔憂 VK1
# 的 DE
# 事 Nac
# 太多 VH11
# 了 Ta
# 如果 Cbaa
# 看 VC2
# 著 Di
# 忘憂草 Nab
# 能 Dbab
# 忘記 VK1
# 憂愁 VK1
# 的 DE
# 事 Nac
# 每天 DM
# 開開心心 VH21
# 的 Ta
# 那 Nep
# 就 Dd
# 太 Dfa
# 好 VH11
# 了 Ta
# 商量好 VE2
# 了 Di
# 之後 Ng
# 我們 Nhaa
# 決定 VE2
# 合力 Dh
# 做 VC31
# 一大束 DM
# 忘憂草 Nab
# 送給 VD1
# 親愛 VH11
# 的 DE
# 媽媽 Nab
# 希望 VK1
# 母親節 Ndabd
# 那天 DM
# 媽媽 Nab
# 看到 VE2
# 這份 DM
# 禮物 Nab
# 能 Dbab
# 笑 VA4
# 得 DE
# 像 P55
# 盛開 VH11
# 的 DE
# 母親花 Nab
# 一樣 VH11
# 美麗 VH11
# 柯 Nbc
# 媽媽 Nab
# 的 DE
# 故事 Nac
# 柯 Nbc
# 媽媽 Nab
# 是 V_11
# 一個 DM
# 平凡 VH11
# 的 DE
# 家庭 Nac
# 主婦 Nab
# 與 P35
# 家人 Nab
# 過 VC1
# 著 Di
# 幸福 VH11
# 的 DE
# 日子 Nac
# 她 Nhaa
# 就讀 VC1
# 研究所 Ncb
# 的 DE
# 兒子 Nab
# 聰明 VH11
# 好學 VH11
# 前途 Nad
# 充滿 VJ3
# 了 Di
# 希望 Nac
# 一場 DM
# 車禍 Nac
# 奪走 VC31
# 了 Di
# 她 Nhaa
# 兒子 Nab
# 寶貴 VH11
# 的 DE
# 生命 Nac
# 柯 Nbc
# 媽媽 Nab
# 受到 VJ3
# 很 Dfa
# 大 VH13
# 的 DE
# 打擊 Nac
# 每天 DM
# 以 P11
# 淚 Naa
# 洗面 VA4
# 車禍 Nac
# 發生 VJ1
# 後 Ng
# 沒有 Nes
# 人 Nab
# 幫助 VC2
# 柯 Nbc
# 媽媽 Nab
# 解決 VC2
# 問題 Nac
# 她 Nhaa
# 找 VC2
# 司機 Nab
# 理論 VE2
# 那個 DM
# 司機 Nab
# 不僅 Cbbb
# 沒有 VJ3
# 一絲 DM
# 悔意 Nad
# 還 Dbb
# 不屑 VL2
# 的 DE
# 丟下 VC31
# 一句 DM
# 話 Nac
# 說 VE2
# 壓死 VC2
# 一個 DM
# 人 Nab
# 算 VG2
# 什麼 Nep
# 柯 Nbc
# 媽媽 Nab
# 聽 VE2
# 了 Di
# 非常 Dfa
# 憤怒 VH21
# 想不到 Dk
# 自己 Nhab
# 兒子 Nab
# 的 DE
# 生命 Nac
# 竟然 Dbb
# 是 Dbaa
# 那麼 Dh
# 卑微 VH11
# 她 Nhaa
# 認為 VE2
# 應該 Dbab
# 為 P03
# 兒子 Nab
# 與 Caa
# 社會 Nac
# 找回 VC2
# 一些 Neqa
# 正義 Nad
# 她 Nhaa
# 化 VG1
# 悲憤 Nv4
# 為 P02
# 力量 Nad
# 到處 Dg
# 奔走 VA11
# 請願 VA4
# 希望 VK1
# 引起 VC2
# 社會 Nac
# 各界 Naea
# 的 DE
# 重視 Nv3
# 柯 Nbc
# 媽媽 Nab
# 在 P21
# 請願 VA4
# 的 DE
# 過程 Nac
# 中 Ng
# 發現 VE2
# 有 V_2
# 很多 Neqa
# 車禍 Nac
# 受難 VH11
# 者 Nab
# 的 DE
# 家屬 Nab
# 因為 Cbaa
# 得不到 VJ1[+NEG]
# 關懷 Nv2
# 與 Caa
# 賠償 Naeb
# 生活 Nad
# 陷入 VC1
# 了 Di
# 困境 Nac
# 柯 Nbc
# 媽媽 Nab
# 決定 VE2
# 幫助 VC2
# 這些 Neqa
# 不幸 VH11
# 的 DE
# 人 Nab
# 一群 DM
# 人 Nab
# 共同 A
# 努力 VH11
# 轉化成 VG1
# 關懷 VJ2
# 社會 Nac
# 的 DE
# 大愛 Nad
# 推動 VC2
# 強制 VF2
# 汽車 Nab
# 責任險 Nac
# 的 DE
# 法案 Nac
# 希望 VK1
# 由 P06
# 法律 Nac
# 來 Dbab
# 保障 VC2
# 車禍 Nac
# 受難 VH11
# 者 Nab
# 的 DE
# 家屬 Nab
# 在 P21
# 爭取 VC31
# 立法 Nv4
# 的 DE
# 過程 Nac
# 中 Ng
# 遇到 VC2
# 了 Di
# 許多 Neqa
# 阻撓 Nad
# 但 Cbca
# 她 Nhaa
# 不 Dc
# 灰心 VH21
# 仍然 Dbb
# 勇往直前 VA11
# 經過 VC1
# 了 Di
# 八年 DM
# 漫長 VH11
# 的 DE
# 時光 Nad
# 這項 DM
# 法案 Nac
# 終於 Dd
# 完成 VC31
# 立法 Nv4
# 使 VL4
# 開車 VA4
# 的 DE
# 司機 Nab
# 能 Dbab
# 重視 VJ1
# 生命 Nac
# 小心 VK1
# 駕駛 VC2
# 也 Dbb
# 使得 VL4
# 車禍 Nac
# 受難 VH11
# 者 Nab
# 的 DE
# 家屬 Nab
# 獲得 VJ3
# 合理 VH11
# 的 DE
# 賠償 Naeb
# 平凡 VH11
# 的 DE
# 柯 Nbc
# 媽媽 Nab
# 勇敢 VH11
# 的 DE
# 站出來 VA11
# 為 P03
# 社會 Nac
# 伸張 VC2
# 正義 Nad
# 是 Dbaa
# 值得 VH15
# 喝采 VA4
# 的 Ta
# 關公 Nba
# 漢朝 Ndaab
# 末年 Nad
# 有 V_2
# 一位 DM
# 智勇雙全 VH11
# 的 DE
# 武將 Nab
# 關公 Nba
# 他 Nhaa
# 和 P35
# 劉備 Nba
# 、 Caa
# 張飛 Nba
# 結拜為 VG2
# 兄弟 Nab
# 一起 Dh
# 為了 P03
# 保衛 VC2
# 漢室 Ndaab
# 而 Cbca
# 努力 VH11
# 有一回 DM
# 關公 Nba
# 被 P02
# 曹軍 Naeb
# 打敗 VC2
# 了 Di
# 曹操 Nba
# 派 VF2
# 人 Nab
# 勸 VF2
# 他 Nhaa
# 投降 VA4
# 關公 Nba
# 義正辭嚴 VH11
# 的 DE
# 說 VE2
# 做 VG2
# 一個 DM
# 大丈夫 Nab
# 要 Dbab
# 知道 VK1
# 做人 VA4
# 做 VC31
# 事 Nac
# 的 DE
# 原則 Nac
# 我 Nhaa
# 是 V_11
# 漢朝 Ndaab
# 武將 Nab
# 寧願 VK1
# 戰死 VH14
# 也 Dbb
# 不 Dc
# 願 VK1
# 投降 VA4
# 曹操 Nba
# 雖然 Cbaa
# 被 P02
# 關公 Nba
# 拒絕 VF1
# 還是 Dbb
# 很 Dfa
# 賞識 VJ1
# 關公 Nba
# 的 DE
# 英勇 Nv4
# 便 Dd
# 想 VE2
# 用 P39
# 錢財 Naeb
# 、 Caa
# 官位 Nac
# 來 Dbab
# 引誘 VC2
# 關公 Nba
# 讓 VL4
# 關公 Nba
# 住 VC1
# 好 VH11
# 房子 Nab
# 還 Dbb
# 經常 Dd
# 送 VD1
# 一些 Neqa
# 絲綢 Naa
# 、 Caa
# 金銀 Naeb
# 和 Caa
# 美女 Nab
# 而且 Cbcb
# 不停 Dd
# 的 DE
# 宴請 VC2
# 關公 Nba
# 可說是 V_11
# 三 Neu
# 日 Nac
# 一 Neu
# 小 VH13
# 宴 Nac
# 五 Neu
# 日 Nac
# 一 Neu
# 大 VH13
# 宴 Nac
# 盛大 VH11
# 的 DE
# 酒宴 Nac
# 之後 Ng
# 曹操 Nba
# 叫 VL4
# 人 Nab
# 牽來 VC2
# 一匹 DM
# 駿馬 Nab
# 他 Nhaa
# 對 P31
# 關公 Nba
# 說 VE2
# 這匹 DM
# 馬 Nab
# 是 V_11
# 天下 Ncc
# 聞名 VI2
# 的 DE
# 赤兔馬 Nab
# 現在 Nddc
# 送給 VD1
# 你 Nhaa
# 關公 Nba
# 得到 VJ3
# 赤兔馬 Nab
# 非常 Dfa
# 高興 VK1
# 一再 Dd
# 的 DE
# 拜謝 VC2
# 曹操 Nba
# 覺得 VK1
# 很 Dfa
# 奇怪 VK1
# 就 Dd
# 問 VE11
# 他 Nhaa
# 常常 Dd
# 送 VD1
# 你 Nhaa
# 金帛 Naeb
# 、 Caa
# 美女 Nab
# 你 Nhaa
# 都 Dab
# 沒有 Dc
# 向 P62
# 我 Nhaa
# 道謝 VB11
# 今天 Ndabd
# 送 VD1
# 你 Nhaa
# 一匹 DM
# 馬 Nab
# 為何 Dj
# 那麼 Dh
# 高興 VK1
# 呢 Tc
# 關公 Nba
# 笑 VA4
# 一 Di
# 笑 VA4
# 並 Dbb
# 沒有 Dc
# 回答 VE12
# 關公 Nba
# 知道 VK1
# 了 Di
# 劉備 Nba
# 的 DE
# 消息 Nac
# 就 Dd
# 準備 VF1
# 離開 VC2
# 曹操 Nba
# 有 Nes
# 人 Nab
# 問 VE11
# 他 Nhaa
# 將軍 Nab
# 你 Nhaa
# 為什麼 Dj
# 急 VH21
# 著 Di
# 去 Dbab
# 找 VC2
# 劉備 Nba
# 關公 Nba
# 說 VE2
# 因為 Cbaa
# 劉備 Nba
# 是 V_11
# 我 Nhaa
# 的 DE
# 結拜 Nv4
# 大哥 Nab
# 他 Nhaa
# 有 V_2
# 理想 Nac
# 、 Caa
# 有 V_2
# 抱負 Nad
# 我 Nhaa
# 要 Dbab
# 去 Dbab
# 幫助 VC2
# 他 Nhaa
# 那 Nep
# 人 Nab
# 又 Dd
# 追問 VE11
# 曹操 Nba
# 對 P31
# 你 Nhaa
# 有 V_2
# 恩 Nad
# 你 Nhaa
# 怎麼 Dj
# 可以 Dbab
# 離開 VC2
# 他 Nhaa
# 呢 Tc
# 人 Nab
# 各 Dab
# 有 V_2
# 志 Nad
# 我 Nhaa
# 和 Caa
# 大哥 Nab
# 的 DE
# 志向 Nac
# 相同 VH11
# 我們 Nhaa
# 要 Dbab
# 一起 Dh
# 努力 VH11
# 實現 VC2
# 理想 Nac
# 使 VL4
# 天下 Ncc
# 太平 VH11
# 百姓 Nab
# 生活 Nad
# 安定 VH16
# 於是 Cbca
# 關公 Nba
# 留下 VC2
# 曹操 Nba
# 所 Dab
# 送 VD1
# 的 DE
# 財物 Naeb
# 和 Caa
# 美女 Nab
# 提 VC2
# 著 Di
# 青龍刀 Nab
# 騎上 VC2
# 赤兔馬 Nab
# 連夜 Dd
# 離開 VC2
# 京城 Ncb
# 見義勇為 VA4
# 義 Nad
# 是 V_11
# 正正當當 VH11
# 的 DE
# 行為 Nad
# 也 Dbb
# 就 Dd
# 是 V_11
# 每個 DM
# 人 Nab
# 都 Dab
# 能 Dbab
# 遵守 VJ1
# 社會 Nac
# 的 DE
# 規範 Nad
# 盡 VJ1
# 個人 Nhab
# 的 DE
# 本分 Nad
# 做 VG2
# 一個 DM
# 堂堂正正 VH11
# 的 DE
# 人 Nab
# 有一個 DM
# 小朋友 Nab
# 在 VC1
# 上學 Nv4
# 途中 Ncc
# 被 P02
# 計程車 Nab
# 撞倒 VC32
# 了 Di
# 司機 Nab
# 先生 Nab
# 和 Caa
# 好心 VH11
# 的 DE
# 路人 Nab
# 趕緊 Dd
# 把 P07
# 他 Nhaa
# 送 VD1
# 到 P61
# 附近 Ncb
# 的 DE
# 醫院 Ncb
# 急救 VB11
# 才 Dd
# 救回 VC2
# 一條 DM
# 寶貴 VH11
# 的 DE
# 生命 Nac
# 好心 VH11
# 的 DE
# 路人 Nab
# 見義勇為 VA4
# 的 DE
# 精神 Nad
# 給 VD1
# 了 Di
# 大家 Nhab
# 很 Dfa
# 好 VH11
# 的 DE
# 示範 Nv1
# 在 P21
# 路 Nab
# 上 Ncda
# 有一個 DM
# 婦人 Nab
# 被 P02
# 搶劫 VC2
# 一名 DM
# 騎 VC2
# 機車 Nab
# 的 DE
# 年輕人 Nab
# 看到 VE2
# 歹徒 Nab
# 正 Dd
# 要 Dbab
# 逃跑 VA11
# 就 Dd
# 奮不顧身 VH11
# 的 DE
# 邊 Dh
# 喊 VE2
# 搶劫 VC2
# 邊 Dh
# 追上去 VA11
# 路人 Nab
# 聽到 VE2
# 了 Di
# 也 Dbb
# 都 Dab
# 紛紛 Dab
# 前來 VC1
# 幫忙 VC2
# 讓 VL4
# 警察 Nab
# 順利 VH11
# 抓到 VC31
# 這個 DM
# 壞人 Nab
# 有 V_2
# 這些 Neqa
# 見義勇為 VA4
# 的 DE
# 人 Nab
# 社會 Nac
# 治安 Nad
# 才 Dd
# 能 Dbab
# 得到 VJ3
# 保障 Nac
# 這種 DM
# 義行 Nac
# 值得 VH15
# 我們 Nhaa
# 讚揚 VC2
# 和 Caa
# 學習 VC2
# 在 P21
# 我們 Nhaa
# 社會 Nac
# 裡 Ncda
# 有 Nes
# 人 Nab
# 販賣 VD1
# 毒品 Naa
# 害人 VA4
# 害己 VA4
# 有 Nes
# 人 Nab
# 沉迷 VJ2
# 賭博 Nv4
# 誤人 VA4
# 誤事 VH11
# 還 Dbb
# 有 V_2
# 人 Nab
# 自私自利 VH11
# 而 Cbca
# 不顧 VJ1
# 公共 A
# 的 DE
# 安全 Nv4
# 這些 Neqa
# 都 Dab
# 是 V_11
# 違反 VJ1
# 社會 Nac
# 公理 Nac
# 的 DE
# 行為 Nad
# 我們 Nhaa
# 要 Dbab
# 依法 Dh
# 來 Dbab
# 制止 VC2
# 他們 Nhaa
# 假使 Cbaa
# 每個 DM
# 人 Nab
# 對 P31
# 社會 Nac
# 都 Dab
# 漠不關心 VI1
# 這個 DM
# 社會 Nac
# 將 Dd
# 是 Dbaa
# 黑暗 VH11
# 的 Ta
# 、 Caa
# 可怕 VH11
# 的 Ta
# 假使 Cbaa
# 社會 Nac
# 上 Ncda
# 有 V_2
# 許多 Neqa
# 見義勇為 VA4
# 的 DE
# 人 Nab
# 處處 Dg
# 幫助 VC2
# 別人 Nhaa
# 造福 VC2
# 大眾 Nhab
# 使 VL4
# 人間 Ncc
# 充滿 VJ3
# 了 Di
# 溫暖 Nv4
# 這 Nep
# 就 Dd
# 是 V_11
# 有義 VH21
# 的 DE
# 社會 Nac
# 返鄉 VA13
# 吃 VC31
# 晚飯 Naa
# 的 DE
# 時候 Nad
# 爸爸 Nab
# 告訴 VE12
# 我們 Nhaa
# 下個 DM
# 月 Ndabc
# 李 Nbc
# 爺爺 Nab
# 要 Dbab
# 從 P19
# 美國 Nca
# 回來 VA11
# 了 Ta
# 媽媽 Nab
# 說 VE2
# 李 Nbc
# 爺爺 Nab
# 跟 P63
# 兒子 Nab
# 、 Caa
# 媳婦 Nab
# 在 P21
# 國外 Ncc
# 住 VC1
# 了 Di
# 好幾年 DM
# 了 Ta
# 哥哥 Nab
# 問 VE11
# 爸爸 Nab
# 說 VE2
# 李 Nbc
# 爺爺 Nab
# 年紀 Nad
# 大 VH13
# 了 Ta
# 長途 A
# 旅行 VA4
# 不 Dc
# 是 Dbaa
# 很 Dfa
# 辛苦 VH16
# 嗎 Td
# 是 V_11
# 啊 Tc
# 可是 Cbca
# 這裡 Ncdb
# 是 V_11
# 他 Nhaa
# 的 DE
# 故鄉 Ncb
# 他 Nhaa
# 要 Dbab
# 回來 VA11
# 看看 VC2
# 老朋友 Nab
# 媽媽 Nab
# 接著 Dd
# 說 VE2
# 人 Nab
# 對 P31
# 故鄉 Ncb
# 都 Dab
# 有 V_2
# 一種 DM
# 特殊 VH11
# 的 DE
# 情感 Nad
# 有些 Neqa
# 動物 Nab
# 也 Dbb
# 一樣 VH11
# 像 P55
# 大雁 Nab
# 、 Caa
# 像 P55
# 鮭魚 Nab
# 爸爸 Nab
# 是 V_11
# 魚類 Naeb
# 專家 Nab
# 一 Dd
# 聽到 VE2
# 鮭魚 Nab
# 就 Dd
# 很 Dfa
# 興奮 VH21
# 的 DE
# 說 VE2
# 鮭魚 Nab
# 在 P21
# 河流 Nab
# 中 Ncda
# 出生 VA12
# 游入 VC1
# 海洋 Nab
# 在 P21
# 海洋 Nab
# 中 Ncda
# 成長 VH12
# 長大 VH11
# 以後 Ng
# 牠們 Nhaa
# 都 Dab
# 渴望 VK1
# 回到 VC1
# 自己 Nhab
# 的 DE
# 故鄉 Ncb
# 因為 Cbaa
# 故鄉 Ncb
# 有 V_2
# 一股 DM
# 特殊 VH11
# 的 DE
# 氣味 Nad
# 儘管 Cbaa
# 離鄉 VA13
# 多年 DM
# 故鄉 Ncb
# 的 DE
# 氣味 Nad
# 還是 Dbb
# 一樣 VH11
# 的 DE
# 熟悉 VJ2
# 爸爸 Nab
# 推推 VC2
# 眼鏡 Nab
# 繼續 VF1
# 說 VE2
# 成群 VH11
# 的 DE
# 鮭魚 Nab
# 奮力 Dh
# 的 DE
# 向 P62
# 前 Ncda
# 游 VA11
# 經過 VC1
# 一段 DM
# 時間 Nad
# 後 Ng
# 故鄉 Ncb
# 的 DE
# 氣味 Nad
# 越來越 Dfa
# 濃厚 VH11
# 牠們 Nhaa
# 的 DE
# 心情 Nad
# 也 Dbb
# 越來越 Dfa
# 興奮 VH21
# 游近 VC1
# 故鄉 Ncb
# 的 DE
# 那條 DM
# 河流 Nab
# 鮭魚 Nab
# 們 Naea
# 激動 VH21
# 得 DE
# 又 Caa[P1]
# 叫 VE2
# 又 Caa[P2]
# 跳 VA11
# 牠們 Nhaa
# 逆 VJ1
# 水 Naa
# 而 Cbca
# 上 VC1
# 碰到 VC2
# 激流 Nab
# 仍然 Dbb
# 不停 Dd
# 的 DE
# 游 VA11
# 不停 Dd
# 的 DE
# 游 VA11
# 我 Nhaa
# 問 VE11
# 爸爸 Nab
# 難道 Dbb
# 牠們 Nhaa
# 都 Dab
# 不 Dc
# 休息 VA12
# 嗎 Td
# 甚至 Dbb
# 捨不得 VL1
# 浪費 VC31
# 時間 Nad
# 去 Dbab
# 尋找 VC2
# 食物 Naa
# 妹妹 Nab
# 得意 VH21
# 的 DE
# 說 VE2
# 我 Nhaa
# 知道 VK1
# 了 Ta
# 李 Nbc
# 爺爺 Nab
# 一定 Dbaa
# 也 Dbb
# 像 P55
# 鮭魚 Nab
# 一樣 VH11
# 急 VH21
# 著 Di
# 回家 VA13
# 囉 Tc
# 給 P04
# 遠方 Ncb
# 的 DE
# 友人 Nab
# 靜文 Nba
# 好 Dfa
# 久 VH11
# 不 Dc
# 見 VE2
# 你 Nhaa
# 好 VH11
# 嗎 Td
# 我 Nhaa
# 好 Dfa
# 想念 VJ2
# 你 Nhaa
# 上次 DM
# 來信 Nab
# 你 Nhaa
# 說 VE2
# 你 Nhaa
# 已經 Dd
# 習慣 VL2
# 澳洲 Nca
# 的 DE
# 生活 Nad
# 也 Dbb
# 會 VL2
# 用 VC2
# 簡單 VH11
# 的 DE
# 英語 Nac
# 了 Ta
# 我 Nhaa
# 實在 Dbb
# 很 Dfa
# 高興 VK1
# 告訴 VE12
# 你 Nhaa
# 等 P13
# 我 Nhaa
# 升上 VC1
# 五年級 Nac
# 我們 Nhaa
# 也 Dbb
# 有 V_2
# 英語課 Nac
# 了 Ta
# 我們 Nhaa
# 一起 Dh
# 到 VC1
# 學校 Ncb
# 後面 Ncdb
# 的 DE
# 溪 Nab
# 邊 Ncda
# 脫了鞋 VA4[+ASP]
# 光 VH17
# 著 Di
# 腳丫子 Nab
# 在 P21
# 溪 Nab
# 邊 Ncda
# 玩水 VA4
# 把 P07
# 頭髮 Nab
# 和 Caa
# 衣服 Nab
# 都 Dab
# 弄溼 VC2
# 了 Di
# 那條 DM
# 小 VH13
# 溪 Nab
# 最近 Nddc
# 經過 VC1
# 保育 Nv1
# 團體 Nab
# 的 DE
# 努力 Nv4
# 變 VH11
# 得 DE
# 更 Dfa
# 清澈 VH11
# 魚蝦 Naeb
# 也 Dbb
# 更多 VH11
# 了 Ta
# 你 Nhaa
# 在 VC1
# 澳洲 Nca
# 已經 Dd
# 一年 DM
# 了 Ta
# 是否 Dj
# 曾經 Dd
# 想起 VE2
# 熟悉 VJ2
# 的 DE
# 故鄉 Ncb
# 呢 Tc
# 再 Dd
# 過 VC1
# 幾天 DM
# 鎮 Ncb
# 上 Ncda
# 的 DE
# 媽祖廟 Nab
# 將 Dd
# 舉辦 VC2
# 一年 DM
# 一度 DM
# 的 DE
# 進香 Nv4
# 活動 Nac
# 都 Dab
# 熱心 VJ1
# 參與 VC2
# 一 Neu
# 系列 Nac
# 的 DE
# 民俗 Nad
# 表演 Nac
# 如 P47
# 舞龍 VA4
# 舞獅 VA4
# 、 Caa
# 歌仔戲 Nac
# 、 Caa
# 布袋戲 Nac
# 我們 Nhaa
# 學校 Ncb
# 的 DE
# 民俗 Nad
# 社團 Nac
# 宋江陣 Nad
# 也 Dbb
# 要 Dbab
# 參加 VC2
# 演出 Nac
# 你 Nhaa
# 可以 Dbab
# 想像得到 VE2[+DE]
# 不久 Nddb
# 之後 Ng
# 整個 Neqa
# 大甲鎮 Nca
# 的 DE
# 街道 Nab
# 將 Dd
# 會 Dbaa
# 出現 VH14
# 人山人海 VH11
# 的 DE
# 盛況 Nac
# 我 Nhaa
# 常常 Dd
# 想起 VE2
# 同學 Nab
# 一起 Dh
# 讀書 VA4
# 、 Caa
# 一起 Dh
# 遊戲 VA4
# 的 DE
# 情形 Nac
# 教室 Ncb
# 前面 Ncdb
# 那棵 DM
# 大 VH13
# 榕樹 Nab
# 枝葉 Naeb
# 比 P49
# 以前 Ndda
# 更 Dfa
# 茂盛 VH11
# 了 Ta
# 你 Nhaa
# 還 Dbb
# 記得 VK1
# 我們 Nhaa
# 在 P21
# 樹蔭 Nab
# 下 Ncda
# 乘涼 VA4
# 、 Caa
# 聊天 VA4
# 的 DE
# 情形 Nac
# 嗎 Td
# 你 Nhaa
# 還 Dbb
# 記得 VK1
# 我們 Nhaa
# 赤著腳 VH11[+ASP]
# 在 P21
# 溪 Nab
# 邊 Ncda
# 玩耍 VA4
# 的 DE
# 情形 Nac
# 嗎 Td
# 希望 VK1
# 你 Nhaa
# 記得 VK1
# 屬於 VG2
# 你 Nhaa
# 的 DE
# 這片 DM
# 土地 Naa
# 記得 VK1
# 你 Nhaa
# 曾經 Dd
# 生長 VH14
# 的 DE
# 地方 Nab
# 今年 Ndaba
# 暑假 Ndabf
# 你 Nhaa
# 會 Dbaa
# 回 VC1
# 臺灣 Nca
# 嗎 Td
# 盼望 VK1
# 我們 Nhaa
# 能 Dbab
# 再 Dd
# 一起 Dh
# 聊天 VA4
# 、 Caa
# 戲水 VA4
# 敬祝 VE12
# 學業 Nad
# 進步 VH11
# 友 Nab
# 家明 Nba
# 上 VA4
# 五月 Ndabc
# 八日 Ndabd
# 大安溪 Nca
# 畔 Ncda
# 綿長 VH11
# 的 DE
# 大安溪 Nca
# 從 P19
# 遙遠 VH11
# 的 DE
# 大霸尖山 Nca
# 流過 VC1
# 山地 Ncb
# 、 Caa
# 流過 VC1
# 田野 Ncb
# 流入 VC1
# 廣大 VH11
# 的 DE
# 海洋 Nab
# 神祕 VH11
# 的 DE
# 火炎山 Nca
# 屹立 VH14
# 在 P21
# 大安溪 Nca
# 畔 Ncda
# 赤紅 VH11
# 的 DE
# 泥土 Naa
# 在 P21
# 夕陽 Nab
# 下 Ncda
# 像 P55
# 熊熊 VH11
# 火焰 Naa
# 般 Ng
# 燃燒 VC2
# 岩石 Naa
# 邊 Ncda
# 榕樹 Nab
# 下 Ncda
# 散落 VH14
# 著 Di
# 我 Nhaa
# 童年 Nad
# 的 DE
# 足跡 Nac
# 家園 Nab
# 的 DE
# 純樸 Nv4
# 、 Caa
# 溫暖 Nv4
# 深鎖 VH11
# 在 P21
# 我 Nhaa
# 的 DE
# 心田 Nad
# 認識 VJ1
# 大自然 Ncb
# 大自然 Ncb
# 是 V_11
# 人類 Naeb
# 的 DE
# 好朋友 Nab
# 我們 Nhaa
# 隨時 Dd
# 可以 Dbab
# 親近 VC2
# 它 Nhaa
# 拜訪 VC2
# 它 Nhaa
# 聞 VC2
# 一 Di
# 聞 VC2
# 青草 Nab
# 的 DE
# 芳香 Nv4
# 聽 VE2
# 一 Di
# 聽 VE2
# 小鳥 Nab
# 的 DE
# 歌唱 Nv4
# 探 VC2
# 一 Di
# 探 VC2
# 星空 Nab
# 的 DE
# 奧祕 Nac
# 使 VL4
# 我們 Nhaa
# 的 DE
# 生活 Nad
# 既 Caa[P1]
# 豐富 VH16
# 又 Caa[P2]
# 有趣 VH11
# 為什麼 Dj
# 我們 Nhaa
# 要 Dbab
# 認識 VJ1
# 大自然 Ncb
# 原因 Nac
# 之 DE
# 一 Neu
# 壯闊 VH11
# 的 DE
# 海洋 Nab
# 有 V_2
# 豐富 VH16
# 的 DE
# 魚蝦 Naeb
# 可以 Dbab
# 提供 VD1
# 人們 Naeb
# 充足 VH11
# 的 DE
# 食物 Naa
# 廣闊 VH11
# 的 DE
# 沙漠 Nab
# 有 V_2
# 大量 Neqa
# 的 DE
# 石油 Naa
# 可以 Dbab
# 供給 VD1
# 能源 Naa
# 的 DE
# 需求 Nad
# 同時 Ndabe
# 人類 Naeb
# 也 Dbb
# 可以 Dbab
# 向 P62
# 大自然 Ncb
# 學習 VC2
# 小 VH13
# 松鼠 Nab
# 收集 VC31
# 果實 Nab
# 過冬 VA4
# 蜜蜂 Nab
# 分工合作 VH11
# 這些 Neqa
# 行為 Nad
# 都 Dab
# 是 Dbaa
# 值得 VH15
# 學習 VC2
# 的 Ta
# 要 Dbab
# 認識 VJ1
# 大自然 Ncb
# 應該 Dbab
# 從 P19
# 下列 A
# 的 DE
# 途徑 Nac
# 去 Dbab
# 做 VC31
# 要 Dbab
# 培養 VC31
# 觀察 VE2
# 的 DE
# 能力 Nad
# 不論 Cbaa
# 是 V_11
# 觀察 VE2
# 高山 Nab
# 、 Caa
# 大海 Nab
# 還是 Dbb
# 欣賞 VJ2
# 花草 Naeb
# 、 Caa
# 樹木 Naeb
# 都 Dab
# 能 Dbab
# 留意 VK1
# 它們 Nhaa
# 的 DE
# 變化 Nac
# 這樣 VH11
# 才 Dd
# 能 Dbab
# 融入 VC33
# 大自然 Ncb
# 做 VG2
# 它們 Nhaa
# 的 DE
# 好朋友 Nab
# 其次 Cbcb
# 要 Dbab
# 多 Neqa
# 參加 VC2
# 探索 VE2
# 自然 Nad
# 的 DE
# 活動 Nac
# 到 P61
# 山 Nab
# 裡 Ncda
# 採集 VC31
# 標本 Nab
# 如果 Cbaa
# 經過 VC1
# 專家 Nab
# 的 DE
# 指導 Nv1
# 可以 Dbab
# 收到 VC31
# 事半功倍 VH11
# 的 DE
# 效果 Nac
# 必須 Dbab
# 要 Dbab
# 養成 VC31
# 隨手 Dh
# 做 VC31
# 筆記 Nac
# 的 DE
# 習慣 Nac
# 把 P07
# 觀察 VE2
# 的 DE
# 結果 Nac
# 隨時 Dd
# 記錄下來 VB2
# 才 Dd
# 能 Dbab
# 有 V_2
# 系統 Nac
# 的 DE
# 了解 VK1
# 大自然 Ncb
# 如果 Cbaa
# 我們 Nhaa
# 能 Dbab
# 做到 VE2
# 這三點 DM
# 必定 Dbaa
# 能 Dbab
# 很 Dfa
# 快 VH13
# 的 DE
# 認識 VJ1
# 大自然 Ncb
# 體驗到 VK1
# 大自然 Ncb
# 的 DE
# 真 Nv4
# 與 Caa
# 美 Nv4
# 與 P35
# 大自然 Ncb
# 和諧 VH11
# 的 DE
# 生活 VA12
# 在一起 VH11
# 誰 Nhb
# 是 V_11
# 爬牆 Nv4
# 高手 Nab
# 走到 VC1
# 街 Nab
# 上 Ncda
# 只要 Cbaa
# 多 Dfa
# 留意 VK1
# 爬滿 VC1
# 綠色 Nad
# 的 DE
# 植物 Nab
# 這種 DM
# 植物 Nab
# 的 DE
# 葉子 Nab
# 密密 VH11
# 的 DE
# 、 Caa
# 均勻 VH11
# 的 DE
# 布滿 VC33
# 牆面 Nab
# 這 Nep
# 是 V_11
# 什麼 Nep
# 植物 Nab
# 呢 Tc
# 它 Nhaa
# 有 V_2
# 一個 DM
# 很 Dfa
# 美麗 VH11
# 的 DE
# 名字 Nac
# 叫做 VG2
# 地錦 Nba
# 意思 Nac
# 是 V_11
# 大地 Nab
# 的 DE
# 錦衣 Nab
# 也 Dbb
# 有 Nes
# 人 Nab
# 稱 VG1
# 它 Nhaa
# 爬牆虎 Nba
# 因為 Cbaa
# 它 Nhaa
# 和 P35
# 壁虎 Nab
# 一樣 VH11
# 很 Dfa
# 會 VL2
# 爬牆 VA4
# 爬牆虎 Nba
# 的 DE
# 外形 Nad
# 十分 Dfa
# 美麗 VH11
# 每一枝 DM
# 莖 Nab
# 上面 Ncdb
# 新 VH11
# 長 VH13
# 的 DE
# 葉子 Nab
# 是 V_11
# 粉紅色 Nad
# 的 Ta
# 但 Cbca
# 經過 VC1
# 幾天 DM
# 就 Dd
# 變成 VG2
# 碧綠 VH11
# 的 DE
# 顏色 Nac
# 如果 Cbaa
# 站 VA12
# 在 P21
# 遠處 Ncb
# 欣賞 VJ2
# 只 Daa
# 見 VE2
# 紅 VH11
# 葉 Nab
# 與 Caa
# 綠 VH11
# 葉 Nab
# 參差 VH14
# 排列 VC33
# 著 Di
# 它 Nhaa
# 像 VG2
# 一幅 DM
# 天然 A
# 的 DE
# 圖畫 Nab
# 掛 VC33
# 在 P21
# 大 VH13
# 牆 Nab
# 上 Ncda
# 走近 VC1
# 細看 VC2
# 它 Nhaa
# 的 DE
# 葉子 Nab
# 有 V_2
# 心形 Nac
# 的 DE
# 、 Caa
# 有 V_2
# Nac Head
# 的 DE
# 一棵 DM
# 植物 Nab
# 上 Ncda
# 長出 VJ3
# 不同 VH11
# 形狀 Nad
# 的 DE
# 葉子 Nab
# 在 P21
# 植物 Nab
# 王國 Nac
# 中 Ng
# 也 Dbb
# 是 Dbaa
# 十分 Dfa
# 少見 VH11
# 的 Ta
# 人們 Naeb
# 最 Dfa
# 感興趣 VI1
# 的 DE
# 是 V_11
# 爬牆虎 Nba
# 為什麼 Dj
# 會 Dbaa
# 爬牆 VA4
# 這 Nep
# 是 V_11
# 一個 DM
# 小 VH13
# 祕密 Nac
# 哦 Tc
# 爬牆虎 Nba
# 的 DE
# 莖 Nab
# 上 Ncda
# 有 V_2
# 卷曲 VH11
# 的 DE
# 細絲 Naa
# 細絲 Naa
# 連 VJ1
# 著 Di
# 五 Neu
# 、 Caa
# 六 Neu
# 個 Nfa
# 碧綠 VH11
# 的 DE
# 小 VH13
# 珠子 Nab
# 這些 Neqa
# 形狀 Nad
# 圓圓 VH11
# 的 DE
# 珠子 Nab
# 就 Dd
# 是 V_11
# 它 Nhaa
# 用來 VL2
# 爬牆 VA4
# 的 DE
# 腳 Nab
# 只要 Cbaa
# 靠近 VC2
# 水泥 Naa
# 牆 Nab
# 或 Caa
# 木板 Nab
# 小 VH13
# 珠子 Nab
# 便 Dd
# 使出 VC31
# 渾身 Nab
# 力氣 Nad
# 牢牢 VH11
# 的 DE
# 黏 VC33
# 在 P21
# 牆面 Nab
# 上 Ncda
# 像 P55
# 章魚 Nab
# 身 Nab
# 上 Ncda
# 的 DE
# 吸盤 Nab
# 抓住 VC2
# 獵物 Nab
# 一樣 VH11
# 為 P03
# 大地 Nab
# 增添 VC31
# 色彩 Nad
# 與 Caa
# 生機 Nad
# 是 V_11
# 美化 VC2
# 城市 Nab
# 、 Caa
# 綠化 VH16
# 環境 Nac
# 的 DE
# 功臣 Nab
# 看 VC2
# 星星 Nab
# 夏天 Ndabb
# 的 DE
# 晚上 Ndabe
# 天空 Ncb
# 像 VG2
# 一塊 DM
# 黑 VH11
# 絲絨 Naa
# 上面 Ncdb
# 掛 VC33
# 著 Di
# 千千萬萬顆 DM
# 的 DE
# 小 VH13
# 星星 Nab
# 它們 Nhaa
# 像 VG2
# 頑皮 VH11
# 的 DE
# 孩子 Nab
# 擠弄 VC31
# 著 Di
# 小 VH13
# 眼睛 Nab
# 小 VH13
# 星星 Nab
# 一直 Dd
# 是 V_11
# 我 Nhaa
# 的 DE
# 好朋友 Nab
# 小時候 Ndda
# 我 Nhaa
# 住在 VC1
# 鄉下 Ncb
# 每當 P13
# 晚風 Naa
# 送 VD1
# 涼 Nv4
# 一家人 Naea
# 便 Dd
# 圍坐 VA12
# 在 P21
# 院子 Nab
# 裡 Ncda
# 聽 VE2
# 祖母 Nab
# 講 VE2
# 牛郎 Nba
# 和 Caa
# 織女 Nba
# 的 DE
# 故事 Nac
# 那時 Ndda
# 我 Nhaa
# 總 Dd
# 期待 VK1
# 著 Di
# 自己 Nhab
# 能 Dbab
# 長出 VJ3
# 翅膀 Nab
# 飛 VA11
# 向 P62
# 銀河 Nab
# 去 Dbab
# 探訪 VC2
# 它們 Nhaa
# 有時候 Dd
# 祖父 Nab
# 也 Dbb
# 教 VC2
# 我 Nhaa
# 認識 VJ1
# 北斗七星 Nba
# 六 Ndabc
# 、 Caa
# 七月 Ndabc
# 時 Ng
# 它 Nhaa
# 像 VG2
# 一只 DM
# 朝向 VC1
# 東方 Ncdb
# 的 DE
# 杓子 Nab
# 等 P13
# 過完 VJ1
# 暑假 Ndabf
# 北斗七星 Nba
# 的 DE
# 杓子 Nab
# 口 Ncda
# 就 Dd
# 換成 VG1
# 了 Di
# 朝 VC2
# 北 Ncda
# 的 DE
# 方向 Nac
# 我 Nhaa
# 猜想 VE2
# 天空 Ncb
# 中 Ng
# 一定 Dbaa
# 住 VC1
# 了 Di
# 魔術師 Nab
# 他 Nhaa
# 用 P39
# 魔法 Nad
# 移動 VA2
# 了 Di
# 北斗七星 Nba
# 的 DE
# 位置 Nac
# 上 VC1
# 了 Di
# 小學 Ncb
# 我 Nhaa
# 參加 VC2
# 觀察 VE2
# 星座 Nab
# 的 DE
# 活動 Nac
# 帶 VC32
# 著 Di
# 雙筒 Nab
# 望遠鏡 Nab
# 和 Caa
# 星座圖 Nab
# 到 P61
# 墾丁 Nca
# 看 VC2
# 星星 Nab
# 那裡 Ncdb
# 的 DE
# 星星 Nab
# 和 P35
# 沙灘 Nab
# 上 Ncda
# 的 DE
# 沙粒 Nab
# 一樣 VH11
# 多 VH13
# 數 VC2
# 也 Dbb
# 數不清 VH11
# 學會 VC2
# 了 Di
# 從 P19
# 北斗七星 Nba
# 尋找 VC2
# 北極星 Nba
# 的 DE
# 方法 Nac
# ...
# 別墅 Nab
# 、 Caa
# 小屋 Nab
# 、 Caa
# 休息屋 Nab
# 處 Ncb
# 服務 VC2
# 這兩座 DM
# 骨董級 Nad
# 的 DE
# 保護區 Ncb
# 在 P21
# １７ Neu
# 、 Caa
# １８ Neu
# 世紀 Nac
# 即已 Dd
# 成立 VC33
# 舒舒夷 Nba
# 位於 VC1
# 聳立 VH14
# 於 P23
# 濱海 VH11
# 平原 Nab
# 第一 Neu
# 斜壁 Nab
# 的 DE
# 山腳 Ncb
# 處 Ncb
# 在 P21
# 這 Nep
# 棲息 VA12
# 著 Di
# 黑 VH11
# 、 Caa
# 白 VH11
# 犀牛 Nab
# 、 Caa
# 大象 Nab
# 、 Caa
# 水牛 Nab
# 、 Caa
# 斑馬 Nab
# 、 Caa
# 東非 Nca
# 條紋羚 Nab
# 、 Caa
# 藍色 Nad
# 角馬 Nab
# 、 Caa
# 牛角 Nab
# 條紋羚 Nab
# 、 Caa
# 叢羚 Nab
# 、 Caa
# 大 VH13
# 角 Nab
# 羚羊 Nab
# 、 Caa
# 叢林 Naeb
# 野豬 Nab
# 、 Caa
# 長頸鹿 Nab
# 、 Caa
# 疣豬 Nab
# 、 Caa
# 跳羚 Nab
# 、 Caa
# 狒狒 Nab
# 、 Caa
# 猴子 Nab
# 、 Caa
# 獅子 Nab
# 、 Caa
# 花豹 Nab
# 、 Caa
# 鬣狗 Nab
# 以及 Caa
# 獵豹 Nab
# 經常 Dd
# 可 Dbab
# 發現到 VE2
# 白 VH11
# 背 Nab
# 兀鷹 Nab
# 、 Caa
# 珠雞 Nab
# 、 Caa
# 綠色 Nad
# 斑鴿 Nab
# 以及 Caa
# 犀鳥 Nab
# 所以 Cbca
# 向隅 VH11
# 的 DE
# 遊客 Nab
# 經常 Dd
# 會 Dbaa
# 選擇 VC2
# 投宿 VC1
# 於 P23
# 外圍 Nce
# 的 DE
# 旅館 Ncb
# 舒舒夷 Nba
# 每日 DM
# 每 Nes
# 人 Nab
# 的 DE
# 食宿 Nad
# 費用 Naeb
# 約 Daa
# 美金 Naeb
# ７０元 DM
# 左右 Ng
# 藉 P38
# 一條 DM
# ８公里 DM
# 寬 VH12
# 的 DE
# 陸地 Nab
# 走廊 Ncb
# 與 P35
# 舒舒夷 Nba
# 相 Dh
# 連接 VJ1
# 乃 VG2
# 一 Neu
# 介於 VJ1
# 黑 VH11
# 、 Caa
# 白 VH11
# 恩佛落芝河 Nca
# 之 DE
# 間 Ncda
# 的 DE
# 楔形 Nad
# 流域 Nab
# 黑 VH11
# 犀牛 Nab
# 、 Caa
# 白 VH11
# 犀牛 Nab
# 、 Caa
# 紅色 Nad
# 和 Caa
# 灰色 Nad
# 小 VH13
# 羚羊 Nab
# 、 Caa
# 大象 Nab
# 、 Caa
# 石羚 Nab
# 、 Caa
# 山區 Ncb
# 沼羚 Nab
# 、 Caa
# 黑臀 Nab
# 羚羊 Nab
# 、 Caa
# 東非 Nca
# 條紋 Nac
# 羚羊 Nab
# 、 Caa
# 大 VH13
# 角 Nab
# 羚羊 Nab
# 、 Caa
# 沼羚 Nab
# 、 Caa
# 牛角 Nab
# 條紋 Nac
# 羊 Nab
# 、 Caa
# 黑 VH11
# 背 Nab
# 胡狼 Nab
# 及 Caa
# 狒狒 Nab
# 穆匹拉 Nba
# 營地 Ncb
# 有 V_2
# 兩間 DM
# 自給自足 VH11
# 的 DE
# 小屋 Nab
# 各 Dab
# 有 V_2
# 一間 DM
# 廚房 Ncb
# 水 Naa
# 底 Ncda
# 抓 VC2
# 魚 Nab
# 以及 Caa
# 撒 VC33
# 餌 Nab
# 捕 VC2
# 魚 Nab
# 在 P21
# 此 Nep
# 是 Dbaa
# 列入 VJ1
# 禁止 Nv1
# 的 Ta
# 都 Dab
# 是 V_11
# 為 P02
# 森林 Nab
# 所 Dab
# 覆蓋 VC33
# 的 DE
# 沙丘 Nab
# 高度 Nad
# 達 VJ3
# １５０公尺 DM
# 盡 Dab
# 是 V_11
# 些 DM
# 沙木本 A
# 的 DE
# 灌木林 Nab
# 與 Caa
# 有 V_2
# 著 Di
# 美麗 VH11
# 花色 Nac
# 的 DE
# 草原 Nab
# 在 P21
# 這 Nep
# 可以 Dbab
# 發現到 VE2
# 紅色 Nad
# 小 VH13
# 羚羊 Nab
# 、 Caa
# 叢羚 Nab
# 、 Caa
# 叢林 Naeb
# 野豬 Nab
# 、 Caa
# 長尾猴 Nab
# 的 DE
# 足跡 Nac
# 長 VH12
# ３０公里 DM
# 可 Dbab
# 遊走 VC1
# 三天 DM
# 的 DE
# 穆里基 Nba
# 路徑 Nac
# 連貫 VC2
# 聖路西亞 Nca
# 和 Caa
# 開普威達 Nca
# 東非 Nca
# 條紋羚 Nab
# 、 Caa
# 沼羚 Nab
# 、 Caa
# 叢林 Naeb
# 野豬 Nab
# 、 Caa
# 疣豬 Nab
# 、 Caa
# 灰色 Nad
# 小 VH13
# 羚羊 Nab
# 與 Caa
# 長尾猴 Nab
# 此 Nep
# 處 Ncb
# 是 V_11
# 非洲 Nca
# 南部 Ncdb
# 惟一 A
# 的 DE
# 粉紅 VH11
# 背 Nab
# 塘鵝 Nab
# 的 DE
# 保護地 Ncb
# 數以百計 Neqa
# 的 DE
# 粉紅 VH11
# 背 Nab
# 塘鵝 Nab
# 聚集 VA2
# 在 P21
# 舒舒夷 Nba
# 河岸 Ncb
# 旁 Ncda
# 的 DE
# 樹林 Nab
# 內 Ncda
# ５公里 DM
# 長 VH12
# 的 DE
# 杜甘洛夫 Nba
# 路徑 Nac
# 有 V_2
# 一個 DM
# 迷人 VH11
# 的 DE
# 鄉村式 Nad
# 營區 Ncb
# 位於 VC1
# 環繞 VJ1
# 著 Di
# 聖西亞湖 Nca
# 的 DE
# 一個 DM
# 寬 VH12
# 一公里 DM
# 的 DE
# 環狀帶 Nad
# 地區 Ncb
# 湖 Nab
# 內 Ncda
# 盛產 VC31
# 著 Di
# 河馬 Nab
# 、 Caa
# 鱷魚 Nab
# 、 Caa
# 蒼鷺 Nab
# 及 Caa
# 其他 Neqa
# 捕食 VC2
# 魚類 Naeb
# 的 DE
# 鳥族 Nab
# 內 Ncda
# 有 V_2
# 交誼廳 Ncb
# 、 Caa
# 廚房 Ncb
# 、 Caa
# 冷 VH11
# 熱 VH16
# 水 Naa
# 均 Dab
# 供應 VD1
# 馬培蘭 Nba
# 營區 Ncb
# 提供 VD1
# 了 Di
# 設備 Naeb
# 完善 VH11
# 的 DE
# 木造 A
# 屋 Nab
# 以及 Caa
# 篷車 Nab
# 露營區 Ncb
# 波那曼芝 Nba
# 尚 Dd
# 提供 VD1
# 了 Di
# 建 VC33
# 在 P21
# 樹枝 Nab
# 間 Ncda
# 的 DE
# 兩 Neu
# 人 Nab
# 床位 Nac
# 樹屋 Nab
# 舒適 VH11
# 且 Caa
# 裝備 Nab
# 齊全 VH11
# 的 DE
# 也 Dbb
# 因為 Cbaa
# 其 Nep
# 巧思 Nad
# 而 Cbca
# 走俏 VH11
# 這種 DM
# 特別 VH11
# 的 DE
# 觀賞 VC2
# 動物 Nab
# 的 DE
# 方法 Nac
# 也 Dbb
# 是 V_11
# 它 Nhaa
# 吸引 VJ1
# 遊客 Nab
# 的 DE
# 一 Neu
# 大 VH13
# 點 Nac
# 八 Ndabc
# １０月 Ndabc
# 中旬 Ndabd
# 是 V_11
# 南非 Nca
# 大部分 Neqa
# 地區 Ncb
# 乾旱 VH11
# 季節 Nac
# 的 DE
# 最後 Nddc
# 幾個 DM
# 月 Ndabc
# 非洲豹 Nab
# 是 V_11
# 屬 VG2
# 大貓科 Nab
# 動物 Nab
# 中 Ng
# 最 Dfa
# 機警 VH11
# 與 Caa
# 最 Dfa
# 偷偷摸摸 VH11
# 的 DE
# 一種 DM
# 動物 Nab
# 慶伯利 Nca
# 附近 Ncb
# 的 DE
# 瓦耳布斯 Nca
# 以及 Caa
# 伊莉莎白港 Nca
# 附近 Ncb
# 的 DE
# 阿多 Nba
# 大象 Nab
# 公園 Ncb
# 輕便 VH11
# 的 DE
# 衣服 Nab
# 、 Caa
# 舒適 VH11
# 的 DE
# 鞋子 Nab
# 、 Caa
# 太陽 Nab
# 眼鏡 Nab
# 、 Caa
# 防曬 VH11
# 乳液 Naa
# 、 Caa
# 雙筒 Nab
# 望眼鏡 Nab
# 、 Caa
# 照相機 Nab
# 數量 Nad
# 足夠 VH15
# 軟片 Nab
# 以及 Caa
# 介紹 VE2
# 南非 Nca
# 各 Nes
# 地 Ncb
# 動植物 Naeb
# 的 DE
# 書籍 Naeb
# 是 Dbaa
# 在 VC1
# 開普省 Nca
# 西部 Ncdb
# 山區 Ncb
# 的 DE
# 南邊 Ncdb
# 以及 Caa
# 整個 DM
# 納塔爾省 Nca
# 內 Ng
# 德拉肯斯堡 Nca
# 的 DE
# 山腳 Ncb
# 地區 Ncb
# 川斯華爾省 Nca
# 、 Caa
# 達爾斯衝 Nca
# 、 Caa
# 林登堡 Nca
# 、 Caa
# 貝爾發斯特 Nca
# 以及 Caa
# 剎林 Nca
# 是 V_11
# 釣 VC2
# 的 DE
# 最佳 A
# 去處 Ncb
# 目前 Nddc
# 台灣 Nca
# 的 DE
# 南非團 Nab
# 均 Dab
# 會 Dbaa
# 安排 VE12
# 旅客 Nab
# 體驗 VC2
# 南非 Nca
# 最 Dfa
# 著稱 VI2
# 的 DE
# 公私立 A
# 野生 A
# 動物 Nab
# 保護區 Ncb
# 通常 Dd
# 會 Dbaa
# 安排 VE12
# 在 VC1
# 離 P15
# 約堡 Nca
# 較 Dfa
# 近 VH13
# 的 DE
# 馬布拉 Nca
# 私人 Nhab
# 保護區 Ncb
# 若 Cbaa
# 想 VE2
# 自行 Dh
# 前往 VC1
# 南非 Nca
# 體驗 VC2
# 各 Nes
# 自然 Nad
# 保護區 Ncb
# 的 DE
# 野趣 Nad
# 可 Dbab
# 選擇 VC2
# 至 P61
# 南非 Nca
# 後 Ng
# 參加 VC2
# 各 Nes
# 大 VH13
# 飯店 Ncb
# 獵遊 Nv4
# 行程 Nad
# 露營車 Nab
# 成本 Naeb
# 每 Nes
# 人 Nab
# 每天 DM
# 大約 Daa
# 攤 VC2
# ８００元 DM
# 左右 Ng
# 頗為 Dfa
# 經濟 VH11
# 若 Cbaa
# 有 Nes
# 超過 VJ1
# １６ Neu
# 人 Nab
# 以上 Neqb
# 的 DE
# 志同道合 VH11
# 的 DE
# 好友 Nab
# 要 Dbab
# 一道 Dh
# 來 VC2
# 趟 DM
# 非 Nca
# 生態 Nac
# 之 DE
# 旅 Nac
# 才 Dd
# 可 Dbab
# 確保 VE2
# 您 Nhac
# 有 V_2
# 一趟 DM
# 快樂 VH21
# 的 DE
# 生態 Nac
# 之 DE
# 旅 Nac
# 在 P21
# 南非 Nca
# 有些 Neqa
# 地區 Ncb
# 如 P47
# 川斯華爾省 Nca
# 和 Caa
# 納塔爾省 Nca
# 都 Dab
# 是 V_11
# 瘧疾 Nad
# 地區 Ncb
# 上午 Ndabe
# ８點 Ndabe
# ３０分 Ndabe
# 搭 VC2
# 飛機 Nab
# 從 P19
# 中正 Nba
# 機場 Ncb
# 起飛 VA11
# 經 P26
# 香港 Nca
# 轉機 VA4
# 她 Nhaa
# 是 V_11
# 台灣 Nca
# 八方 Nba
# 旅行社 Ncb
# 事先 Dd
# 就 Dd
# 替 P37
# 我 Nhaa
# 安排好 VE2
# 的 DE
# 地陪 Nab
# 張 Nbc
# 小姐 Nab
# 告訴 VE12
# 我 Nhaa
# 這幾年 DM
# 來 Ng
# 北京 Nca
# 的 DE
# 新 VH11
# 建設 Naeb
# 頗多 VH11
# 歷任 Nddc
# 遼 Ndaab
# 、 Caa
# 金 Ndaab
# 、 Caa
# 元 Ndaab
# 、 Caa
# 明 Ndaab
# 、 Caa
# 清 Ndaab
# 五 Neu
# 代 Nac
# 之 DE
# 國都 Ncb
# 北京 Nca
# 這個 DM
# 地方 Nab
# 最早 Dd
# 出現 VH14
# 於 P23
# 歷史 Nad
# 記載 Naeb
# 是 V_11
# 西元 Ndaad
# 前 Ng
# １０００年 Ndaad
# 春秋 Ndaab
# 戰國 Ndaab
# 時 Ng
# 燕國 Nca
# 國都 Ncb
# 聽 VE2
# 父親 Nab
# 說 VE2
# 當時 Ndabe
# 北京 Nca
# 市民 Nab
# 為 P03
# 北平 Nca
# 一 Neu
# 名 Nac
# 甚 Dfa
# 反感 VI1
# 北京 Nca
# 現有 A
# 都市 Ncb
# 之 DE
# 雛型 Nac
# 是 Dbaa
# 元朝 Ndaab
# 設 VC33
# 大都 Nca
# 時 Ng
# 所 Dab
# 建立 VC31
# 的 Ta
# 留下 VC2
# 如 P47
# 故宮 Nca
# 、 Caa
# 頤和園 Nca
# 、 Caa
# 景山 Nba
# 公園 Ncb
# 、 Caa
# 北海 Nba
# 公園 Ncb
# 等 Cab
# 兀自 Dh
# 敘說 VE2
# 當年 Ndabf
# 帝王 Nab
# 的 DE
# 豪華 VH11
# 絢爛 VH11
# 生活 Nad
# 堂妹 Nab
# 興奮 VH21
# 得 DE
# 說明 VE2
# 今兒個 Nddc
# 晚上 Ndabe
# 來 Dbab
# 找 VC2
# 我 Nhaa
# 去 Dbab
# 吃 VC31
# 羊肉 Naa
# 到 VC1
# 了 Di
# 沙河鎮 Nca
# 進 VC1
# 昌平縣 Nca
# 大約 Daa
# 又 Dd
# 開 VC2
# 了 Di
# ５公里 DM
# 就 Dd
# 到 VC1
# 了 Ta
# 下 VC1
# 了 Di
# 車 Nab
# 就 Dd
# 有 Nes
# 一些 Neqa
# 換 VC31
# 錢 Naeb
# 的 DE
# 人 Nab
# 圍過來 VA11
# 明十三陵 Nca
# 是 V_11
# 我國 Nac
# 帝王 Nab
# 陵墓 Ncb
# 中 Ng
# 保存 VC2
# 比較 Dfa
# 完整 VH11
# 的 DE
# 一 Neu
# 處 Ncb
# 是 V_11
# 明朝 Ndaab
# 第１３位 DM
# 皇帝 Nab
# 神宗 Nba
# 朱翊鈞 Nba
# 和 Caa
# 他 Nhaa
# 兩位 DM
# 皇后 Nab
# 的 DE
# 合葬地 Ncb
# 主要 VH11
# 建築物 Nab
# 只 Daa
# 剩下 VJ3
# 寶城 Nca
# 、 Caa
# 方城 Nca
# 、 Caa
# 明樓 Nca
# 和 Caa
# 地下 A
# 玄宮 Ncb
# 又 Dd
# 陸續 Dh
# 發現 VE2
# 刻有 VJ3
# 金牆前皮 Nba
# 、 Caa
# 右道 Nba
# 、 Caa
# 寶城中 Nba
# 、 Caa
# 左道大中 Nba
# 等 Cab
# 字跡 Nac
# 中室 Ncb
# 陳設 VC33
# 萬曆 Ndaac
# 皇帝 Nab
# 和 Caa
# 孝瑞 Nba
# 、 Caa
# 孝靖 Nba
# 兩 Neu
# 皇后 Nab
# 之 DE
# 白玉石 Nab
# 神座 Nab
# 神座 Nab
# 之 DE
# 前 Ncda
# 各 Dab
# 有 V_2
# 香爐 Nab
# 一 Neu
# 、 Caa
# 燭台 Nab
# 二 Neu
# 、 Caa
# 花瓶 Nab
# 二 Neu
# 在 P21
# 棺 Nab
# 左右 Ncdb
# 放有 VJ3
# ２６只 DM
# 盛滿 VC2
# 殉葬物 Nab
# 之 DE
# 紅 VH11
# 漆 Naa
# 木箱 Nab
# 便 Dd
# 由 P06
# 新 VH11
# 登基 VA4
# 的 DE
# 皇帝 Nab
# 為 P03
# 其 Nep
# 圈定 VC2
# 殉葬 Nv4
# 人員 Nab
# 各 Nes
# 陵 Ncb
# 均 Dab
# 是 Dbaa
# 用 P39
# 木俑 Nab
# 來 Dbab
# 代替 VC2
# 人 Nab
# 殉葬 VA4
# 的 Ta
# 我們 Nhaa
# 的 DE
# 參觀 Nv1
# 路線 Nac
# 是 V_11
# 由 P06
# 玄宮 Ncb
# 後面 Ncdb
# 順著 P25
# 現代 Nddc
# 打造 VC31
# 的 DE
# 水泥 Naa
# 扶梯 Nab
# 深入 VC1
# 地 Naa
# 底 Ncda
# 一 Neu
# 部分 Neqa
# 在 VC1
# 定陵 Nca
# 明樓 Nba
# 前 Ncda
# 的 DE
# 第一 Neu
# 、 Caa
# 二 Neu
# 陳列室 Ncb
# 還 Dbb
# 有 V_2
# 金 Naa
# 、 Caa
# 銀 Naa
# 、 Caa
# 玉器 Nab
# 、 Caa
# 木俑 Nab
# 、 Caa
# 甲冑 Nab
# 、 Caa
# 箭 Nab
# 等等 Cab
# 賣 VD1
# 皮帽 Nab
# 的 DE
# 、 Caa
# 賣 VD1
# 紅柿 Nab
# 的 DE
# 、 Caa
# 賣 VD1
# 橘子 Nab
# 的 DE
# 、 Caa
# 換 VC31
# 錢 Naeb
# 的 DE
# 張 Nbc
# 小姐 Nab
# 直 Dh
# 拉 VC2
# 我 Nhaa
# 袖子 Nab
# 示意 VB11
# 叫 VF2
# 我 Nhaa
# 快點 Dab
# 走 VA11
# 別 Dbab
# 搭理 VC2
# 但 Cbca
# 香港 Nca
# 購物 Nv4
# 的 DE
# 多樣化 Nv4
# 卻 Dbb
# 是 V_11
# 其 Nep
# 最 Dfa
# 吸引 VJ1
# 人 Nab
# 的 DE
# 地方 Nab
# 從 Caa[P1]
# 全球 Nce
# 最 Dfa
# 知名 VH11
# 的 DE
# 名牌 Nab
# 精品 Nab
# 到 Caa[P2]
# 世界 Ncb
# 各 Nes
# 角落 Ncb
# 出產 VJ3
# 的 DE
# 特色 Nac
# 貨品 Nab
# 其中 Nep
# 又 Dd
# 以 P11
# 耶誕節 Ndabd
# 前後 Ng
# 一直 Dd
# 到 VC1
# 春節 Ndabd
# 、 Caa
# 元宵節 Ndabd
# 的 DE
# 戰況 Nad
# 最 Dfa
# 激烈 VH11
# 香港 Nca
# 本島 Nce
# 和 Caa
# 九龍 Nca
# 共 Daa
# 可 Dbab
# 區分出 VC2
# 四 Neu
# 大 VH13
# 購物 Nv4
# 中心區 Ncb
# 港島 Nca
# 的 DE
# 中環 Nca
# 、 Caa
# 銅鑼灣 Nca
# 及 Caa
# 九龍 Nca
# 的 DE
# 尖沙咀 Nca
# 、 Caa
# 油旺角 Nca
# 一帶 Ncdb
# 則 Dbb
# 是 V_11
# 平價貨 Nab
# 、 Caa
# 水貨 Nab
# 的 DE
# 集散 A
# 中心 Ncb
# 例如 P54
# 位於 VC1
# 文華 Nba
# 酒店 Ncb
# 旁 Ncda
# 的 DE
# 太子 Nba
# 大廈 Nab
# 、 Caa
# 太古 Nba
# 大廈 Nab
# 、 Caa
# 亞歷山大 Nba
# 大廈 Nab
# 及 Caa
# 置地 Nba
# 廣場 Ncb
# 與 P35
# 中環 Nca
# 緊緊 VH11
# 相連 VH11
# 的 DE
# 上環 Nca
# 也 Dbb
# 是 V_11
# 主要 VH11
# 的 DE
# 購物區 Ncb
# 中環 Nca
# 所有 Neqa
# 大型 Nad
# 購物 Nv4
# 中心 Ncb
# 都 Dab
# 集中 VC2
# 在 P21
# 于諾道 Nca
# 、 Caa
# 德輔道 Nca
# 和 Caa
# 皇后大道 Nca
# 約 Daa
# 港 Naeb
# 百元 DM
# 就 Dd
# 能 Dbab
# 買到 VC31
# 一個 DM
# 不錯 VH11
# 的 DE
# 真皮 Nab
# 皮夾 Nab
# 有 V_2
# 藝術 Nad
# 精品 Nab
# 、 Caa
# 瓷器 Nab
# 、 Caa
# 地毯 Nab
# 、 Caa
# 家具 Naeb
# 及 Caa
# 各式各樣 A
# 小 VH13
# 擺飾 Nab
# 地攤 Ncb
# 及 Caa
# 路 Nab
# 邊 Ncda
# 小 VH13
# 鋪子 Ncb
# 也 Dbb
# 有 V_2
# 可 Dbab
# 看 VC2
# 之 DE
# 處 Ncb
# 銅鑼灣 Nca
# 位於 VC1
# 連接 VJ1
# 九龍 Nca
# 和 Caa
# 港島 Nca
# 的 DE
# 海 Nab
# 底 Ncda
# 隧道 Nab
# 出口 Ncb
# 附近 Ncb
# 三越 Nba
# 百貨 Naea
# 、 Caa
# 崇光 Nba
# 百貨 Naea
# 、 Caa
# 大丸 Nba
# 百貨 Naea
# 和 Caa
# 松屋 Nba
# 百貨 Naea
# 而是 Cbca
# 以 P11
# 優美 VH11
# 的 DE
# 景致 Nad
# 及 Caa
# 格調 Nad
# 高貴 VH11
# 的 DE
# 建築 Nab
# 風貌 Nac
# 著稱 VI2
# 尤其 Dbb
# 是 V_11
# 赤柱 Nba
# 市場 Ncb
# 的 DE
# 水洗絲 Naa
# 衣物 Naeb
# 及 Caa
# 運動服 Nab
# 、 Caa
# Ｔ恤 Nab
# 、 Caa
# 手工 Nad
# 藝品 Nab
# 、 Caa
# 手錶 Nab
# 等 Cab
# 一 Neu
# 景 Nac
# 一 Neu
# 物 Nab
# 都 Dab
# 散發 VC31
# 著 Di
# 古老 VH11
# 中國 Nca
# 的 DE
# 傳統 Nac
# 氣息 Naa
# 九龍 Nca
# 尖沙咀 Nca
# 購物區 Ncb
# 主要 A
# 集中 VC2
# 在 P21
# 海運 Nad
# 大廈 Nab
# 、 Caa
# 海港城 Nca
# 、 Caa
# 海洋 Nab
# 中心 Ncb
# 、 Caa
# 中港城 Nca
# 及 Caa
# 彌敦道 Nca
# 上 Ncda
# 由 P06
# 彌敦道 Nca
# 、 Caa
# 梳巴利道 Nca
# 、 Caa
# 柯士甸道 Nca
# ３條 DM
# 街 Nab
# 圍繞而成 VG1
# 的 DE
# 地帶 Ncb
# 前者 Nhc
# 以 P11
# 音響 Naeb
# 器材 Nab
# 、 Caa
# 高級 VH11
# 服飾 Naeb
# 、 Caa
# 珠寶 Nab
# 、 Caa
# 皮件 Naeb
# 及 Caa
# 傳統 Nac
# 中國 Nca
# 手工 Nad
# 藝品 Nab
# 為主 VI2
# 海洋 Nab
# 中心 Ncb
# 又 Dd
# 連接 VJ1
# 全 Neqa
# 港 Nca
# 最 Dfa
# 著名 VH11
# 的 DE
# 購物 Nv4
# 中心 Ncb
# 海運 Nad
# 大廈 Nab
# 最好 Dbb
# 到 VC1
# 貼有 VJ1
# 香港 Nca
# 旅遊 Nv4
# 協會 Ncb
# 帆船 Nab
# 標誌 Nac
# 的 DE
# 商店 Ncb
# 購買 VC31
# 以 P11
# 售賣 VC32
# 女人 Nab
# 服飾 Naeb
# 、 Caa
# 皮鞋 Nab
# 、 Caa
# 飾品 Naeb
# 、 Caa
# 手袋 Nab
# 為主 VI2
# 歐美 Nca
# 、 Caa
# 新加坡 Nca
# 、 Caa
# 泰國 Nca
# 等 Cab
# 地 Naa
# 遊客 Nab
# 都 Dab
# 紛紛 Dab
# 來 VA11
# 此 Nep
# 尋 VC2
# 寶 Nab
# 在 P21
# 銅鑼灣 Nca
# 及 Caa
# 尖沙咀 Nca
# 各 Dab
# 設有 VJ3
# 分店 Ncb
# 的 DE
# 一家 DM
# 大型 Nad
# 專賣店 Ncb
# 折扣 Naeb
# 更 Dfa
# 不少 VH11
# 在 P21
# 此 Nep
# 以 P11
# 熟練 VI2
# 的 DE
# 技工 Nab
# 、 Caa
# 創意 Nad
# 的 DE
# 設計 Nad
# 、 Caa
# 完善 VH11
# 的 DE
# 生產 Nv1
# 科技 Nac
# 及 Caa
# 現代化 VH16
# 的 DE
# 管理 Nv1
# 方式 Nac
# 經營 VC2
# 台灣 Nca
# 旅客 Nab
# 赴 VC1
# 港 Nca
# 觀光 VA4
# 人數 Nad
# 占 VJ3
# 香港 Nca
# 外來 A
# 旅客 Nab
# 的 DE
# 首位 Nad
# 攝影 Nad
# 器材 Nab
# 、 Caa
# 電器 Nab
# 、 Caa
# 電子 Nab
# 用品 Nab
# 、 Caa
# 玉器 Nab
# 也 Dbb
# 時 Dd
# 有 V_2
# 糾紛 Nac
# 發生 VJ1
# 如 P47
# 中橋 Nba
# 、 Caa
# 中藝 Nba
# 、 Caa
# 裕華 Nba
# 、 Caa
# 大華 Nba
# 、 Caa
# 中國 Nba
# 等 Cab
# 國貨店 Ncb
# 及 Caa
# 南北行 Ncb
# 購買 VC31
# 購買 VC31
# 攝影 Nad
# 器材 Nab
# 、 Caa
# 電器 Nab
# 、 Caa
# 電子 Nab
# 用品 Nab
# 常見 VH11
# 的 DE
# 糾紛 Nac
# 是 V_11
# 業者 Nab
# 提出 VC31
# 的 DE
# 價格 Nac
# 是 V_11
# 主體 Nac
# 的 DE
# 價錢 Nad
# 赴 VC1
# 香港 Nca
# 採購 VC31
# 的 DE
# 人 Nab
# 又 Dd
# 有 V_2
# 一處 DM
# 新 VH11
# 的 DE
# 購物 Nv4
# 廣場 Ncb
# 可以 Dbab
# 去 VC1
# 除了 P50
# 有 Dbab
# 包括 VK2
# 了 Di
# 化妝品 Naa
# 、 Caa
# 服飾 Naeb
# 、 Caa
# 珠寶 Nab
# 、 Caa
# 皮件 Naeb
# 等 Cab
# 價位 Nac
# 平實 VH11
# 的 DE
# 名牌 Nab
# 精品 Nab
# 外 Ng
# 遊客 Nab
# 可 Dbab
# 一邊 Dh
# 用餐 VA4
# 、 Caa
# 一邊 Dh
# 賞 VC2
# 太平山 Nca
# 優美 VH11
# 的 DE
# 景致 Nad
# 公車 Nab
# 、 Caa
# 小型 Nad
# 公車 Nab
# 直接 VH11
# 停靠 VC2
# 在 P21
# 購物 Nv4
# 中心 Ncb
# 的 DE
# 區域 Nab
# 內 Ncda
# 提供 VD1
# 零售 Nv1
# 定價 Nad
# 、 Caa
# 最 Dfa
# 新 VH11
# 款 Nab
# 、 Caa
# 產品 Nab
# 特點 Nac
# 、 Caa
# 配件 Nab
# 、 Caa
# 編號 Nac
# 、 Caa
# 保用 A
# 方式 Nac
# 等 Cab
# 資料 Nab
# ２ Cbcb
# 香港 Nca
# 政府 Nac
# 暫 Dd
# 未 Dc
# 有 V_2
# 條例 Nac
# 管制 VC2
# 中藥 Nab
# 的 DE
# 使用 Nv1
# 及 Caa
# 販售 Nv1
# 收據 Nab
# 上 Ncda
# 應 Dbab
# 明列 VC33
# 所 Dab
# 購 VC31
# 貨品 Nab
# 之 DE
# 資料 Nab
# 、 Caa
# 價錢 Nad
# 及 Caa
# 購貨 Nv4
# 日期 Nac
# ８５２－８５６３１１３ Nba
# 有別於 VJ1
# 新加坡 Nca
# 的 DE
# 購物 Nv4
# 商區 Ncb
# 香港 Nca
# 的 DE
# 購物區 Ncb
# 更 Dfa
# 多 VH13
# 更 Dfa
# 廣 VH11
# 好 VH11
# 山 Nab
# 好 VH11
# 水 Naa
# 擠 VH14
# 在 P21
# 高密度 Nad
# 開發 Nv1
# 的 DE
# 市鎮 Naeb
# 旁 Ncda
# 東部 Ncdb
# 的 DE
# 人文 Nad
# 風情 Nad
# 也 Dbb
# 略 Dh
# 不同於 VJ1
# 西部 Ncdb
# 的 DE
# 漢民族 Nba
# 文化 Nad
# 在 P21
# 台東 Nca
# 即 Dd
# 佔 VJ3
# 了 Di
# 阿美 Nba
# 、 Caa
# 布農 Nba
# 魯凱 Nba
# 、 Caa
# 排灣 Nba
# 、 Caa
# 卑南 Nba
# 、 Caa
# 雅美 Nba
# 等 Cab
# ６ Neu
# 族 Nab
# 讓 VL4
# 參觀 VC2
# 者 Nab
# 在 P21
# 短 VH13
# 時間 Nad
# 就 Dd
# 能 Dbab
# 了解 VK1
# 原住民 Nab
# 的 DE
# 文化 Nad
# 文化 Nad
# 中心 Ncb
# 裡 Ncda
# 還 Dbb
# 陳列 VC33
# 了 Di
# 史前 Ndc
# 的 DE
# 卑南 Nba
# 文化 Nad
# 部份 Neqa
# 遺物 Nac
# 讓 VL4
# 大家 Nhab
# 了解到 VK1
# 歷史 Nad
# 的 DE
# 可貴 Nv4
# 和 Caa
# 後世 Naea
# 子孫 Naeb
# 尋 VC2
# 根 Nab
# 的 DE
# 考據 Nad
# 卑南文 Nba
# 公園 Ncb
# 及 Caa
# 卑南族 Nba
# 的 DE
# 獵場 Ncb
# 離 P15
# 台東 Nca
# 市區 Ncb
# 很 Dfa
# 近 VH13
# 遊客 Nab
# 可以 Dbab
# 在 P21
# 文化 Nad
# 中心 Ncb
# 參觀 Nv1
# 活動 Nac
# 中 Ng
# 先 Dd
# 了解 VK1
# 何謂 VG2
# 卑南 Nba
# 文化 Nad
# 不再 Dd
# 是 V_11
# 冥頑不靈 VH11
# 的 DE
# 石頭 Nab
# 、 Caa
# 也 Dbb
# 不再 Dd
# 是 V_11
# 平凡 VH11
# 的 DE
# 面孔 Nac
# 聰明 VH11
# 的 DE
# 人 Nab
# 都 Dab
# 從 P19
# 富岡 Nba
# 碼頭 Ncb
# 這 Nep
# 一 Neu
# 端 Ncda
# 開始 VL2
# 玩 VC2
# 起 Di
# 交疊出 VJ1
# 豆腐岩 Nab
# 、 Caa
# 蜂窩岩 Nab
# 、 Caa
# 蕈狀岩 Nab
# 、 Caa
# 珊瑚礁岩 Nab
# 、 Caa
# 豆腐岩 Nab
# 、 Caa
# 小 VH13
# 單面 Nac
# 山群 Nab
# 、 Caa
# 蕈狀岩 Nab
# 等 Cab
# 岩塊 Nab
# ９年 DM
# 前 Ng
# 我 Nhaa
# 到 VC1
# 台東 Nca
# 時 Ng
# 附近 Ncb
# 還 Dbb
# 有 V_2
# 半露天 Ncb
# 的 DE
# 溫泉 Nab
# 知本 Nca
# 溫泉 Nab
# 屬 VG2
# 鹼性 Nad
# 碳 Naa
# 初 Dd
# 入浴 VA11
# 時 Ng
# 小心 VK1
# 太 Dfa
# 燙 VH11
# 使 VL4
# 瀑布 Nab
# 失 VJ3
# 了 Di
# 水煙 Naa
# 瀰漫 VH14
# 、 Caa
# 秀麗 VH11
# 壯觀 VH11
# 的 DE
# 景象 Nac
# 知本溪 Nca
# 攔砂壩 Nab
# 附近 Ncb
# 尚 Dd
# 有 V_2
# 氣勢不凡 VH11
# 的 DE
# 知本 Nca
# 峽谷 Nab
# 、 Caa
# 清覺寺 Nca
# 值得 VH15
# 一 Dd
# 遊 VC1
# 沿著 P24
# 這條 DM
# 充滿 VJ3
# 商業 Nad
# 氣息 Naa
# 的 DE
# 路 Nab
# 往 P30
# 前 Ncda
# 走 VA11
# 即可 Dbab
# 抵達 VC1
# 區 Ncb
# 內 Ncda
# 有 V_2
# 烤肉區 Ncb
# 、 Caa
# 野餐區 Ncb
# 、 Caa
# 露營區 Ncb
# 、 Caa
# 營火區 Ncb
# 、 Caa
# 溫室 Ncb
# 、 Caa
# 山莊 Ncb
# 、 Caa
# 植物園 Ncb
# 及 Caa
# 各 Nes
# 臺灣 Nca
# 特有 A
# 林木 Naeb
# 樟樹林 Nab
# 、 Caa
# 闊葉林 Nab
# 、 Caa
# 桃花 Nab
# 心木林 Nab
# 、 Caa
# 松樹 Nab
# 、 Caa
# 桂樹林 Nab
# 、 Caa
# 茄冬 Nab
# 古 VH11
# 樹 Nab
# 、 Caa
# 光臘 Nba
# 樹林 Nab
# 溫室 Ncb
# 破敗 VH11
# 、 Caa
# 外來種 Nac
# 的 DE
# 強勢 Nad
# 植物 Nab
# 馬櫻丹 Nab
# 等 Cab
# 大 VH13
# 面積 Nad
# 栽培 VC2
# 沿途 Ncb
# 有 V_2
# 忠烈祠 Nca
# 、 Caa
# 鯉魚山 Nca
# 公園 Ncb
# 、 Caa
# 救國團 Nca
# 青年 Nab
# 育樂 Naea
# 中心 Ncb
# 在 P21
# 山麓 Nab
# 並 Dbb
# 曾 Dd
# 發現 VE2
# 新石器時代 Ndaaa
# 的 DE
# 石棺 Nab
# 、 Caa
# 石骨 Nab
# 等 Cab
# 遺物 Nac
# 祠堂 Ncb
# 兩 Neu
# 側 Ncdb
# 並 Dbb
# 有 V_2
# 清 Ndaab
# 末 Ng
# 台東 Nca
# 直隸州 Nca
# 胡鐵花 Nba
# 紀念碑 Nab
# 公園 Ncb
# 內 Ncda
# 還 Dbb
# 有 V_2
# 一部 DM
# 早期 Ndabf
# 的 DE
# 蒸汽 Naa
# 火車頭 Nab
# 、 Caa
# 火車迷 Nab
# 不可 Dbab
# 錯過 VJ1
# 包括 VK2
# 台北 Nca
# 的 DE
# 大街小巷 Ncb
# 也 Dbb
# 洋溢 VH14
# 著 Di
# 節慶 Nac
# 的 DE
# 歡樂 VH21
# 氣氛 Nad
# 除了 P50
# 教堂 Ncb
# 和 Caa
# 街道 Nab
# 上 Ncda
# 零星 VH11
# 的 DE
# 耶誕樹 Nab
# 閃 VA12
# 著 Di
# 霓虹 Nab
# 的 DE
# 燈光 Naa
# 外 Ng
# 這裡 Ncdb
# 的 DE
# 小朋友 Nab
# 並 Dbb
# 不 Dc
# 期盼 VK1
# 叮噹 A
# 的 DE
# 鈴聲 Nad
# 和 Caa
# 耶誕 Ndabd
# 小 VH13
# 禮物 Nab
# 猴祭 Nac
# 是 V_11
# １２ Neu
# － Caa
# １８ Neu
# 歲 Nfg
# 青少年 Nab
# 一連串 A
# 戰技 Nad
# 訓練 Nad
# 、 Caa
# 絕對 Dbaa
# 服從 VC2
# 長上 Nab
# 、 Caa
# 敬老尊賢 VH11
# 的 DE
# 儀式 Nac
# 兄弟 Nab
# 中 Ng
# 弟弟 Nab
# 在 P21
# 一 Neu
# 大 VH13
# 山洞 Nab
# 前 Ncda
# 發現 VE2
# 了 Di
# 妹妹 Nab
# 的 DE
# 衣物 Naeb
# 並 Cbcb
# 給 P04
# 他 Nhaa
# 吃 VC31
# 蜥蜴 Nab
# 、 Caa
# 蚯蚓 Nab
# 等 Cab
# 被 P02
# 原住民 Nab
# 視為 VG1
# 穢物 Nab
# 的 DE
# 東西 Nab
# 族 Nab
# 裡 Ncda
# 長老 Nab
# 也 Dbb
# 不 Dc
# 忍心 VK1
# 他們 Nhaa
# 繼續 VF1
# 在 P21
# 外 Ncda
# 流浪 VA11
# 並 Cbcb
# 昭告 VE12
# 族人 Nab
# 新 VH11
# 屋 Nab
# 落成 VH11
# 之 DE
# 日 Nac
# 不得 Dbab
# 有 Nes
# 人 Nab
# 靠近 VC2
# 種種 Neqa
# 的 DE
# 不滿 Nv2
# 讓 VL4
# 他們 Nhaa
# 覺得 VK1
# 父親 Nab
# 不配 Dbab
# 做 VG2
# 他們 Nhaa
# 的 DE
# 父親 Nab
# 後來 Nddb
# 為了 P03
# 紀念 VJ2
# 整個 DM
# 事件 Nac
# 並 Cbcb
# 訓練 VC2
# 青少年 Nab
# 有 V_2
# 兩 Neu
# 兄弟 Nab
# 的 DE
# 膽識 Nad
# 沒有 Nes
# 少年 Nab
# 會 Dbaa
# 因 Cbaa
# 受不了 VC1
# 鞭打 Nv1
# 或 Caa
# 考驗 Nac
# 而 Cbca
# 退出 VC1
# 的 Ta
# 今年 Ndaba
# 因為 Cbaa
# 得到 VJ3
# 行政院 Nca
# 文人 Nab
# 建設 Naeb
# 委員會 Ncb
# 的 DE
# 支持 Nv1
# 及 Caa
# 贊助 Nv1
# 配合 VC2
# 卑南 Nba
# 文物展 Nad
# 、 Caa
# 歌謠 Nab
# 演唱 Nv1
# 、 Caa
# 文化 Nad
# 之 DE
# 族 Nab
# 、 Caa
# 大獵祭 Nac
# 、 Caa
# 迎接 VC2
# 凱旋 Nad
# 、 Caa
# 美食 Naeb
# 饗宴 Nac
# 、 Caa
# 八社 Nca
# 聯合祭 Nac
# 、 Caa
# 神話 Nac
# 故事 Nac
# 集錦 Nad
# 等 Cab
# 活動 Nac
# 出外 VA11
# 旅行 VA4
# 的 DE
# 一 Neu
# 大 VH13
# 享受 Nv2
# 就 Dd
# 是 V_11
# 吃吃 VC31
# 喝喝 VC31
# 嘍 Tc
# 台東 Nca
# 的 DE
# 特產 Nab
# 是 V_11
# 海鮮 Naeb
# 、 Caa
# 金針菇 Nab
# 、 Caa
# 柴魚 Nab
# 、 Caa
# 小米 Naa
# 洛神花 Nab
# 蜜餞 Naa
# 、 Caa
# 釋迦 Nab
# 、 Caa
# 木瓜 Nab
# 及 Caa
# 各式 DM
# 小吃 Naa
# 夜市 Ncb
# 有 V_2
# 光明路 Nca
# 、 Caa
# 福建路 Nca
# 正氣路 Nca
# 口 Ncda
# 、 Caa
# 寶桑路 Nca
# 、 Caa
# 四維 Nba
# 等 Cab
# 夜市 Ncb
# 台東 Nca
# 特產 Nab
# 水果 Nab
# 釋迦 Nab
# 、 Caa
# 木瓜 Nab
# 、 Caa
# 琵琶 Nab
# 、 Caa
# 葡萄柚 Nab
# 及 Caa
# 各式 DM
# 蜜餞 Naa
# 、 Caa
# 柴魚 Nab
# 、 Caa
# 金針菇 Nab
# 等 Cab
# 一應俱全 VH11
# 正氣路 Nca
# 上 Ncda
# 的 DE
# 米苔目王 Nba
# 是 V_11
# 老饕 Nab
# 不可 Dbab
# 不 Dc
# 到 VC1
# 的 DE
# 小吃店 Ncb
# 鹹 VH11
# 米苔目 Naa
# 以 P11
# 菜 Nab
# 、 Caa
# 豆芽菜 Nab
# 、 Caa
# 芹菜 Nab
# 、 Caa
# 柴魚 Nab
# 、 Caa
# 肉燥 Naa
# 和 Caa
# 米苔目 Naa
# 一起 Dh
# 煮出 VC2
# 香味四溢 VH11
# 、 Caa
# 油 VH11
# 而 Caa
# 不 Dc
# 膩 VH11
# 的 DE
# 正宗 Nad
# 小吃 Naa
# 不 Dc
# 知道 VK1
# 您 Nhac
# 吃 VC31
# 不 Dc
# 吃 VC31
# 得 DE
# ３０餘年 DM
# 歷史 Nad
# 的 DE
# 好 VH11
# 味道 Nad
# 趕著 Dh
# 在 P21
# 火車 Nab
# 開動 VA4
# 前 Ng
# 買 VC31
# 池上 Nca
# 便當 Nab
# 了 Ta
# 、 Caa
# 台東市 Nca
# 更生路 Nca
# ５０１號 Ncb
# 也 Dbb
# 有 V_2
# 池上 Nca
# 便當 Nab
# 的 DE
# 門市 Ncb
# 販賣 VD1
# 上好 A
# 的 DE
# 柴魚 Nab
# 鮮 VH11
# 而 Caa
# 不 Dc
# 腥 VH11
# 、 Caa
# 薄 VH11
# 而 Caa
# 不 Dc
# 韌 VH11
# 以 P11
# 台東市 Nca
# 為 VG1
# 中心 Ncb
# 可 Dbab
# 遊覽 VC1
# 文化 Nad
# 中心 Ncb
# 、 Caa
# 鯉魚山 Nca
# 風景區 Ncb
# 、 Caa
# 小野柳 Nca
# 、 Caa
# 知本 Nca
# 森林 Nab
# 遊樂區 Ncb
# 、 Caa
# 初鹿 Nca
# 牧場 Ncb
# 、 Caa
# 卑南 Nba
# 遺跡 Nab
# 、 Caa
# 市區 Ncb
# 遊覽 Nv4
# 、 Caa
# 杉原 Nba
# 海水 Naa
# 浴場 Ncb
# 、 Caa
# 卑南族 Nba
# 大 VH13
# 獵場 Ncb
# 、 Caa
# 台東 Nca
# 海堤 Ncb
# 都蘭 Nca
# 林場 Ncb
# 、 Caa
# 泰源 Nca
# 幽谷 Ncb
# 、 Caa
# 三仙台 Nca
# 、 Caa
# 石雨傘 Nca
# 、 Caa
# 烏石鼻 Nca
# 、 Caa
# 長濱 Nca
# 史前 Ndc
# 文化 Nad
# 、 Caa
# 八仙洞 Nca
# 花東 Nca
# 縱谷 Nab
# 是 V_11
# 東部 Ncdb
# 海岸 Ncc
# 山區 Ncb
# 與 Caa
# 中央山脈 Nca
# 間 Ncda
# 所 Dab
# 夾峙 VJ1
# 的 DE
# 狹長 VH11
# 谷地 Nab
# 紅葉村 Nca
# 附近 Ncb
# 的 DE
# 龍門峽 Nca
# 和 Caa
# 蘇鐵 Nba
# 保護村 Nca
# 、 Caa
# 鹿野 Nca
# 觀光 Nv4
# 茶園 Ncb
# 、 Caa
# 關山 Nca
# 的 DE
# 加拿 Nba
# 瀑布 Nab
# 、 Caa
# 池上 Nca
# 大坡湖 Nca
# 先 Dd
# 是 V_11
# 於 P23
# 今年 Ndaba
# 元月 Ndabc
# １日 Ndabd
# 起 Ng
# 實施 VC2
# １２ Neu
# 國 Ncb
# 友好 VH11
# 國家 Nac
# 人民 Naeb
# 來 VA11
# 華 Nca
# １２０ Neu
# 免 Dbab
# 簽證 VA4
# 措施 Nac
# 在 P21
# 本 Nes
# 國 Ncb
# 設有 VJ3
# 辦事處 Ncb
# 、 Caa
# 旅遊 Nv4
# 推廣 Nv1
# 機構 Nac
# 或 Caa
# 與 P35
# 我國 Ncb
# 有 V_2
# 邦交 Nad
# 的 DE
# 國家 Nac
# 與 P35
# 我國 Ncb
# 無 VJ3
# 邦交 Nad
# 且 Caa
# 在 P21
# 我國 Ncb
# 未 Dc
# 設 VC33
# 辦事處 Ncb
# 、 Caa
# 旅遊 Nv4
# 機構 Nac
# 的 DE
# 國家 Nac
# 台胞證 Nab
# 主要 VH11
# 是 V_11
# 針對 P31
# 國人 Naea
# 進入 VC1
# 大陸 Nca
# 地區 Ncb
# 所 Dab
# 辦理 VC2
# 的 DE
# 特定 A
# 證件 Nab
# 據 P43
# 大陸 Nca
# 當局 Nad
# 於 P23
# ８１年 Ndaad
# ５月 Ndabc
# １日 Ndabd
# 實施 VC2
# 的 DE
# 中國 Nca
# 公民 Nab
# 往來 VC1
# 台灣 Nca
# 地區 Ncb
# 管理 Nv1
# 辦法 Nac
# 可 Dbab
# 持 VC2
# 證 Nab
# 至 P61
# 當地 Nce
# 公安局 Nca
# 出入境 Nv4
# 管理 Nv1
# 部門 Nac
# 申請 VF1
# 停留 Nv4
# 延期 Nv1
# 申請 Nv1
# 文件 Nab
# 包含 VJ3
# 居住 Nv4
# 、 Caa
# 身分 Nad
# 證明 Nac
# 、 Caa
# 申請 Nv1
# 事宜 Nac
# 及 Caa
# 相關 VH11
# 證件 Nab
# 申請 Nv1
# 單位 Nac
# 則 Dbb
# 是 V_11
# 公安部 Nca
# 在 P21
# 香港 Nca
# 、 Caa
# 澳門 Nca
# 所 Dab
# 委託 VF2
# 的 DE
# 有關 Nv3
# 機構 Nac
# 但 Cbca
# 因 Cbaa
# 世界 Ncb
# 各 Nes
# 國 Ncb
# 對 P31
# 我國 Ncb
# 國際 Ncc
# 駕照 Nab
# 承認 VE2
# 情況 Nac
# 不同 VH11
# 準備 VC2
# 護照 Nab
# 正本 Nab
# 、 Caa
# 駕照 Nab
# 、 Caa
# 身分證 Nab
# 、 Caa
# 最近 Nddc
# 兩吋 DM
# 半身 Dg
# 光面 A
# 脫帽 Nv4
# 照片 Nab
# 以及 Caa
# 新台幣 Naeb
# ２５０元 DM
# 因此 Cbca
# 可 Dbab
# 將 P07
# 客車 Nab
# 與 Caa
# 機車 Nab
# 駕照 Nab
# 申請 VF1
# 在 P21
# 同一本 DM
# 國際 Ncc
# 駕照 Nab
# 上 Ncda
# 如 P47
# 國內外 Ncc
# 交通 Nad
# 包括 VK2
# 國際 Ncc
# 青年 Nab
# 機票 Nab
# 、 Caa
# 參觀 Nv1
# 門票 Nab
# 與 Caa
# 購物 Nv4
# 折扣 Naeb
# 等 Cab
# 此 Nep
# 證 Nab
# 可 Dbab
# 享受 VJ2
# 全球 Nce
# １２０家 DM
# 學生 Nab
# 旅遊 Nv4
# 組織 Nac
# 所 Dab
# 提供 VD1
# 的 DE
# 旅遊 Nab
# 資訊 Nad
# 服務 Nv1
# 且 Cbcb
# 非 Dc
# 在學 VH11
# 青年 Nab
# 也 Dbb
# 能 Dbab
# 享有 VJ3
# 機票 Nab
# 與 Caa
# 購物 Nv4
# 的 DE
# 優惠 Nv3
# 折扣 Naeb
# 國際 Ncc
# 學生 Nab
# 及 Caa
# 青年 Nab
# 機票 Nab
# 已 Dd
# 在 P21
# 國際 Ncc
# 間 Ng
# 發行 VC31
# 多年 DM
# 只要 Cbaa
# 持 VC2
# 有效期 Nad
# 國際 Ncc
# 學生證 Nab
# ＩＳＩＣ Nba
# 、 Caa
# ＳＴＡ Nba
# 青年證 Nab
# 、 Caa
# ＳＴＡ Nba
# 會員證 Nab

# %%
# https://github.com/fxsjy/jieba

# %%
default_tagger = nltk.DefaultTagger('NN')
raw = '我 累 个 去 啊'
tokens = nltk.word_tokenize(raw)
tags = default_tagger.tag(word)
tags
# Out:
# [('會員證', 'NN'), ('Nab', 'NN')]

# %%
tagged_sents =  [ [(u'我',u'PRO') ,(u'小兔',u'NN')]]
print(tagged_sents[0][1])
unigram_tagger = nltk.UnigramTagger(tagged_sents)
print(unigram_tagger)
sents = brown.sents(categories = 'news')
sents = [[u'我', u'你', u'小兔']]
tags = unigram_tagger.tag(sents[0])
print(tags)
# Out:
# ('小兔', 'NN')
# <UnigramTagger: size=2>
# [('我', 'PRO'), ('你', None), ('小兔', 'NN')]

# %%
brown_tagged_sents = brown.tagged_sents(categories = 'news')
brown_tagged_sents
# Out:
# [[('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')], [('The', 'AT'), ('jury', 'NN'), ('further', 'RBR'), ('said', 'VBD'), ('in', 'IN'), ('term-end', 'NN'), ('presentments', 'NNS'), ('that', 'CS'), ('the', 'AT'), ('City', 'NN-TL'), ('Executive', 'JJ-TL'), ('Committee', 'NN-TL'), (',', ','), ('which', 'WDT'), ('had', 'HVD'), ('over-all', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('the', 'AT'), ('election', 'NN'), (',', ','), ('``', '``'), ('deserves', 'VBZ'), ('the', 'AT'), ('praise', 'NN'), ('and', 'CC'), ('thanks', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('City', 'NN-TL'), ('of', 'IN-TL'), ('Atlanta', 'NP-TL'), ("''", "''"), ('for', 'IN'), ('the', 'AT'), ('manner', 'NN'), ('in', 'IN'), ('which', 'WDT'), ('the', 'AT'), ('election', 'NN'), ('was', 'BEDZ'), ('conducted', 'VBN'), ('.', '.')], ...]

# %%
train_sents = nltk.corpus.genesis.words('english-kjv.txt')
t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(train_sents, backoff=t0)
t2 = nltk.BigramTagger(train_sents, backoff=t1) 

import _pickle as cPickle
from _pickle import dump
from _pickle import load
output = open('t2.pkl','wb')
dump(t2,output,-1)
output.close()
# input = open('t2.pkl','rb')
# tagger = load(input)
# input.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-734470bb86c3> in <module>()
#       1 train_sents = nltk.corpus.genesis.words('english-kjv.txt')
#       2 t0 = nltk.DefaultTagger('NN')
# ----> 3 t1 = nltk.UnigramTagger(train_sents, backoff=t0)
#       4 t2 = nltk.BigramTagger(train_sents, backoff=t1)
#       5
#
# d:\Users\Administrator\Anaconda3\lib\site-packages\nltk\tag\sequential.py in __init__(self, train, model, backoff, cutoff, verbose)
#     338                  backoff=None, cutoff=0, verbose=False):
#     339         NgramTagger.__init__(self, 1, train, model,
# --> 340                              backoff, cutoff, verbose)
#     341
#     342     def encode_json_obj(self):
#
# d:\Users\Administrator\Anaconda3\lib\site-packages\nltk\tag\sequential.py in __init__(self, n, train, model, backoff, cutoff, verbose)
#     285
#     286         if train:
# --> 287             self._train(train, cutoff, verbose)
#     288
#     289     def encode_json_obj(self):
#
# d:\Users\Administrator\Anaconda3\lib\site-packages\nltk\tag\sequential.py in _train(self, tagged_corpus, cutoff, verbose)
#     176         fd = ConditionalFreqDist()
#     177         for sentence in tagged_corpus:
# --> 178             tokens, tags = zip(*sentence)
#     179             for index, (token, tag) in enumerate(sentence):
#     180                 # Record the event.
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
# 五-自然语言处理中的文本分类
my_train_set = [
    ({'feature1':u'a'},'1'),
    ({'feature1':u'a'},'2'),
    ({'feature1':u'a'},'3'),
    ({'feature1':u'a'},'3'),
    ({'feature1':u'b'},'2'),
    ({'feature1':u'b'},'2'),
    ({'feature1':u'b'},'2'),
    ({'feature1':u'b'},'2'),
    ({'feature1':u'b'},'2'),
    ({'feature1':u'b'},'2'),
]
classifier = nltk.NaiveBayesClassifier.train(my_train_set)
print( classifier.classify({'feature1':u'a'}))
# Out:
# 3

# %%
from nltk.corpus import movie_reviews
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = list(all_words.keys())[:2000]

print(word_features)
# Out:
# ['mayor', 'diarist', 'brooks', 'ease', 'depicted', 'arsed', 'expectations', 'quarry', 'upbeat', 'standers', 'graziella', 'preminger', 'nibble', 'raised', 'paradoxical', 'hoodwink', 'efficiently', 'alan', 'beavis', 'outer', 'visual', 'zus', 'luciano', 'pedophilic', 'leconte', 'powerlessness', 'sprouse', 'touted', 'lux', 'hellhole', 'lifter', 'cindy', 'mcneill', 'arecibo', 'chill', 'memorabilia', 'eyeroll', 'male', '167', 'tripper', '_porky', 'reuben', 'capitol', 'subliminal', 'heirloom', 'siding', 'uneasiness', 'gadgetry', 'ugh', 'dwarves', 'crocodile', 'lili', 'snazzy', 'tasha', 'projecting', 'colin', 'stall', 'reform', 'kinnear', 'unsuitable', 'musicians', 'thurgood', '2020', 'stiletto', 'stipend', 'videos', 'doesnut', 'lulls', 'australia', 'strums', 'deflower', 'bayou_', 'theoretical', 'hark', 'unexpected', 'marooned', 'arizona', 'grilling', 'decidedly', 'cooler', '42', 'jars', 'grocery', 'rocky', 'ot', 'kilner', 'tit', 'thompson', 'bath', 'ensuring', 'howington', 'francesco', 'quintana', 'dude', 'traders', 'treaty', 'dismay', 'audacious', 'curtiz', 'left', "/'", 'antennae', 'unidentified', 'builder', 'paralleling', 'greatest', 'thumbs', 'bronx', 'cheerleaders', 'kujan', 'loyality', 'say', 'cynics', 'telly', 'vaporize', 'retriever', 'sixteen', 'risqu', 'oneders', 'helicopter', 'lysterine', 'aviation', 'inescapable', 'unabashedly', 'prentice', 'escort', 'soothe', 'perplexed', 'reap', 'erickson', 'blitzed', 'puppeteering', 'ingredient', 'dow', 'surrealism', 'asp', 'swimmer', 'christ', 'irked', 'appeals', 'creamy', 'leashes', 'militant', 'heretic', 'synth', 'waddling', 'crops', 'victoire', 'assisting', 'gascogne', 'overlight', 'daft', '_wayyyyy_', 'laudable', 'grave', 'buffoonish', 'sorderbergh', 'comatose', 'jaye', 'teen', 'apex', 'prim', 'humorless', 'golfer', 'assert', 'happenning', 'remains', 'prom', 'enticingly', 'separatist', 'situational', 'mirthless', 'scatalogical', 'azure', 'butts', 'loft', 'morquio', 'meaninglessness', '13th', 'whelming', 'chung', 'ripper', 'wachowski', 'ardently', 'knit', 'haul', 'machines', 'hope', 'sect', 'completists', 'seeing', 'replace', 'nightly', 'meteorite', 'emissary', 'alway', 'aunt', 'tweed', 'course', 'naivete', 'declares', 'simm', 'tibetans', 'ambles', 'lifted', 'crests', 'expulsion', 'knutt', 'rediscover', 'pesence', 'actualizing', 'unwinds', 'leapfrog', '66', 'garnish', 'arsenal', 'mesquida', 'babycakes', 'ziegler', 'cate', 'menacing', 'crusher', 'jenny', 'idolize', 'stock', 'happiness', 'intuition', 'marian', 'leaf', 'consolidate', 'riding', 'hanger', 'chaney', 'prompt', 'flexible', 'necessarily', 'thx', 'ripened', 'reportedly', 'abducted', 'harada', 'metaphorically', 'grownups', 'rows', 'gayle', 'intertwines', 'perspectives', '8th', 'handiwork', 'reconnect', 'win', 'wheat', '30s', 'witzky', 'linear', 'obnoxious', 'loaded', 'firefighters', 'tuesday', 'squad', 'damed', 'fireside', 'buddies', 'hendricks', 'objections', 'sighing', 'osborne', 'impeccably', 'trendiness', 'decimated', 'mtcts1', 'feminist', 'peron', 'undoes', 'xref', 'chi', 'lerner', 'beckel', 'climactic', 'moron', 'roundhouse', 'ditto', 'geneticist', 'souvenir', 'impostors', 'slays', 'recovers', 'convenience', 'c3', 'empathetic', 'allowing', 'apropos', 'exec', 'yoo', 'crumb', 'admired', 'tabloids', 'herb', 'visas', 'talented', 'shapely', 'statuesque', 'wizard', 'wachowskis', 'mild', 'ringwood', 'sentencing', 'job', 'demises', 'imgen', 'elizabethan', 'hirst', 'mistaking', 'sheets', 'egg', 'gibbs', 'persecuted', 'divulge', 'gots', 'regression', 'ragsdale', 'meditate', 'catering', 'embarked', 'prize', 'homogeneity', 'labelled', 'while', 'fascinating', 'agonizingly', 'unfortunately', 'dewy', 'mann', 'luftwaffe', 'levying', 'regular', 'alejandro', 'batting', 'namesakes', 'optimism', 'malik', 'barreness', 'diverting', 'extraneous', 'faison', 'manners', 'resubmit', 'mexico', 'laded', 'inroad', 'harwich', 'berserk', 'transmissions', 'depicting', 'nello', 'rates', 'tie', 'flamethrowers', 'wait', 'hockley', 'jelly', 'thankfully', 'g ...

# %%
def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word ] =( word in document_words)
    return features

# %%
documents = [(list(movie_reviews.words(fileid)),category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)
             # fileids  file id s
             ]
featuressets = [ (document_features(d),c ) for (d ,c ) in documents]
train_set ,test_set = featuressets[100:],featuressets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier,test_set))
classifier.show_most_informative_features(5)
# Out:
# 0.68
# Most Informative Features
#      contains(furniture) = True              neg : pos    =      8.5 : 1.0
#        contains(winslet) = True              pos : neg    =      8.1 : 1.0
#       contains(depicted) = True              pos : neg    =      7.4 : 1.0
#       contains(everyman) = True              pos : neg    =      6.9 : 1.0
#          contains(masks) = True              neg : pos    =      6.3 : 1.0
